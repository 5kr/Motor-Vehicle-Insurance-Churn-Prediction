# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import variation 
# %matplotlib inline

# %%
df_low=pd.read_csv("Low_budget.csv")
df_mid=pd.read_csv("Mid_budget.csv")
df_high=pd.read_csv("High_budget.csv")

# %%
df_low.head(5)
# Out:
#   INTERMEDIARY     CHANNEL  VEH_MANU_YEAR VEHICLE_MAKE   VEHICLE_MODEL  \
# 0  IMD-1101735      AGENCY         2009.0         FIAT           LINEA
# 1  IMD-1100101      AGENCY         2008.0        HONDA        NEW CITY
# 2  IMD-1100113      AGENCY         2011.0   VOLKSWAGEN            POLO
# 3  IMD-1100144  DEALERSHIP         2006.0         TATA  INDICA V2 XETA
# 4  IMD-1100733      AGENCY         2006.0         FORD            IKON
#
#   VEH_ORIG  SUM_INSURED  TOTAL_PREMIUM  OD_PREM  TP_PREM  ...  VEH_AGE  \
# 0  Foreign       282610           5462     3491     1972  ...     11.0
# 1  Foreign       260217           6008     4008     2000  ...     12.0
# 2  Foreign       292940           7527     4724     2803  ...      9.0
# 3   Indian       127418           4784     2981     1803  ...     14.0
# 4  Foreign       266217           9296     6324     2972  ...     14.0
#
#    SENIORITY  Ratio_PS  BODY_TYPE  CAR_BUDGET CAR_TYPE   LOCATION  \
# ...

# %%
df_mid.head(5)
# Out:
#   INTERMEDIARY     CHANNEL  VEH_MANU_YEAR VEHICLE_MAKE VEHICLE_MODEL VEH_ORIG  \
# 0  IMD-1100111  DEALERSHIP         2016.0   VOLKSWAGEN          POLO  Foreign
# 1  IMD-1102937      AGENCY         2014.0    CHEVROLET         ENJOY  Foreign
# 2  IMD-1100862      AGENCY         2010.0    CHEVROLET       CAPTIVA  Foreign
# 3  IMD-1100101      AGENCY         2011.0   VOLKSWAGEN         VENTO  Foreign
# 4  IMD-1100522      AGENCY         2012.0          BMW      3 Series  Foreign
#
#    SUM_INSURED  TOTAL_PREMIUM  OD_PREM  TP_PREM  ...  VEH_AGE  SENIORITY  \
# 0       628167          33966    30825     3140  ...      2.0   0.000000
# 1       516817          12988    10410     2578  ...      6.0   0.166667
# 2       866967          19058    11556     7502  ...     10.0   0.600000
# 3       528180          25652    19931     5721  ...      9.0   0.333333
# 4      1475217          29300    23439     5862  ...      8.0   0.250000
#
# ...

# %%
df_high.head(5)
# Out:
#   INTERMEDIARY     CHANNEL  VEH_MANU_YEAR   VEHICLE_MAKE  \
# 0  IMD-1100101      AGENCY         2014.0  MERCEDES-BENZ
# 1  IMD-1101649      AGENCY         2012.0            BMW
# 2  IMD-1100391  DEALERSHIP         2014.0  MERCEDES-BENZ
# 3  IMD-1101017      AGENCY         2011.0           AUDI
# 4  IMD-1100101      AGENCY         2008.0         TOYOTA
#
#           VEHICLE_MODEL VEH_ORIG  SUM_INSURED  TOTAL_PREMIUM  OD_PREM  \
# 0              GL CLASS  Foreign      6500217          82591    77331
# 1  6 Series Convertible  Foreign      6800317         227128   220020
# 2               C CLASS  Foreign      3500217          72514    65378
# 3                    A6  Foreign      2500217          51305    45471
# 4    LAND CRUSIER PRADO  Foreign      2780217          55348    49233
#
#    TP_PREM  ...  VEH_AGE  SENIORITY  Ratio_PS    BODY_TYPE  CAR_BUDGET  \
# 0     5260  ...      4.0       0.00  0.012706          SUV        High
# ...

# %%
df_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611362 entries, 0 to 611361
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   INTERMEDIARY   611362 non-null  object
#  1   CHANNEL        611362 non-null  object
#  2   VEH_MANU_YEAR  611362 non-null  float64
#  3   VEHICLE_MAKE   611362 non-null  object
#  4   VEHICLE_MODEL  611362 non-null  object
#  5   VEH_ORIG       611362 non-null  object
#  6   SUM_INSURED    611362 non-null  int64
#  7   TOTAL_PREMIUM  611362 non-null  int64
#  8   OD_PREM        611362 non-null  int64
#  9   TP_PREM        611362 non-null  int64
#  10  POLICY_AGE     611362 non-null  float64
#  11  NCB            611362 non-null  float64
#  12  VEH_AGE        611362 non-null  float64
#  13  SENIORITY      611362 non-null  float64
#  14  Ratio_PS       611362 non-null  float64
#  15  BODY_TYPE      611362 non-null  object
#  16  CAR_BUDGET     611362 non-null  object
# ...

# %%
df_mid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143629 entries, 0 to 143628
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   INTERMEDIARY   143629 non-null  object
#  1   CHANNEL        143629 non-null  object
#  2   VEH_MANU_YEAR  143629 non-null  float64
#  3   VEHICLE_MAKE   143629 non-null  object
#  4   VEHICLE_MODEL  143629 non-null  object
#  5   VEH_ORIG       143629 non-null  object
#  6   SUM_INSURED    143629 non-null  int64
#  7   TOTAL_PREMIUM  143629 non-null  int64
#  8   OD_PREM        143629 non-null  int64
#  9   TP_PREM        143629 non-null  int64
#  10  POLICY_AGE     143629 non-null  float64
#  11  NCB            143629 non-null  float64
#  12  VEH_AGE        143629 non-null  float64
#  13  SENIORITY      143629 non-null  float64
#  14  Ratio_PS       143629 non-null  float64
#  15  BODY_TYPE      143629 non-null  object
#  16  CAR_BUDGET     143629 non-null  object
# ...

# %%
df_high.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5393 entries, 0 to 5392
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   INTERMEDIARY   5393 non-null   object
#  1   CHANNEL        5393 non-null   object
#  2   VEH_MANU_YEAR  5393 non-null   float64
#  3   VEHICLE_MAKE   5393 non-null   object
#  4   VEHICLE_MODEL  5393 non-null   object
#  5   VEH_ORIG       5393 non-null   object
#  6   SUM_INSURED    5393 non-null   int64
#  7   TOTAL_PREMIUM  5393 non-null   int64
#  8   OD_PREM        5393 non-null   int64
#  9   TP_PREM        5393 non-null   int64
#  10  POLICY_AGE     5393 non-null   float64
#  11  NCB            5393 non-null   float64
#  12  VEH_AGE        5393 non-null   float64
#  13  SENIORITY      5393 non-null   float64
#  14  Ratio_PS       5393 non-null   float64
#  15  BODY_TYPE      5393 non-null   object
#  16  CAR_BUDGET     5393 non-null   object
# ...

# %%
cat_cols = ['CHANNEL','VEHICLE_MAKE', 'BODY_TYPE','STATE','ZONE','CHURN','CAR_TYPE''VEH_ORIG'],
num_cols = ['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM','POLICY_AGE','NCB', 'VEH_AGE','SENIORITY','Ratio_PS']

# %%
df_low.describe(include='all').T
# Out:
#                 count unique           top    freq       mean        std  \
# INTERMEDIARY   611362   7008   IMD-1100100  380151        NaN        NaN
# CHANNEL        611362      9  CLOSE CIRCLE  380554        NaN        NaN
# VEH_MANU_YEAR  611362    NaN           NaN     NaN    2011.19    3.47867
# VEHICLE_MAKE   611362     32        MARUTI  479814        NaN        NaN
# VEHICLE_MODEL  611362    255       WAGON R   92795        NaN        NaN
# VEH_ORIG       611362      2        Indian  460302        NaN        NaN
# SUM_INSURED    611362    NaN           NaN     NaN     250199     112759
# TOTAL_PREMIUM  611362    NaN           NaN     NaN    8252.98    3586.17
# OD_PREM        611362    NaN           NaN     NaN    5309.52     3380.2
# TP_PREM        611362    NaN           NaN     NaN    2943.52    984.364
# POLICY_AGE     611362    NaN           NaN     NaN    2.33446    2.31344
# NCB            611362    NaN           NaN     NaN    30.3563    17.0894
# ...

# %%
df_mid.describe(include='all').T
# Out:
#                 count unique           top    freq       mean         std  \
# INTERMEDIARY   143629   4979   IMD-1100100   56833        NaN         NaN
# CHANNEL        143629      9  CLOSE CIRCLE   57076        NaN         NaN
# VEH_MANU_YEAR  143629    NaN           NaN     NaN    2014.22      2.2381
# VEHICLE_MAKE   143629     32        MARUTI   64283        NaN         NaN
# VEHICLE_MODEL  143629    233        ERTIGA   19173        NaN         NaN
# VEH_ORIG       143629      2        Indian   78600        NaN         NaN
# SUM_INSURED    143629    NaN           NaN     NaN     787393      315161
# TOTAL_PREMIUM  143629    NaN           NaN     NaN    21960.3      9627.6
# OD_PREM        143629    NaN           NaN     NaN    17619.3     9001.94
# TP_PREM        143629    NaN           NaN     NaN    4340.94     2082.83
# POLICY_AGE     143629    NaN           NaN     NaN   0.741494      1.2936
# NCB            143629    NaN           NaN     NaN    21.5313     14.6329
# ...

# %%
df_high.describe(include='all').T
# Out:
#               count unique            top  freq         mean          std  \
# INTERMEDIARY   5393   1044    IMD-1100101   935          NaN          NaN
# CHANNEL        5393      8         AGENCY  3541          NaN          NaN
# VEH_MANU_YEAR  5393    NaN            NaN   NaN      2013.76      2.35768
# VEHICLE_MAKE   5393     29  MERCEDES-BENZ  1509          NaN          NaN
# VEHICLE_MODEL  5393    132        E CLASS   429          NaN          NaN
# VEH_ORIG       5393      1        Foreign  5393          NaN          NaN
# SUM_INSURED    5393    NaN            NaN   NaN  4.22183e+06  2.49655e+06
# TOTAL_PREMIUM  5393    NaN            NaN   NaN      97452.2        71435
# OD_PREM        5393    NaN            NaN   NaN      90221.8      71409.9
# TP_PREM        5393    NaN            NaN   NaN      7230.49      478.945
# POLICY_AGE     5393    NaN            NaN   NaN     0.470795       1.1638
# NCB            5393    NaN            NaN   NaN      23.2181      14.5868
# ...

# %% [markdown]
# # Univariate Analysis

# %%
# Box Plot for Low budget Segment
for col in num_cols:
    print(col.upper())
    sns.catplot(kind="box",x='CHURN',y = col,data= df_low,orient= 'v')    
    plt.show()
# Out:
# SUM_INSURED
# TOTAL_PREMIUM
# OD_PREM
# TP_PREM
# POLICY_AGE
# NCB
# VEH_AGE
# SENIORITY
# RATIO_PS

# %%
# Box plot for Mid budget Segment
for col in num_cols:
    print(col.upper())
    sns.catplot(kind="box",x='CHURN',y = col,data= df_mid,orient= 'v')    
    plt.show()
# Out:
# SUM_INSURED
# TOTAL_PREMIUM
# OD_PREM
# TP_PREM
# POLICY_AGE
# NCB
# VEH_AGE
# SENIORITY
# RATIO_PS

# %%
#Box plot for High budget segment
for col in num_cols:
    print(col.upper())
    sns.catplot(kind="box",x='CHURN',y = col,data= df_high,orient= 'v')    
    plt.show()
# Out:
# SUM_INSURED
# TOTAL_PREMIUM
# OD_PREM
# TP_PREM
# POLICY_AGE
# NCB
# VEH_AGE
# SENIORITY
# RATIO_PS

# %% [markdown]
# ### Churn distribution

# %%
#Understanding the distribution of attrition in Low budget segment
print('The churn distribution in low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_low['CHURN'].value_counts(normalize=True).round(2))
fig_dims=(20,12)
chart=sns.countplot(x='CHURN', data=df_low,order = df_low['CHURN'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=360)
chart.set(title='Churn distribution')
plt.show()
# Out:
# The churn distribution in low budget segment is :
# -------------------------------------------------------------------------------
# 0    0.66
# 1    0.34
# Name: CHURN, dtype: float64

# %%
#Understanding the distribution of attrition in mid budget segment
print('The overall churn distribution mid budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_mid['CHURN'].value_counts(normalize=True).round(2))
fig_dims=(20,12)
chart=sns.countplot(x='CHURN', data=df_mid,order = df_mid['CHURN'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=360)
chart.set(title='Churn distribution')
plt.show()
# Out:
# The overall churn distribution mid budget segment is :
# -------------------------------------------------------------------------------
# 0    0.59
# 1    0.41
# Name: CHURN, dtype: float64

# %%
#Understanding the distribution of attrition in high budget segment
print('The overall churn distribution high budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_high['CHURN'].value_counts(normalize=True).round(2))
fig_dims=(20,12)
chart=sns.countplot(x='CHURN', data=df_high,order = df_high['CHURN'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=360)
chart.set(title='Churn distribution')
plt.show()
# Out:
# The overall churn distribution high budget segment is :
# -------------------------------------------------------------------------------
# 0    0.53
# 1    0.47
# Name: CHURN, dtype: float64

# %% [markdown]
# ## Distribution of policy holders per zone

# %%
print('The distribution of poliholders per zone for low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_low['ZONE'].value_counts(normalize=True).round(2))
fig_dims=(15,20)
chart=sns.countplot(x='ZONE', data=df_low,order = df_low['ZONE'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Concentration of policyholders per Zone')
plt.show()
# Out:
# The distribution of poliholders per zone for low budget segment is :
# -------------------------------------------------------------------------------
# Western          0.38
# Southern         0.24
# Northern         0.18
# Eastern          0.13
# Central          0.06
# North Eastern    0.01
# Name: ZONE, dtype: float64

# %%
sum_bt_low=df_high.groupby(['ZONE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_low
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                SUM_INSURED  TOTAL_PREMIUM    OD_PREM   TP_PREM
# ZONE
# Western         9525203311      211027254  194327309  16700271
# Northern        5490079197      121411442  111940427   9471051
# Southern        4639595084      105748380   97886426   7861951
# Eastern         1782746133       53030818   50465600   2565262
# Central         1259309097       32549947   30304307   2245670
# North Eastern     71412982        1791980    1642142    149836

# %%
print('The distribution of poliholders per zone for mid budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_mid['ZONE'].value_counts(normalize=True).round(2))
fig_dims=(15,20)
chart=sns.countplot(x='ZONE', data=df_mid,order = df_mid['ZONE'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Concentration of policyholders per Zone')
plt.show()
# Out:
# The distribution of poliholders per zone for mid budget segment is :
# -------------------------------------------------------------------------------
# Western          0.41
# Southern         0.24
# Northern         0.18
# Eastern          0.10
# Central          0.07
# North Eastern    0.01
# Name: ZONE, dtype: float64

# %%
sum_bt_mid=df_mid.groupby(['ZONE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_mid
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                SUM_INSURED  TOTAL_PREMIUM     OD_PREM    TP_PREM
# ZONE
# Western        46045846410     1301259947  1041564760  259703641
# Southern       26837776919      744262694   609956888  134302449
# Northern       21074364367      556948521   435367569  121578141
# Eastern        10734846571      305672692   242171351   63499413
# Central         7603550339      224500460   184474931   40025819
# North Eastern    796057178       21488497    17112950    4375351

# %%
print('The distribution of poliholders per zone for high budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_high['ZONE'].value_counts(normalize=True).round(2))
fig_dims=(15,20)
chart=sns.countplot(x='ZONE', data=df_high,order = df_high['ZONE'].value_counts().index)
chart. set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Concentration of policyholders per Zone')
plt.show()
# Out:
# The distribution of poliholders per zone for high budget segment is :
# -------------------------------------------------------------------------------
# Western          0.43
# Northern         0.24
# Southern         0.20
# Eastern          0.07
# Central          0.06
# North Eastern    0.00
# Name: ZONE, dtype: float64

# %%
sum_bt_high=df_high.groupby(['ZONE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_high
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                SUM_INSURED  TOTAL_PREMIUM    OD_PREM   TP_PREM
# ZONE
# Western         9525203311      211027254  194327309  16700271
# Northern        5490079197      121411442  111940427   9471051
# Southern        4639595084      105748380   97886426   7861951
# Eastern         1782746133       53030818   50465600   2565262
# Central         1259309097       32549947   30304307   2245670
# North Eastern     71412982        1791980    1642142    149836

# %% [markdown]
# ## Distribution of  policy holders according to Car body type

# %%
print('The distribution of poliholders per car body type in low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_low['BODY_TYPE'].value_counts(normalize=True).round(2))
fig_dims=(15,12)
chart=sns.countplot(x='BODY_TYPE',data=df_low,order = df_low['BODY_TYPE'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Level of policyholders per car body type')
plt.show()
# Out:
# The distribution of poliholders per car body type in low budget segment is :
# -------------------------------------------------------------------------------
# Hatchback       0.72
# Sedan           0.16
# Van             0.09
# MUV             0.02
# SUV             0.01
# Pickup Truck    0.00
# Convertible     0.00
# Coupe           0.00
# Name: BODY_TYPE, dtype: float64

# %%
sum_bt_low=df_low.groupby(['BODY_TYPE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_low
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                SUM_INSURED  TOTAL_PREMIUM     OD_PREM     TP_PREM
# BODY_TYPE
# Hatchback     101220468883     3364657150  2171298623  1193393133
# Sedan          31908011828      944135630   616075835   328060683
# Van            11640017666      460631663   309771913   150866021
# MUV             5298561360      164248384    96889921    67356846
# SUV             2802205792      108429477    49670899    58757961
# Pickup Truck      91703356        3397624     2305831     1091855
# Convertible         768598          29405       13563       15843
# Coupe               659623          26346       12016       14329

# %%
print('The distribution of poliholders per car body type in mid budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_mid['BODY_TYPE'].value_counts(normalize=True).round(2))
fig_dims=(15,12)
chart=sns.countplot(x='BODY_TYPE',data=df_mid,order = df_mid['BODY_TYPE'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Level of policyholders per car body type')
plt.show()
# Out:
# The distribution of poliholders per car body type in mid budget segment is :
# -------------------------------------------------------------------------------
# Sedan           0.43
# SUV             0.22
# MUV             0.21
# Hatchback       0.14
# Pickup Truck    0.00
# Van             0.00
# Coupe           0.00
# Convertible     0.00
# Name: BODY_TYPE, dtype: float64

# %%
sum_bt_mid=df_mid.groupby(['BODY_TYPE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_mid
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               SUM_INSURED  TOTAL_PREMIUM     OD_PREM    TP_PREM
# BODY_TYPE
# Sedan         48248438618     1302327572  1043867650  258463018
# SUV           30132362698      840283719   665513986  174769474
# MUV           22664115607      649412954   517975933  131433475
# Hatchback     11939477487      359091699   301023539   58069312
# Pickup Truck     36830331        1342164     1010695     331482
# Van              25511546         793385      565378     228004
# Coupe            40175963         751503      583340     168162
# Convertible       5529534         129815      107928      21887

# %%
print('The distribution of poliholders per car body type in high budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_high['BODY_TYPE'].value_counts(normalize=True).round(2))
fig_dims=(15,12)
chart=sns.countplot(x='BODY_TYPE',data=df_high,order = df_high['BODY_TYPE'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='Level of policyholders per car body type')
plt.show()
# Out:
# The distribution of poliholders per car body type in high budget segment is :
# -------------------------------------------------------------------------------
# Sedan          0.52
# SUV            0.44
# Coupe          0.02
# Hatchback      0.01
# Convertible    0.00
# MUV            0.00
# Van            0.00
# Name: BODY_TYPE, dtype: float64

# %%
sum_bt_high=df_high.groupby(['BODY_TYPE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_high
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#              SUM_INSURED  TOTAL_PREMIUM    OD_PREM   TP_PREM
# BODY_TYPE
# SUV          10552554184      252284612  234891643  17393144
# Sedan        11056254517      245072352  224769383  20303221
# Coupe          674050797       15200743   14621980    578762
# Hatchback      343957352        9866672    9373012    493663
# Convertible     87431671        2096479    1959122    137358
# MUV             28060889         593545     528479     65066
# Van             26036394         445418     422592     22827

# %% [markdown]
# ## Distribution of vehicle Origin across the three segments of the customers

# %%
print('The distribution of vehicle origin per car type in low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_low['VEH_ORIG'].value_counts(normalize=True).round(7))
fig_dims=(15,12)
chart=sns.countplot(x='VEH_ORIG',data=df_low,order = df_low['VEH_ORIG'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='The distribution of vehicle origin per car type')
plt.show()
# Out:
# The distribution of vehicle origin per car type in low budget segment is :
# -------------------------------------------------------------------------------
# Indian     0.752912
# Foreign    0.247088
# Name: VEH_ORIG, dtype: float64

# %%
print('The distribution of vehicle origin per car type in low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_mid['VEH_ORIG'].value_counts(normalize=True).round(7))
fig_dims=(15,12)
chart=sns.countplot(x='VEH_ORIG',data=df_mid,order = df_mid['VEH_ORIG'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='The distribution of vehicle origin per car type')
plt.show()
# Out:
# The distribution of vehicle origin per car type in low budget segment is :
# -------------------------------------------------------------------------------
# Indian     0.547243
# Foreign    0.452757
# Name: VEH_ORIG, dtype: float64

# %%
print('The distribution of vehicle origin per car type in low budget segment is :  ')
print ("-------------------------------------------------------------------------------")
print(df_high['VEH_ORIG'].value_counts(normalize=True).round(7))
fig_dims=(15,12)
chart=sns.countplot(x='VEH_ORIG',data=df_high,order = df_high['VEH_ORIG'].value_counts().index)
chart.set_xticklabels(chart. get_xticklabels(), rotation=45)
chart.set(title='The distribution of vehicle origin per car type')
plt.show()
# Out:
# The distribution of vehicle origin per car type in low budget segment is :
# -------------------------------------------------------------------------------
# Foreign    1.0
# Name: VEH_ORIG, dtype: float64

# %% [markdown]
# ## Distribution of policy holders per state

# %%
fig_dims=(15,12)
chart=sns.catplot(y='STATE', kind='count',data=df_low,aspect=2,order = df_low['STATE'].value_counts().index)
chart.set(title='Distribution of policyholders per State in low budget segment')
plt.show()

# %%
fig_dims=(15,12)
chart=sns.catplot(y='STATE', kind='count',data=df_mid,aspect=2,order = df_mid['STATE'].value_counts().index)
chart.set(title='Distribution of policyholders per State mid budget segment')
plt.show()

# %%
fig_dims=(15,12)
chart=sns.catplot(y='STATE', kind='count',data=df_high,aspect=2,order = df_high['STATE'].value_counts().index)
chart.set(title='Distribution of policyholders per State high budget segment')
plt.show()

# %% [markdown]
# ## Distribution of policy holders per channel across the three segments

# %%
print(df_low['CHANNEL'].value_counts(normalize = True))
fig_dims=(15,12)
chart=sns.catplot(y='CHANNEL', kind='count',data=df_low,aspect=2,order = df_low['CHANNEL'].value_counts().index)
chart.set(title='Distribution of policyholders per Channel')
plt.show()
# Out:
# CLOSE CIRCLE      0.622469
# AGENCY            0.262435
# DIRECT            0.046149
# DEALERSHIP        0.036958
# BANC ASSURANCE    0.019543
# WEBSALES          0.006144
# BROKERS           0.004691
# TRAVEL AGENT      0.001300
# OTHERS            0.000309
# Name: CHANNEL, dtype: float64

# %%
sum_bt_low=df_low.groupby(['CHANNEL'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_low
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 SUM_INSURED  TOTAL_PREMIUM     OD_PREM     TP_PREM
# CHANNEL
# CLOSE CIRCLE    95081484874     3131974744  2087388242  1044622287
# AGENCY          40018999901     1332963467   807798756   525166771
# DIRECT           6924423339      215151144   124365936    90785894
# DEALERSHIP       5865290089      202581011   128394386    74187466
# BANC ASSURANCE   3113973554      100213144    62209127    38004219
# WEBSALES          952314851       30807714    18402676    12404848
# BROKERS           759946639       23482701    12368337    11114534
# TRAVEL AGENT      205616967        6956177     4277840     2678377
# OTHERS             40346892        1425577      833301      592275

# %%
print(df_mid['CHANNEL'].value_counts(normalize = True))
fig_dims=(15,12)
chart=sns.catplot(y='CHANNEL', kind='count',data=df_mid,aspect=2,order = df_mid['CHANNEL'].value_counts().index)
chart.set(title='Distribution of policyholders per Channel')
plt.show()
# Out:
# CLOSE CIRCLE      0.397385
# AGENCY            0.394029
# DEALERSHIP        0.091089
# DIRECT            0.066017
# BANC ASSURANCE    0.032090
# BROKERS           0.009601
# WEBSALES          0.007589
# TRAVEL AGENT      0.001963
# OTHERS            0.000237
# Name: CHANNEL, dtype: float64

# %%
sum_bt_mid=df_mid.groupby(['CHANNEL'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_mid
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 SUM_INSURED  TOTAL_PREMIUM     OD_PREM    TP_PREM
# CHANNEL
# AGENCY          48187029529     1304587107  1002105650  302481484
# CLOSE CIRCLE    39430524177     1122128041   954477944  167650251
# DEALERSHIP      11443562929      372931837   306333451   66598645
# DIRECT           7805036716      187645172   138718022   48927375
# BANC ASSURANCE   3801454447      108421507    85873769   22547357
# BROKERS          1237510429       28560347    21286850    7273625
# WEBSALES          903886561       21892195    15635391    6256844
# TRAVEL AGENT      252082755        7089502     5529315    1560187
# OTHERS             31354241         877103      688057     189046

# %%
print(df_high['CHANNEL'].value_counts(normalize = True))
fig_dims=(15,12)
chart=sns.catplot(y='CHANNEL', kind='count',data=df_high,aspect=2,order = df_high['CHANNEL'].value_counts().index)
chart.set(title='Distribution of policyholders per Channel')
plt.show()
# Out:
# AGENCY            0.656592
# DEALERSHIP        0.194511
# DIRECT            0.069535
# BANC ASSURANCE    0.040608
# BROKERS           0.024662
# WEBSALES          0.009642
# TRAVEL AGENT      0.004079
# OTHERS            0.000371
# Name: CHANNEL, dtype: float64

# %%
sum_bt_high=df_high.groupby(['CHANNEL'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_high
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 SUM_INSURED  TOTAL_PREMIUM    OD_PREM   TP_PREM
# CHANNEL
# AGENCY          14233965310      306219779  280697768  25522261
# DEALERSHIP       5032217988      148333795  140666945   7666979
# DIRECT           1625168586       30977091   28274506   2702618
# BANC ASSURANCE    969981747       21847777   20253604   1594182
# BROKERS           631318794       12997603   12042835    954771
# WEBSALES          192192046        3422929    3044617    378316
# TRAVEL AGENT       77208530        1586128    1425855    160275
# OTHERS              6292803         174719     160081     14639

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Scatter plot for sum_insured vs Total premium across all three segments

# %%
fig_dims = (20, 10)
fig = plt.subplots(figsize=fig_dims)
sns.scatterplot(x='TOTAL_PREMIUM', y='SUM_INSURED', hue='CHURN', data=df_low)

# %%
fig_dims = (20, 10)
fig = plt.subplots(figsize=fig_dims)
sns.scatterplot(x='TOTAL_PREMIUM', y='SUM_INSURED', hue='CHURN', data=df_mid)

# %%
fig_dims = (20, 10)
fig = plt.subplots(figsize=fig_dims)
sns.scatterplot(x='TOTAL_PREMIUM', y='SUM_INSURED', hue='CHURN', data=df_high)

# %% [markdown]
# ## Churn Analysis ratio per Channel across the 3 segments

# %%
print('The Churn analysis ratio per channel in low budget segment is :  ')
print ("------------------------------------------------------")
ag_low = pd.crosstab(df_low.CHANNEL, df_low.CHURN, normalize='index').round(4)*100
ag_low.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per channel')

print (ag_low)
# Out:
# The Churn analysis ratio per channel in low budget segment is :
# ------------------------------------------------------
# CHURN               0      1
# CHANNEL
# AGENCY          71.02  28.98
# BANC ASSURANCE  66.35  33.65
# BROKERS         73.95  26.05
# CLOSE CIRCLE    63.92  36.08
# DEALERSHIP      65.84  34.16
# DIRECT          71.15  28.85
# OTHERS          70.90  29.10
# TRAVEL AGENT    73.46  26.54
# WEBSALES        56.71  43.29

# %%
print('The Churn analysis ratio per channel in mid budget segment is :  ')
print ("------------------------------------------------------")
ag_mid = pd.crosstab(df_mid.CHANNEL, df_mid.CHURN, normalize='index').round(4)*100
ag_mid.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per channel')

print (ag_mid)
# Out:
# The Churn analysis ratio per channel in mid budget segment is :
# ------------------------------------------------------
# CHURN               0      1
# CHANNEL
# AGENCY          64.95  35.05
# BANC ASSURANCE  60.92  39.08
# BROKERS         75.20  24.80
# CLOSE CIRCLE    55.95  44.05
# DEALERSHIP      45.06  54.94
# DIRECT          60.75  39.25
# OTHERS          67.65  32.35
# TRAVEL AGENT    69.15  30.85
# WEBSALES        52.48  47.52

# %%
print('The Churn analysis ratio per channel in high budget segment is :  ')
print ("------------------------------------------------------")
ag_high = pd.crosstab(df_high.CHANNEL, df_high.CHURN, normalize='index').round(4)*100
ag_high.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per channel')

print (ag_high)
# Out:
# The Churn analysis ratio per channel in high budget segment is :
# ------------------------------------------------------
# CHURN               0       1
# CHANNEL
# AGENCY          58.29   41.71
# BANC ASSURANCE  56.62   43.38
# BROKERS         72.18   27.82
# DEALERSHIP      35.37   64.63
# DIRECT          46.93   53.07
# OTHERS           0.00  100.00
# TRAVEL AGENT    63.64   36.36
# WEBSALES        44.23   55.77

# %% [markdown]
# ## Churn analysis based on car body type across all 3 segments

# %%
print('The Churn analysis ratio per car body type in Low budget segment is :  ')
print ("------------------------------------------------------")
ag_low = pd.crosstab(df_low.BODY_TYPE, df_low.CHURN, normalize='index').round(4)*100
ag_low.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per car body type')
print (ag_low)
# Out:
# The Churn analysis ratio per car body type in Low budget segment is :
# ------------------------------------------------------
# CHURN              0      1
# BODY_TYPE
# Convertible   100.00   0.00
# Coupe          50.00  50.00
# Hatchback      67.06  32.94
# MUV            67.24  32.76
# Pickup Truck   49.67  50.33
# SUV            65.46  34.54
# Sedan          67.65  32.35
# Van            57.08  42.92

# %%
print('The Churn analysis ratio per car body type mid budget segment is :  ')
print ("------------------------------------------------------")
ag_mid = pd.crosstab(df_mid.BODY_TYPE, df_mid.CHURN, normalize='index').round(4)*100
ag_mid.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per car body type')
print (ag_mid)
# Out:
# The Churn analysis ratio per car body type mid budget segment is :
# ------------------------------------------------------
# CHURN             0      1
# BODY_TYPE
# Convertible   66.67  33.33
# Coupe         66.67  33.33
# Hatchback     58.74  41.26
# MUV           60.01  39.99
# Pickup Truck  60.00  40.00
# SUV           55.48  44.52
# Sedan         60.82  39.18
# Van           61.29  38.71

# %%
print('The Churn analysis ratio per car body type high budget segment is :  ')
print ("------------------------------------------------------")
ag_high = pd.crosstab(df_high.BODY_TYPE, df_high.CHURN, normalize='index').round(4)*100
ag_high.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per car body type')
print (ag_high)
# Out:
# The Churn analysis ratio per car body type high budget segment is :
# ------------------------------------------------------
# CHURN            0      1
# BODY_TYPE
# Convertible  57.89  42.11
# Coupe        46.34  53.66
# Hatchback    54.17  45.83
# MUV          77.78  22.22
# SUV          50.08  49.92
# Sedan        55.89  44.11
# Van          33.33  66.67

# %% [markdown]
# ## Churn ratio per Zone across all 3 segments

# %%
print('The Churn analysis ratio per zone for low budget segment is :  ')
print ("------------------------------------------------------")
ag_low = pd.crosstab(df_low.ZONE, df_low.CHURN, normalize='index').round(4)*100
ag_low.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per zone')
print (ag_low)
# Out:
# The Churn analysis ratio per zone for low budget segment is :
# ------------------------------------------------------
# CHURN              0      1
# ZONE
# Central        64.16  35.84
# Eastern        71.77  28.23
# North Eastern  60.06  39.94
# Northern       63.15  36.85
# Southern       68.02  31.98
# Western        65.19  34.81

# %%
print('The Churn analysis ratio per zone for mid budget segment is :  ')
print ("------------------------------------------------------")
ag_mid = pd.crosstab(df_mid.ZONE, df_mid.CHURN, normalize='index').round(4)*100
ag_mid.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per zone')
print (ag_mid)
# Out:
# The Churn analysis ratio per zone for mid budget segment is :
# ------------------------------------------------------
# CHURN              0      1
# ZONE
# Central        59.13  40.87
# Eastern        57.04  42.96
# North Eastern  63.58  36.42
# Northern       56.99  43.01
# Southern       60.21  39.79
# Western        59.94  40.06

# %%
print('The Churn analysis ratio per zone for high budget segment is :  ')
print ("------------------------------------------------------")
ag_high = pd.crosstab(df_high.ZONE, df_high.CHURN, normalize='index').round(4)*100
ag_high.plot(kind='bar',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5),ncol=2)
plt.suptitle('Churn analysis per zone')
print (ag_high)
# Out:
# The Churn analysis ratio per zone for high budget segment is :
# ------------------------------------------------------
# CHURN              0      1
# ZONE
# Central        49.68  50.32
# Eastern        44.75  55.25
# North Eastern  80.95  19.05
# Northern       54.73  45.27
# Southern       49.49  50.51
# Western        55.58  44.42

# %% [markdown]
# ## Churn Analysis ratio per state across the 3 segments

# %%
print('The Churn analysis ratio per state for low budget Segment is :  ')
print ("------------------------------------------------------")
ag_low = pd.crosstab(df_low.STATE, df_low.CHURN, normalize='index').round(4)*100
ag_low.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),ncol=2)
plt.suptitle('Churn analysis per state')
print (ag_low)
# Out:
# The Churn analysis ratio per state for low budget Segment is :
# ------------------------------------------------------
# CHURN                            0      1
# STATE
# Andaman and Nicobar Islands  68.63  31.37
# Andhra Pradesh               80.14  19.86
# Assam                        60.06  39.94
# Bihar                        58.49  41.51
# Chandigarh                   64.92  35.08
# Chhattisgarh                 43.57  56.43
# Delhi                        65.49  34.51
# Goa                          74.90  25.10
# Gujarat                      61.97  38.03
# Haryana                      69.59  30.41
# Himachal Pradesh             67.19  32.81
# Jammu &  Kashmir             37.04  62.96
# Jharkhand                    65.24  34.76
# Karnataka                    72.83  27.17
# Kerala                       13.52  86.48
# Madhya Pradesh               68.92  31.08
# Maharashtra                  68.92  31.08
# Odisha                       58.08  41.92
# ...

# %%
sum_bt_low=df_low.groupby(['STATE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_low
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                              SUM_INSURED  TOTAL_PREMIUM    OD_PREM    TP_PREM
# STATE
# Gujarat                      33573625253     1183090764  775859770  407248204
# Maharashtra                  22478929192      735052409  460522703  274536411
# Delhi                        20380148005      656559362  435838535  220719759
# West Bengal                  13430207427      418797120  258909136  159892711
# Telangana                    11445799651      366132404  236288010  129847025
# Karnataka                    10580446426      349704747  226147310  123558394
# Madhya Pradesh                6293063438      209747832  137958648   71790844
# Andhra Pradesh                4880565675      156733522  101093515   55642384
# ...

# %%
print('The Churn analysis ratio per state for mid budget Segment is :  ')
print ("------------------------------------------------------")
ag_mid = pd.crosstab(df_mid.STATE, df_mid.CHURN, normalize='index').round(4)*100
ag_mid.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),ncol=2)
plt.suptitle('Churn analysis per state')
print (ag_mid)
# Out:
# The Churn analysis ratio per state for mid budget Segment is :
# ------------------------------------------------------
# CHURN                             0      1
# STATE
# Andaman and Nicobar Islands   68.94  31.06
# Andhra Pradesh                67.42  32.58
# Assam                         63.58  36.42
# Bihar                         45.45  54.55
# Chandigarh                    61.03  38.97
# Chhattisgarh                  39.22  60.78
# Delhi                         56.92  43.08
# Goa                           73.79  26.21
# Gujarat                       54.79  45.21
# Haryana                       66.87  33.13
# Himachal Pradesh             100.00   0.00
# Jammu &  Kashmir              44.81  55.19
# Jharkhand                     40.39  59.61
# Karnataka                     57.92  42.08
# Kerala                        26.89  73.11
# Madhya Pradesh                62.57  37.43
# Maharashtra                   64.05  35.95
# Odisha                        50.62  49.38
# ...

# %%
sum_bt_mid=df_mid.groupby(['STATE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_mid
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                              SUM_INSURED  TOTAL_PREMIUM    OD_PREM    TP_PREM
# STATE
# Maharashtra                  23682656348      640362983  501843307  138522113
# Gujarat                      20963737102      623342556  510012409  113336130
# Delhi                        14614667826      379135041  297475462   81658011
# Karnataka                    11102704370      298333159  238471944   59859080
# Telangana                     7519318735      212135577  179312864   32820784
# West Bengal                   5706628940      153374582  121793246   31580615
# Madhya Pradesh                4705155960      138524059  115367936   23156882
# Andhra Pradesh                3458501535      100473314   83948136   16525953
# ...

# %%
print('The Churn analysis ratio per state for high budget Segment is :  ')
print ("------------------------------------------------------")
ag_high = pd.crosstab(df_high.STATE, df_high.CHURN, normalize='index').round(4)*100
ag_high.plot(kind='barh',stacked=True)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),ncol=2)
plt.suptitle('Churn analysis per state')
print (ag_high)
# Out:
# The Churn analysis ratio per state for high budget Segment is :
# ------------------------------------------------------
# CHURN                            0       1
# STATE
# Andaman and Nicobar Islands   0.00  100.00
# Andhra Pradesh               56.41   43.59
# Assam                        80.95   19.05
# Bihar                        83.33   16.67
# Chandigarh                   75.00   25.00
# Chhattisgarh                 30.23   69.77
# Delhi                        54.35   45.65
# Goa                          67.65   32.35
# Gujarat                      54.82   45.18
# Haryana                      57.26   42.74
# Jammu &  Kashmir             25.00   75.00
# Jharkhand                    46.00   54.00
# Karnataka                    56.69   43.31
# Kerala                       40.98   59.02
# Madhya Pradesh               45.06   54.94
# Maharashtra                  55.28   44.72
# Odisha                       29.67   70.33
# Puducherry                    0.00  100.00
# ...

# %%
sum_bt_high=df_high.groupby(['STATE'])['SUM_INSURED','TOTAL_PREMIUM','OD_PREM','TP_PREM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_high
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                              SUM_INSURED  TOTAL_PREMIUM    OD_PREM   TP_PREM
# STATE
# Maharashtra                   7989054350      171528360  157747135  13781438
# Delhi                         4444137108       95490254   87996913   7493374
# Karnataka                     2151381179       46037518   42218889   3818608
# Gujarat                       1289868382       34274329   31850332   2424100
# West Bengal                   1089837583       33323725   31851623   1472132
# Telangana                      888664534       23844017   22601423   1242604
# Tamil Nadu                     915733358       22992209   21358360   1633865
# Madhya Pradesh                 698986274       19143301   17943770   1199553
# ...

# %% [markdown]
# ## Study based on Vehicle Make

# %%
sum_bt_low=df_low.groupby(['VEHICLE_MAKE'])['SUM_INSURED','TOTAL_PREMIUM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_low.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                       SUM_INSURED  TOTAL_PREMIUM
# VEHICLE_MAKE
# MARUTI               116262725025     3843333071
# HYUNDAI               15678452696      504766128
# TOYOTA                 3821492142      132856639
# HONDA                  4526058571      124547347
# MAHINDRA & MAHINDRA    2727074087      101683753
# TATA                   2126107032       77698088
# FORD                   1878315563       62010036
# CHEVROLET              1718347756       57003471
# VOLKSWAGEN             1625336859       54719519
# SKODA                   709219175       24184587

# %%
sum_bt_mid=df_mid.groupby(['VEHICLE_MAKE'])['SUM_INSURED','TOTAL_PREMIUM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_mid.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      SUM_INSURED  TOTAL_PREMIUM
# VEHICLE_MAKE
# MARUTI               44073075175     1248879265
# HYUNDAI              12423997184      383174020
# TOYOTA               12462187703      347730968
# MAHINDRA & MAHINDRA  11391636273      338072474
# HONDA                 6990621152      178288836
# VOLKSWAGEN            3464924333      106695619
# SKODA                 3635208582      101073288
# FORD                  2916018335       80916408
# RENAULT               2828848567       68540515
# MERCEDES-BENZ         3139681951       64630383

# %%
sum_bt_high=df_high.groupby(['VEHICLE_MAKE'])['SUM_INSURED','TOTAL_PREMIUM'].sum().sort_values('TOTAL_PREMIUM',ascending=False)
sum_bt_high.head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                SUM_INSURED  TOTAL_PREMIUM
# VEHICLE_MAKE
# MERCEDES-BENZ   6468689084      138378105
# AUDI            4957184143      118689195
# BMW             3944642620       86656639
# ROVER           2171543025       52226693
# JAGUAR          1460598557       34164139
# PORSCHE         1089002232       30310867
# TOYOTA           748487915       17087832
# VOLVO            617383854       15934662
# FORD             300176822       10140449
# HYUNDAI          160703153        4721889

# %% [markdown]
# ## Study wrt Agency and Vehicle make across all three segments

# %%
Agency_vehiclemake_low=(pd.crosstab(df_low['CHANNEL'],df_low['VEHICLE_MAKE'],margins=True,normalize=True)*100).T
Agency_vehiclemake_low
# Out:
# CHANNEL                 AGENCY  BANC ASSURANCE   BROKERS  CLOSE CIRCLE  \
# VEHICLE_MAKE
# AUSTIN                0.000164        0.000000  0.000000      0.000000
# BUICK                 0.000164        0.000000  0.000000      0.000000
# CHEVROLET             0.781207        0.052342  0.021264      0.000000
# DAEWOO                0.006379        0.000654  0.000000      0.000000
# DATSUN                0.035985        0.005561  0.000327      0.000000
# EICHER POLARIS        0.000491        0.000654  0.000000      0.000000
# FIAT                  0.130201        0.012431  0.002454      0.000000
# FORCE                 0.005398        0.000000  0.000491      0.000000
# FORD                  0.540596        0.048253  0.011286      0.000000
# GENERAL MOTORS        0.016520        0.000654  0.000818      0.000000
# HINDUSTAN MOTORS      0.027480        0.003108  0.000327      0.000000
# HONDA                 1.638963        0.066736  0.035985      0.066082
# ...

# %%
Agency_vehiclemake_mid=(pd.crosstab(df_mid['CHANNEL'],df_mid['VEHICLE_MAKE'],margins=True,normalize=True)*100).T
Agency_vehiclemake_mid
# Out:
# CHANNEL                 AGENCY  BANC ASSURANCE   BROKERS  CLOSE CIRCLE  \
# VEHICLE_MAKE
# ASHOK LEYLAND         0.001392        0.000000  0.000000      0.000000
# AUDI                  0.731746        0.030634  0.024368      0.000000
# BMW                   0.777002        0.025065  0.017406      0.000000
# CHEVROLET             0.531230        0.045255  0.020887      0.000000
# FIAT                  0.116272        0.015317  0.000000      0.000000
# FORCE                 0.019495        0.001392  0.001392      0.000000
# FORD                  1.686985        0.147603  0.025065      0.000000
# HONDA                 4.968356        0.302864  0.154565      0.169186
# HUMMER                0.002089        0.000000  0.000000      0.000000
# HYUNDAI               7.087705        0.474834  0.103043      0.000000
# ISUZU                 0.010444        0.003481  0.001392      0.000000
# JAGUAR                0.004177        0.000000  0.000000      0.000000
# ...

# %%
Agency_vehiclemake_high=(pd.crosstab(df_high['CHANNEL'],df_high['VEHICLE_MAKE'],margins=True,normalize=True)*100).T
Agency_vehiclemake_mid
# Out:
# CHANNEL                 AGENCY  BANC ASSURANCE   BROKERS  CLOSE CIRCLE  \
# VEHICLE_MAKE
# ASHOK LEYLAND         0.001392        0.000000  0.000000      0.000000
# AUDI                  0.731746        0.030634  0.024368      0.000000
# BMW                   0.777002        0.025065  0.017406      0.000000
# CHEVROLET             0.531230        0.045255  0.020887      0.000000
# FIAT                  0.116272        0.015317  0.000000      0.000000
# FORCE                 0.019495        0.001392  0.001392      0.000000
# FORD                  1.686985        0.147603  0.025065      0.000000
# HONDA                 4.968356        0.302864  0.154565      0.169186
# HUMMER                0.002089        0.000000  0.000000      0.000000
# HYUNDAI               7.087705        0.474834  0.103043      0.000000
# ISUZU                 0.010444        0.003481  0.001392      0.000000
# JAGUAR                0.004177        0.000000  0.000000      0.000000
# ...

# %% [markdown]
# ## Correlation Matrix across all three segments

# %%
corr_low=df_low.corr()
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sns.heatmap(corr_low,vmin = -1, vmax = 1, cmap = 'plasma', annot = True, mask=np.triu(corr_low), linewidths=0.5, ax=ax)

# %%
corr_mid=df_mid.corr()
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sns.heatmap(corr_mid,vmin = -1, vmax = 1, cmap = 'plasma', annot = True, mask=np.triu(corr_mid), linewidths=0.5, ax=ax)

# %%
corr_high=df_high.corr()
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
sns.heatmap(corr_high,vmin = -1, vmax = 1, cmap = 'plasma', annot = True, mask=np.triu(corr_high), linewidths=0.5, ax=ax)

# %% [markdown]
# # Models

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import variation 
# %matplotlib inline
from sklearn.model_selection import GridSearchCV
from matplotlib import pyplot
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import  LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score,roc_auc_score,roc_curve
from sklearn import metrics
import pickle

# %%
from google.colab import drive
drive.mount("/drive")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
df_low = pd.read_csv("/drive/My Drive/capstone/12-oct-2021/Low_budget_Stratified.csv")
df_mid = pd.read_csv("/drive/My Drive/capstone/12-oct-2021/Mid_budget.csv")
df_high = pd.read_csv("/drive/My Drive/capstone/12-oct-2021/High_budget.csv")

# %%
## Function to create confusion matrix
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth  
    
    '''
    y_predict = model.predict(X_test)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
##  Function to calculate different metric scores of the model - Accuracy, Recall and Precision
def get_metrics_score(model,flag=True):
    '''
    model : classifier to predict values of X

    '''
    # defining an empty list to store train and test results
    score_list=[] 
    
    pred_train = model.predict(X_train)
    pred_test = model.predict(X_test)
    
    train_acc = model.score(X_train,Y_train)
    test_acc = model.score(X_test,Y_test)
    
    train_recall = metrics.recall_score(Y_train,pred_train)
    test_recall = metrics.recall_score(Y_test,pred_test)
    
    train_precision = metrics.precision_score(Y_train,pred_train)
    test_precision = metrics.precision_score(Y_test,pred_test)
    
    score_list.extend((train_acc,test_acc,train_recall,test_recall,train_precision,test_precision))
        
    # If the flag is set to True then only the following print statements will be dispayed. The default value is set to True.
    if flag == True: 
        print("Accuracy on training set : ",model.score(X_train,Y_train))
        print("Accuracy on test set : ",model.score(X_test,Y_test))
        print("Recall on training set : ",metrics.recall_score(Y_train,pred_train))
        print("Recall on test set : ",metrics.recall_score(Y_test,pred_test))
        print("Precision on training set : ",metrics.precision_score(Y_train,pred_train))
        print("Precision on test set : ",metrics.precision_score(Y_test,pred_test))
    
    return score_list # returning the list with train and test scores

# %% [markdown]
# ## Low Budget

# %%
df_low.head()
# Out:
#     index INTERMEDIARY       CHANNEL  ...        STATE      ZONE CHURN
# 0   37332  IMD-1100100  CLOSE CIRCLE  ...      Gujarat   Western     0
# 1  257059  IMD-1103268        AGENCY  ...      Gujarat   Western     0
# 2  351467  IMD-1100127        AGENCY  ...  Maharashtra   Western     0
# 3  154926  IMD-1100121        DIRECT  ...  Maharashtra   Western     0
# 4  221438  IMD-1100100  CLOSE CIRCLE  ...   Tamil Nadu  Southern     0
#
# [5 rows x 23 columns]

# %%
df1=df_low.copy()
df1.drop(['ZONE','BODY_TYPE','CHANNEL','VEH_ORIG'],inplace = True,axis=1)

# %%
#encoding data
for i in df1.columns:#looping through all of the columns or variables
    if df1[i].dtype == 'object': #checking if the data type of the variable is 'object'
        df1[i] = pd.Categorical(df_low[i]).codes #converting the identified variable into Categorical and extracting the ranks

# %%
df1.columns
# Out:
# Index(['index', 'INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE',
#        'VEHICLE_MODEL', 'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM',
#        'POLICY_AGE', 'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET',
#        'CAR_TYPE', 'LOCATION', 'STATE', 'CHURN'],
#       dtype='object')

# %%
df1.head()
# Out:
#     index  INTERMEDIARY  VEH_MANU_YEAR  ...  LOCATION  STATE  CHURN
# 0   37332             0         2014.0  ...        18      8      0
# 1  257059          1969         2002.0  ...       140      8      0
# 2  351467            25         2012.0  ...        99     16      0
# 3  154926            19         2008.0  ...       116     16      0
# 4  221438             0         2012.0  ...        33     21      0
#
# [5 rows x 19 columns]

# %%
df1["BODY_TYPE"] = df_low["BODY_TYPE"]
df1["CHANNEL"] = df_low["CHANNEL"]
df1["ZONE"] = df_low["ZONE"]
df1["VEH_ORIG"] = df_low["VEH_ORIG"]

# %%
df1.columns
# Out:
# Index(['index', 'INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE',
#        'VEHICLE_MODEL', 'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM',
#        'POLICY_AGE', 'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET',
#        'CAR_TYPE', 'LOCATION', 'STATE', 'CHURN', 'BODY_TYPE', 'CHANNEL',
#        'ZONE', 'VEH_ORIG'],
#       dtype='object')

# %%
df1 = df1.reindex(columns=['INTERMEDIARY', 'CHANNEL', 'VEH_MANU_YEAR', 'VEHICLE_MAKE',
       'VEHICLE_MODEL','VEH_ORIG', 'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM',
       'POLICY_AGE', 'NCB', 'VEH_AGE', 'SENIORITY','Ratio_PS','BODY_TYPE','CAR_BUDGET','CAR_TYPE',
       'LOCATION','STATE', 'ZONE','CHURN'])

# %%
df_dummy_low = pd.get_dummies(df1,drop_first=True)

# %%
df_dummy_low.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0             0         2014.0  ...              0             1
# 1          1969         2002.0  ...              0             1
# 2            25         2012.0  ...              0             1
# 3            19         2008.0  ...              0             1
# 4             0         2012.0  ...              1             0
#
# [5 rows x 37 columns]

# %%
df_dummy_low['CHURN'] = df_dummy_low['CHURN'].astype('category')

# %%
df_dummy_low.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59999 entries, 0 to 59998
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   INTERMEDIARY            59999 non-null  int16
#  1   VEH_MANU_YEAR           59999 non-null  float64
#  2   VEHICLE_MAKE            59999 non-null  int8
#  3   VEHICLE_MODEL           59999 non-null  int16
#  4   SUM_INSURED             59999 non-null  int64
#  5   TOTAL_PREMIUM           59999 non-null  int64
#  6   OD_PREM                 59999 non-null  int64
#  7   TP_PREM                 59999 non-null  int64
#  8   POLICY_AGE              59999 non-null  float64
#  9   NCB                     59999 non-null  float64
#  10  VEH_AGE                 59999 non-null  float64
#  11  SENIORITY               59999 non-null  float64
#  12  Ratio_PS                59999 non-null  float64
#  13  CAR_BUDGET              59999 non-null  int8
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %% [markdown]
# ### Logistic Regression

# %%
X = df_dummy_low.drop('CHURN',axis=1)
Y = df_dummy_low["CHURN"]

# %%
df_dummy_low.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN', 'CHANNEL_BANC ASSURANCE',
#        'CHANNEL_BROKERS', 'CHANNEL_CLOSE CIRCLE', 'CHANNEL_DEALERSHIP',
#        'CHANNEL_DIRECT', 'CHANNEL_OTHERS', 'CHANNEL_TRAVEL AGENT',
#        'CHANNEL_WEBSALES', 'VEH_ORIG_Indian', 'BODY_TYPE_MUV',
#        'BODY_TYPE_Pickup Truck', 'BODY_TYPE_SUV', 'BODY_TYPE_Sedan',
#        'BODY_TYPE_Van', 'ZONE_Eastern', 'ZONE_North Eastern', 'ZONE_Northern',
#        'ZONE_Southern', 'ZONE_Western'],
#       dtype='object')

# %%
num_cols = X.columns[:].to_list()
X.loc[:, num_cols] = ss.fit_transform(X.loc[:, num_cols])
X.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0     -0.413877       0.813398  ...      -0.559595      1.268282
# 1      2.618260      -2.643828  ...      -0.559595      1.268282
# 2     -0.375378       0.237194  ...      -0.559595      1.268282
# 3     -0.384618      -0.915215  ...      -0.559595      1.268282
# 4     -0.413877       0.237194  ...       1.787005     -0.788468
#
# [5 rows x 36 columns]

# %%
import statsmodels.formula.api as SM

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=SM.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.78
# VEH_MANU_YEAR  VIF =  76.83
# VEHICLE_MAKE  VIF =  1.3
# VEHICLE_MODEL  VIF =  1.22
# SUM_INSURED  VIF =  12.68
# TOTAL_PREMIUM  VIF =  47564586.53
# OD_PREM  VIF =  42240958.51
# TP_PREM  VIF =  3552850.82
# POLICY_AGE  VIF =  11.51
# NCB  VIF =  1.49
# VEH_AGE  VIF =  70.99
# SENIORITY  VIF =  9.15
# Ratio_PS  VIF =  4.6
# CAR_BUDGET  VIF =  nan
# CAR_TYPE  VIF =  nan
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.33
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.87
# BODY_TYPE_MUV  VIF =  1.38
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Sedan  VIF =  1.56
# BODY_TYPE_Van  VIF =  1.35
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ...

# %%
X.drop('TOTAL_PREMIUM',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.78
# VEH_MANU_YEAR  VIF =  76.81
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.21
# SUM_INSURED  VIF =  12.68
# OD_PREM  VIF =  10.5
# TP_PREM  VIF =  2.35
# POLICY_AGE  VIF =  11.51
# NCB  VIF =  1.49
# VEH_AGE  VIF =  70.99
# SENIORITY  VIF =  9.15
# Ratio_PS  VIF =  4.6
# CAR_BUDGET  VIF =  nan
# CAR_TYPE  VIF =  nan
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.33
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.87
# BODY_TYPE_MUV  VIF =  1.38
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Sedan  VIF =  1.56
# BODY_TYPE_Van  VIF =  1.35
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.78
# ZONE_Western  VIF =  4.69

# %%
X.drop('CAR_TYPE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.78
# VEH_MANU_YEAR  VIF =  76.81
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.21
# SUM_INSURED  VIF =  12.68
# OD_PREM  VIF =  10.5
# TP_PREM  VIF =  2.35
# POLICY_AGE  VIF =  11.51
# NCB  VIF =  1.49
# VEH_AGE  VIF =  70.99
# SENIORITY  VIF =  9.15
# Ratio_PS  VIF =  4.6
# CAR_BUDGET  VIF =  nan
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.33
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.87
# BODY_TYPE_MUV  VIF =  1.38
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Sedan  VIF =  1.56
# BODY_TYPE_Van  VIF =  1.35
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.78
# ZONE_Western  VIF =  4.69

# %%
X.drop('CAR_BUDGET',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.78
# VEH_MANU_YEAR  VIF =  76.81
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.21
# SUM_INSURED  VIF =  12.68
# OD_PREM  VIF =  10.5
# TP_PREM  VIF =  2.35
# POLICY_AGE  VIF =  11.51
# NCB  VIF =  1.49
# VEH_AGE  VIF =  70.99
# SENIORITY  VIF =  9.15
# Ratio_PS  VIF =  4.6
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.33
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.87
# BODY_TYPE_MUV  VIF =  1.38
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Sedan  VIF =  1.56
# BODY_TYPE_Van  VIF =  1.35
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.78
# ZONE_Western  VIF =  4.69

# %%
X.drop('VEH_MANU_YEAR',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.77
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.2
# SUM_INSURED  VIF =  12.68
# OD_PREM  VIF =  10.3
# TP_PREM  VIF =  2.35
# POLICY_AGE  VIF =  11.42
# NCB  VIF =  1.49
# VEH_AGE  VIF =  6.02
# SENIORITY  VIF =  8.85
# Ratio_PS  VIF =  4.51
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.04
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.86
# BODY_TYPE_MUV  VIF =  1.37
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.56
# BODY_TYPE_Sedan  VIF =  1.54
# BODY_TYPE_Van  VIF =  1.33
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.78
# ZONE_Western  VIF =  4.67

# %%
X.drop('SUM_INSURED',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.77
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.19
# OD_PREM  VIF =  3.15
# TP_PREM  VIF =  2.04
# POLICY_AGE  VIF =  11.4
# NCB  VIF =  1.49
# VEH_AGE  VIF =  6.02
# SENIORITY  VIF =  8.84
# Ratio_PS  VIF =  2.24
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.04
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.3
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.11
# VEH_ORIG_Indian  VIF =  1.86
# BODY_TYPE_MUV  VIF =  1.32
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.55
# BODY_TYPE_Sedan  VIF =  1.45
# BODY_TYPE_Van  VIF =  1.31
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.78
# ZONE_Western  VIF =  4.67

# %%
X.drop('POLICY_AGE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.77
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.17
# OD_PREM  VIF =  3.0
# TP_PREM  VIF =  2.04
# NCB  VIF =  1.49
# VEH_AGE  VIF =  4.24
# SENIORITY  VIF =  1.2
# Ratio_PS  VIF =  2.24
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  3.0
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.29
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.1
# VEH_ORIG_Indian  VIF =  1.86
# BODY_TYPE_MUV  VIF =  1.31
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.55
# BODY_TYPE_Sedan  VIF =  1.43
# BODY_TYPE_Van  VIF =  1.3
# ZONE_Eastern  VIF =  2.92
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.77
# ZONE_Western  VIF =  4.66

# %%
X.drop('OD_PREM',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.77
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.14
# TP_PREM  VIF =  2.04
# NCB  VIF =  1.37
# VEH_AGE  VIF =  2.15
# SENIORITY  VIF =  1.2
# Ratio_PS  VIF =  1.86
# LOCATION  VIF =  1.03
# STATE  VIF =  1.54
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  2.93
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.29
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.1
# VEH_ORIG_Indian  VIF =  1.85
# BODY_TYPE_MUV  VIF =  1.25
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.54
# BODY_TYPE_Sedan  VIF =  1.27
# BODY_TYPE_Van  VIF =  1.29
# ZONE_Eastern  VIF =  2.91
# ZONE_North Eastern  VIF =  1.16
# ZONE_Northern  VIF =  3.41
# ZONE_Southern  VIF =  3.77
# ZONE_Western  VIF =  4.66

# %%
X.drop('ZONE_Western',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.75
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.14
# TP_PREM  VIF =  2.04
# NCB  VIF =  1.37
# VEH_AGE  VIF =  2.15
# SENIORITY  VIF =  1.2
# Ratio_PS  VIF =  1.86
# LOCATION  VIF =  1.03
# STATE  VIF =  1.49
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.02
# CHANNEL_CLOSE CIRCLE  VIF =  2.93
# CHANNEL_DEALERSHIP  VIF =  1.21
# CHANNEL_DIRECT  VIF =  1.29
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.1
# VEH_ORIG_Indian  VIF =  1.85
# BODY_TYPE_MUV  VIF =  1.25
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.54
# BODY_TYPE_Sedan  VIF =  1.27
# BODY_TYPE_Van  VIF =  1.28
# ZONE_Eastern  VIF =  1.57
# ZONE_North Eastern  VIF =  1.04
# ZONE_Northern  VIF =  1.23
# ZONE_Southern  VIF =  1.36

# %%
X.drop('CHANNEL_CLOSE CIRCLE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.21
# VEHICLE_MAKE  VIF =  1.29
# VEHICLE_MODEL  VIF =  1.14
# TP_PREM  VIF =  2.04
# NCB  VIF =  1.37
# VEH_AGE  VIF =  2.08
# SENIORITY  VIF =  1.19
# Ratio_PS  VIF =  1.85
# LOCATION  VIF =  1.03
# STATE  VIF =  1.49
# CHANNEL_BANC ASSURANCE  VIF =  1.03
# CHANNEL_BROKERS  VIF =  1.01
# CHANNEL_DEALERSHIP  VIF =  1.08
# CHANNEL_DIRECT  VIF =  1.09
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.0
# CHANNEL_WEBSALES  VIF =  1.08
# VEH_ORIG_Indian  VIF =  1.62
# BODY_TYPE_MUV  VIF =  1.25
# BODY_TYPE_Pickup Truck  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.52
# BODY_TYPE_Sedan  VIF =  1.27
# BODY_TYPE_Van  VIF =  1.25
# ZONE_Eastern  VIF =  1.57
# ZONE_North Eastern  VIF =  1.04
# ZONE_Northern  VIF =  1.23
# ZONE_Southern  VIF =  1.34

# %%
import statsmodels.api as sm

import random
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595177
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59971
# Method:                           MLE   Df Model:                           27
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06907
# Time:                        12:22:51   Log-Likelihood:                -35710.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.497      0.000      -0.762      -0.725
# INTERMEDIARY              -0.1568      0.011    -14.687      0.000      -0.178      -0.136
# ...

# %%
X.drop('VEH_ORIG_Indian',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595189
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59972
# Method:                           MLE   Df Model:                           26
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06905
# Time:                        12:23:23   Log-Likelihood:                -35711.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.501      0.000      -0.762      -0.726
# INTERMEDIARY              -0.1595      0.010    -15.331      0.000      -0.180      -0.139
# ...

# %%
X.drop('CHANNEL_BANC ASSURANCE',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595190
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59973
# Method:                           MLE   Df Model:                           25
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06905
# Time:                        12:23:33   Log-Likelihood:                -35711.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.501      0.000      -0.762      -0.726
# INTERMEDIARY              -0.1593      0.010    -15.337      0.000      -0.180      -0.139
# ...

# %%
X.drop('CHANNEL_OTHERS',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595192
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59974
# Method:                           MLE   Df Model:                           24
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06904
# Time:                        12:23:42   Log-Likelihood:                -35711.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.500      0.000      -0.762      -0.726
# INTERMEDIARY              -0.1593      0.010    -15.342      0.000      -0.180      -0.139
# ...

# %%
X.drop('CHANNEL_WEBSALES',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595206
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59975
# Method:                           MLE   Df Model:                           23
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06902
# Time:                        12:23:53   Log-Likelihood:                -35712.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.500      0.000      -0.762      -0.725
# INTERMEDIARY              -0.1598      0.010    -15.392      0.000      -0.180      -0.139
# ...

# %%
X.drop('CHANNEL_BROKERS',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595215
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59976
# Method:                           MLE   Df Model:                           22
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06901
# Time:                        12:24:03   Log-Likelihood:                -35712.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7436      0.009    -80.499      0.000      -0.762      -0.725
# INTERMEDIARY              -0.1597      0.010    -15.385      0.000      -0.180      -0.139
# ...

# %%
X.drop('BODY_TYPE_SUV',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595236
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59977
# Method:                           MLE   Df Model:                           21
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06897
# Time:                        12:24:13   Log-Likelihood:                -35714.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.7435      0.009    -80.497      0.000      -0.762      -0.725
# INTERMEDIARY              -0.1596      0.010    -15.379      0.000      -0.180      -0.139
# ...

# %%
X.drop('BODY_TYPE_Pickup Truck',inplace=True,axis=1)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595260
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                59999
# Model:                          Logit   Df Residuals:                    59978
# Method:                           MLE   Df Model:                           20
# Date:                Fri, 22 Oct 2021   Pseudo R-squ.:                 0.06894
# Time:                        12:24:20   Log-Likelihood:                -35715.
# converged:                       True   LL-Null:                       -38359.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.7435      0.009    -80.496      0.000      -0.762      -0.725
# INTERMEDIARY            -0.1592      0.010    -15.347      0.000      -0.180      -0.139
# ...

# %%
## Collect the coef in a dataframe
lgcoef = pd.DataFrame(lg.params, columns=['coef'])

## Calculate Odds Ratio
lgcoef['Odds_ratio']=np.exp(lgcoef.coef)
lgcoef
# Out:
#                           coef  Odds_ratio
# const                -0.743486    0.475454
# INTERMEDIARY         -0.159224    0.852805
# VEHICLE_MAKE          0.030232    1.030694
# VEHICLE_MODEL        -0.060264    0.941516
# TP_PREM               0.061871    1.063825
# NCB                  -0.469676    0.625205
# VEH_AGE               0.198515    1.219590
# SENIORITY            -0.373319    0.688446
# Ratio_PS             -0.113810    0.892428
# LOCATION             -0.024750    0.975554
# STATE                -0.056985    0.944608
# CHANNEL_DEALERSHIP    0.036872    1.037560
# CHANNEL_DIRECT       -0.058738    0.942954
# CHANNEL_TRAVEL AGENT -0.027038    0.973324
# BODY_TYPE_MUV        -0.045598    0.955426
# BODY_TYPE_Sedan      -0.034585    0.966006
# BODY_TYPE_Van         0.109869    1.116132
# ZONE_Eastern         -0.078206    0.924774
# ZONE_North Eastern    0.017214    1.017363
# ZONE_Northern         0.035616    1.036258
# ZONE_Southern        -0.058305    0.943362

# %%
#Calculate Probability
lgcoef['probability'] = lgcoef['Odds_ratio']/(1+lgcoef['Odds_ratio'])
lgcoef
# Out:
#                           coef  Odds_ratio  probability
# const                -0.743486    0.475454     0.322242
# INTERMEDIARY         -0.159224    0.852805     0.460278
# VEHICLE_MAKE          0.030232    1.030694     0.507557
# VEHICLE_MODEL        -0.060264    0.941516     0.484939
# TP_PREM               0.061871    1.063825     0.515463
# NCB                  -0.469676    0.625205     0.384693
# VEH_AGE               0.198515    1.219590     0.549466
# SENIORITY            -0.373319    0.688446     0.407739
# Ratio_PS             -0.113810    0.892428     0.471578
# LOCATION             -0.024750    0.975554     0.493813
# STATE                -0.056985    0.944608     0.485758
# CHANNEL_DEALERSHIP    0.036872    1.037560     0.509217
# CHANNEL_DIRECT       -0.058738    0.942954     0.485320
# CHANNEL_TRAVEL AGENT -0.027038    0.973324     0.493241
# BODY_TYPE_MUV        -0.045598    0.955426     0.488602
# BODY_TYPE_Sedan      -0.034585    0.966006     0.491355
# ...

# %%
#Calculate p value
lgcoef['pval']=lg.pvalues

#Display rounded to 2 decimal points
pd.options.display.float_format = '{:.2f}'.format
lgcoef
# Out:
#                       coef  Odds_ratio  probability  pval
# const                -0.74        0.48         0.32  0.00
# INTERMEDIARY         -0.16        0.85         0.46  0.00
# VEHICLE_MAKE          0.03        1.03         0.51  0.00
# VEHICLE_MODEL        -0.06        0.94         0.48  0.00
# TP_PREM               0.06        1.06         0.52  0.00
# NCB                  -0.47        0.63         0.38  0.00
# VEH_AGE               0.20        1.22         0.55  0.00
# SENIORITY            -0.37        0.69         0.41  0.00
# Ratio_PS             -0.11        0.89         0.47  0.00
# LOCATION             -0.02        0.98         0.49  0.01
# STATE                -0.06        0.94         0.49  0.00
# CHANNEL_DEALERSHIP    0.04        1.04         0.51  0.00
# CHANNEL_DIRECT       -0.06        0.94         0.49  0.00
# CHANNEL_TRAVEL AGENT -0.03        0.97         0.49  0.01
# BODY_TYPE_MUV        -0.05        0.96         0.49  0.00
# ...

# %%
#Sort by descending order of odds ratio 
lgcoef = lgcoef.sort_values(by="Odds_ratio", ascending=False)

#Filter to display only variables with significant p value
pval_filter = lgcoef['pval']<=0.05
lgcoef[pval_filter]
# Out:
#                       coef  Odds_ratio  probability  pval
# VEH_AGE               0.20        1.22         0.55  0.00
# BODY_TYPE_Van         0.11        1.12         0.53  0.00
# TP_PREM               0.06        1.06         0.52  0.00
# CHANNEL_DEALERSHIP    0.04        1.04         0.51  0.00
# ZONE_Northern         0.04        1.04         0.51  0.00
# VEHICLE_MAKE          0.03        1.03         0.51  0.00
# LOCATION             -0.02        0.98         0.49  0.01
# CHANNEL_TRAVEL AGENT -0.03        0.97         0.49  0.01
# BODY_TYPE_Sedan      -0.03        0.97         0.49  0.00
# BODY_TYPE_MUV        -0.05        0.96         0.49  0.00
# STATE                -0.06        0.94         0.49  0.00
# ZONE_Southern        -0.06        0.94         0.49  0.00
# CHANNEL_DIRECT       -0.06        0.94         0.49  0.00
# VEHICLE_MODEL        -0.06        0.94         0.48  0.00
# ZONE_Eastern         -0.08        0.92         0.48  0.00
# ...

# %% [markdown]
# #### Logistic Regression using SCikitLearn library

# %%
X_lr = df_dummy_low.drop(['CHURN','TOTAL_PREMIUM','CAR_BUDGET','BODY_TYPE_SUV','CHANNEL_BANC ASSURANCE', 'CHANNEL_BROKERS','CHANNEL_WEBSALES','CHANNEL_CLOSE CIRCLE','BODY_TYPE_Pickup Truck','OD_PREM','VEH_MANU_YEAR','SUM_INSURED','POLICY_AGE','CAR_TYPE','CHANNEL_OTHERS','VEH_ORIG_Indian','ZONE_Western'],axis=1)
Y_lr = df_dummy_low['CHURN']

# %%
X_lr.columns
# Out:
# Index(['INTERMEDIARY', 'VEHICLE_MAKE', 'VEHICLE_MODEL', 'TP_PREM', 'NCB',
#        'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'LOCATION', 'STATE',
#        'CHANNEL_DEALERSHIP', 'CHANNEL_DIRECT', 'CHANNEL_TRAVEL AGENT',
#        'BODY_TYPE_MUV', 'BODY_TYPE_Sedan', 'BODY_TYPE_Van', 'ZONE_Eastern',
#        'ZONE_North Eastern', 'ZONE_Northern', 'ZONE_Southern'],
#       dtype='object')

# %%
# splitting data into training and test set for independent attributes. Test Size =30% and stratify on Y to have the good proportion between 0 and 1

# %%
X_train_lr, X_test_lr, Y_train_lr, Y_test_lr= train_test_split(X_lr, Y_lr, test_size=.30, random_state=1,stratify= Y_lr)

# %%
num_cols = X_train_lr.columns[:].to_list()
X_train_lr.loc[:, num_cols] = ss.fit_transform(X_train_lr.loc[:, num_cols])
X_train_lr.head()
# Out:
#        INTERMEDIARY  VEHICLE_MAKE  ...  ZONE_Northern  ZONE_Southern
# 52320         -0.35          0.17  ...          -0.47          -0.56
# 49674         -0.41          0.17  ...          -0.47          -0.56
# 33578         -0.41          0.17  ...           2.13          -0.56
# 37244         -0.41          0.17  ...          -0.47          -0.56
# 28351         -0.41          0.17  ...          -0.47          -0.56
#
# [5 rows x 20 columns]

# %%
num_cols = X_test_lr.columns[:].to_list()
X_test_lr.loc[:, num_cols] = ss.transform(X_test_lr.loc[:, num_cols])
X_test_lr.head()
# Out:
#        INTERMEDIARY  VEHICLE_MAKE  ...  ZONE_Northern  ZONE_Southern
# 1394          -0.39          3.24  ...           2.13          -0.56
# 16228          0.84          0.17  ...          -0.47           1.78
# 1517          -0.40          2.90  ...          -0.47          -0.56
# 34240         -0.30         -0.85  ...          -0.47           1.78
# 56693         -0.41          0.17  ...          -0.47          -0.56
#
# [5 rows x 20 columns]

# %%
lr = LogisticRegression()
lr.fit(X_train_lr, Y_train_lr)

train_pred = lr.predict(X_train_lr)
test_pred = lr.predict(X_test_lr)

print("Acc Train:",metrics.accuracy_score(Y_train_lr, train_pred))
print('Train F1: ', f1_score(Y_train_lr, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test_lr, test_pred))
print('Test F1: ', f1_score(Y_test_lr, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test_lr, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test_lr, test_pred)}')
print('\n')
print(classification_report(Y_test_lr, test_pred))
# Out:
# Acc Train: 0.6882306721588609
# Train F1:  0.34725822532402795
# Acc Test: 0.6855
# Test F1:  0.33828170660432494
# Area Under Curve: 0.575763595072699
# Confusion Matrix:
# [[10892  1034]
#  [ 4627  1447]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.91      0.79     11926
#            1       0.58      0.24      0.34      6074
#
#     accuracy                           0.69     18000
#    macro avg       0.64      0.58      0.57     18000
# weighted avg       0.66      0.69      0.64     18000

# %% [markdown]
# ### LDA

# %%
df_dummy_low.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0             0        2014.00  ...              0             1
# 1          1969        2002.00  ...              0             1
# 2            25        2012.00  ...              0             1
# 3            19        2008.00  ...              0             1
# 4             0        2012.00  ...              1             0
#
# [5 rows x 37 columns]

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320         -0.35           0.52  ...          -0.56          1.26
# 49674         -0.41          -0.06  ...          -0.56         -0.79
# 33578         -0.41          -0.63  ...          -0.56         -0.79
# 37244         -0.41          -2.65  ...          -0.56          1.26
# 28351         -0.41           0.81  ...          -0.56          1.26
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394          -0.39          -0.06  ...          -0.56         -0.79
# 16228          0.84          -2.07  ...           1.78         -0.79
# 1517          -0.40           1.10  ...          -0.56         -0.79
# 34240         -0.30          -0.34  ...           1.78         -0.79
# 56693         -0.41           1.10  ...          -0.56          1.26
#
# [5 rows x 33 columns]

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, Y_train)

train_pred = lda.predict(X_train)
test_pred = lda.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6906116812305055
# Train F1:  0.36983511154219206
# Acc Test: 0.6907222222222222
# Test F1:  0.36860610184870135
# Area Under Curve: 0.5868944955311348
# Confusion Matrix:
# [[10808  1118]
#  [ 4449  1625]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80     11926
#            1       0.59      0.27      0.37      6074
#
#     accuracy                           0.69     18000
#    macro avg       0.65      0.59      0.58     18000
# weighted avg       0.67      0.69      0.65     18000

# %% [markdown]
# ### Decision Tree

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
# Create Decision Tree classifer object
dt_model = DecisionTreeClassifier(criterion = 'gini' )
# Train Decision Tree Classifier
dt_model.fit(X_train, Y_train)

#Predict the response for test dataset
train_pred = dt_model.predict(X_train)
test_pred = dt_model.predict(X_test)
print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9927617324222006
# Train F1:  0.9891891891891891
# Acc Test: 0.6333888888888889
# Test F1:  0.45940853608585236
# Area Under Curve: 0.5912508791592717
# Confusion Matrix:
# [[8597 3329]
#  [3270 2804]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72     11926
#            1       0.46      0.46      0.46      6074
#
#     accuracy                           0.63     18000
#    macro avg       0.59      0.59      0.59     18000
# weighted avg       0.63      0.63      0.63     18000

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [5, 7, 9, 10],
    'min_samples_leaf': [10, 15, 20],
    'min_samples_split': [45, 60, 100]
}

dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dt_model, param_grid = param_grid, cv = 5)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
grid_search.best_params_
# Out:
# {'max_depth': 9, 'min_samples_leaf': 20, 'min_samples_split': 60}

# %%
best_grid = grid_search.best_estimator_

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7180170956451344
# Train F1:  0.4982842618089388
# Acc Test: 0.6971666666666667
# Test F1:  0.4613104061666172
# Area Under Curve: 0.620396365337317
# Confusion Matrix:
# [[10215  1711]
#  [ 3740  2334]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79     11926
#            1       0.58      0.38      0.46      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.65      0.62      0.63     18000
# weighted avg       0.68      0.70      0.68     18000

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [10, 11, 13, 15],
    'min_samples_leaf': [20, 25, 30],
    'min_samples_split': [55, 60,65]
}

dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dt_model, param_grid = param_grid, cv = 5)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=13, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=25, min_samples_split=65,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7361365746803495
# Train F1:  0.5094723796033994
# Acc Test: 0.696
# Test F1:  0.43506091265744373
# Area Under Curve: 0.6103467541663329
# Confusion Matrix:
# [[10421  1505]
#  [ 3967  2107]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79     11926
#            1       0.58      0.35      0.44      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.65      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [10,11,12],
    'min_samples_leaf': [19, 20, 21],
    'min_samples_split': [52, 55,57]
}

dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dt_model, param_grid = param_grid, cv = 5)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=11, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=57,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7298507107312079
# Train F1:  0.4836155106499182
# Acc Test: 0.6960555555555555
# Test F1:  0.4217313180424902
# Area Under Curve: 0.6058646777507505
# Confusion Matrix:
# [[10534  1392]
#  [ 4079  1995]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79     11926
#            1       0.59      0.33      0.42      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.65      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [11],
    'min_samples_leaf': [20],
    'min_samples_split': [56,57,58]
}

dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(estimator = dt_model, param_grid = param_grid, cv = 5)

# %%
grid_search.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
#                                               random_state=None,
#                                               splitter='best'),
#              iid='deprecated', n_jobs=None,
# ...

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=11, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=58,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7297554703683421
# Train F1:  0.48385629831741694
# Acc Test: 0.6962222222222222
# Test F1:  0.42223161453930685
# Area Under Curve: 0.6061116319818995
# Confusion Matrix:
# [[10534  1392]
#  [ 4076  1998]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79     11926
#            1       0.59      0.33      0.42      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.66      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
pd.Series(best_grid.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                      0.31
# SENIORITY                0.14
# STATE                    0.11
# INTERMEDIARY             0.08
# LOCATION                 0.08
# Ratio_PS                 0.06
# OD_PREM                  0.05
# TP_PREM                  0.03
# ZONE_Southern            0.03
# SUM_INSURED              0.03
# VEH_MANU_YEAR            0.02
# VEHICLE_MODEL            0.02
# VEH_AGE                  0.01
# CHANNEL_CLOSE CIRCLE     0.01
# POLICY_AGE               0.01
# VEH_ORIG_Indian          0.00
# BODY_TYPE_Van            0.00
# ZONE_Western             0.00
# CHANNEL_DEALERSHIP       0.00
# ZONE_Northern            0.00
# ZONE_Eastern             0.00
# VEHICLE_MAKE             0.00
# ZONE_North Eastern       0.00
# BODY_TYPE_Sedan          0.00
# CHANNEL_DIRECT           0.00
# BODY_TYPE_SUV            0.00
# BODY_TYPE_MUV            0.00
# CHANNEL_WEBSALES         0.00
# CHANNEL_TRAVEL AGENT     0.00
# CHANNEL_BANC ASSURANCE   0.00
# CHANNEL_BROKERS          0.00
# ...

# %% [markdown]
# ### ANN

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
ANN_model = MLPClassifier(hidden_layer_sizes=(100,100)
                     ,max_iter=100
                     ,solver='adam'
                     ,activation='relu'
                     ,random_state=1
                     ,verbose=True
                     ,tol=0.0001)

# %%
ANN_model.fit(X_train,Y_train)

train_pred = ANN_model.predict(X_train)
test_pred = ANN_model.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Iteration 1, loss = inf
# Iteration 2, loss = inf
# Iteration 3, loss = inf
# Iteration 4, loss = inf
# Iteration 5, loss = inf
# Iteration 6, loss = inf
# Iteration 7, loss = inf
# Iteration 8, loss = inf
# Iteration 9, loss = inf
# Iteration 10, loss = inf
# Iteration 11, loss = inf
# Iteration 12, loss = inf
# Iteration 13, loss = inf
# Iteration 14, loss = inf
# Iteration 15, loss = inf
# Iteration 16, loss = inf
# Iteration 17, loss = inf
# Iteration 18, loss = inf
# Iteration 19, loss = inf
# Iteration 20, loss = inf
# Iteration 21, loss = inf
# Iteration 22, loss = inf
# Iteration 23, loss = inf
# Iteration 24, loss = inf
# Iteration 25, loss = inf
# Iteration 26, loss = inf
# Iteration 27, loss = inf
# Iteration 28, loss = inf
# Iteration 29, loss = inf
# Iteration 30, loss = inf
# Iteration 31, loss = inf
# Iteration 32, loss = inf
# Iteration 33, loss = inf
# Iteration 34, loss = inf
# Iteration 35, loss = inf
# Iteration 36, loss = inf
# Iteration 37, loss = inf
# ...

# %% [markdown]
# ### Random Forest

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, Y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9927379223314841
# Train F1:  0.9892184241224503
# Acc Test: 0.7077222222222223
# Test F1:  0.4668085537650756
# Area Under Curve: 0.6271099753495806
# Confusion Matrix:
# [[10436  1490]
#  [ 3771  2303]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80     11926
#            1       0.61      0.38      0.47      6074
#
#     accuracy                           0.71     18000
#    macro avg       0.67      0.63      0.63     18000
# weighted avg       0.69      0.71      0.69     18000

# %%
params = {'n_estimators': [70,90,100],
          'min_samples_split':[5,7,10],
          'min_samples_leaf':[10,15,20],
          'max_depth': [5, 8, 10],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed: 13.1min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 10,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=11, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=58,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7297554703683421
# Train F1:  0.48385629831741694
# Acc Test: 0.6962222222222222
# Test F1:  0.42223161453930685
# Area Under Curve: 0.6061116319818995
# Confusion Matrix:
# [[10534  1392]
#  [ 4076  1998]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79     11926
#            1       0.59      0.33      0.42      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.66      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
params = {'n_estimators': [100,120],
          'min_samples_split':[5],
          'min_samples_leaf':[10,11,13],
          'max_depth': [10,15,20],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:  5.4min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 20,
#  'min_samples_leaf': 10,
#  'min_samples_split': 5,
#  'n_estimators': 120}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=11, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=58,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#running the model
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

# %%
#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7297554703683421
# Train F1:  0.48385629831741694
# Acc Test: 0.6962222222222222
# Test F1:  0.42223161453930685
# Area Under Curve: 0.6061116319818995
# Confusion Matrix:
# [[10534  1392]
#  [ 4076  1998]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79     11926
#            1       0.59      0.33      0.42      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.66      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
params = {'n_estimators': [120,130,300],
          'min_samples_split':[5],
          'min_samples_leaf':[10],
          'max_depth': [20],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:  1.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 20,
#  'min_samples_leaf': 10,
#  'min_samples_split': 5,
#  'n_estimators': 300}

# %%
best_grid = grid_search.best_estimator_
best_grid
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=11, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=20, min_samples_split=58,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
ytrain_predict = best_grid.predict(X_train)
ytest_predict = best_grid.predict(X_test)

#Predict the response for test dataset
print("Acc Train:",metrics.accuracy_score(Y_train, ytrain_predict))
print('Train F1: ', f1_score(Y_train, ytrain_predict))
print("Acc Test:",metrics.accuracy_score(Y_test, ytest_predict ))
print('Test F1: ', f1_score(Y_test, ytest_predict ))
print('Area Under Curve:',roc_auc_score(Y_test, ytest_predict ))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, ytest_predict )}')
print('\n')
print(classification_report(Y_test, ytest_predict ))
# Out:
# Acc Train: 0.7297554703683421
# Train F1:  0.48385629831741694
# Acc Test: 0.6962222222222222
# Test F1:  0.42223161453930685
# Area Under Curve: 0.6061116319818995
# Confusion Matrix:
# [[10534  1392]
#  [ 4076  1998]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79     11926
#            1       0.59      0.33      0.42      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.66      0.61      0.61     18000
# weighted avg       0.68      0.70      0.67     18000

# %%
#Importance of features
pd.Series(best_grid.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                      0.31
# SENIORITY                0.14
# STATE                    0.11
# INTERMEDIARY             0.08
# LOCATION                 0.08
# Ratio_PS                 0.06
# OD_PREM                  0.05
# TP_PREM                  0.03
# ZONE_Southern            0.03
# SUM_INSURED              0.03
# VEH_MANU_YEAR            0.02
# VEHICLE_MODEL            0.02
# VEH_AGE                  0.01
# CHANNEL_CLOSE CIRCLE     0.01
# POLICY_AGE               0.01
# VEH_ORIG_Indian          0.00
# BODY_TYPE_Van            0.00
# ZONE_Western             0.00
# CHANNEL_DEALERSHIP       0.00
# ZONE_Northern            0.00
# ZONE_Eastern             0.00
# VEHICLE_MAKE             0.00
# ZONE_North Eastern       0.00
# BODY_TYPE_Sedan          0.00
# CHANNEL_DIRECT           0.00
# BODY_TYPE_SUV            0.00
# BODY_TYPE_MUV            0.00
# CHANNEL_WEBSALES         0.00
# CHANNEL_TRAVEL AGENT     0.00
# CHANNEL_BANC ASSURANCE   0.00
# CHANNEL_BROKERS          0.00
# ...

# %% [markdown]
# ### Ensemble Bagging Classifier

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320     -0.349980       0.521128  ...      -0.560493      1.264368
# 49674     -0.413134      -0.055274  ...      -0.560493     -0.790909
# 33578     -0.413134      -0.631676  ...      -0.560493     -0.790909
# 37244     -0.411594      -2.649082  ...      -0.560493      1.264368
# 28351     -0.413134       0.809328  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394      -0.393109      -0.055274  ...      -0.560493     -0.790909
# 16228      0.842252      -2.072680  ...       1.784143     -0.790909
# 1517      -0.403892       1.097529  ...      -0.560493     -0.790909
# 34240     -0.297608      -0.343475  ...       1.784143     -0.790909
# 56693     -0.413134       1.097529  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
from sklearn.ensemble import BaggingClassifier
be = DecisionTreeClassifier()
bgcl = BaggingClassifier(base_estimator=be,n_estimators=100,random_state=1)


bgcl = bgcl.fit(X_train, Y_train)

abc_score=get_metrics_score(bgcl)

train_pred = bgcl.predict(X_train)
test_pred = bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.9927379223314841
# Accuracy on test set :  0.7035
# Recall on training set :  0.9868764552317787
# Recall on test set :  0.3934804082976622
# Precision on training set :  0.9915638735289948
# Precision on test set :  0.5911451892159287
# Train F1:  0.9892146115492061
# Test F1:  0.4724720767025798
#
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.79     11926
#            1       0.59      0.39      0.47      6074
#
#     accuracy                           0.70     18000
#    macro avg       0.66      0.63      0.63     18000
# weighted avg       0.69      0.70      0.69     18000

# %%
params = {'base_estimator__min_samples_split':[5,7,10],
          'base_estimator__min_samples_leaf':[10, 15, 20],
          'base_estimator__max_depth': [5, 10],
          }

# %%
bgcl = BaggingClassifier(base_estimator=be,random_state=1)
grid_bgcl = GridSearchCV(bgcl, param_grid = params, cv = 5, scoring='accuracy',n_jobs=-1)
grid_bgcl.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                                class_weight=None,
#                                                                                criterion='gini',
#                                                                                max_depth=None,
#                                                                                max_features=None,
#                                                                                max_leaf_nodes=None,
#                                                                                min_impurity_decrease=0.0,
#                                                                                min_impurity_split=None,
#                                                                                min_samples_leaf=1,
# ...

# %%
grid_bgcl.best_params_
# Out:
# {'base_estimator__max_depth': 10,
#  'base_estimator__min_samples_leaf': 15,
#  'base_estimator__min_samples_split': 5}

# %%
grid_bgcl.best_score_
# Out:
# 0.711969477658905

# %%
abc_score=get_metrics_score(grid_bgcl)

train_pred = grid_bgcl.predict(X_train)
test_pred = grid_bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7431367413509845
# Accuracy on test set :  0.7141111111111111
# Recall on training set :  0.3987158682000988
# Recall on test set :  0.35281527823510045
# Precision on training set :  0.713780472401162
# Precision on test set :  0.6381774865991662
# Train F1:  0.5116342236306021
# Test F1:  0.4544105173876166
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.90      0.81     11926
#            1       0.64      0.35      0.45      6074
#
#     accuracy                           0.71     18000
#    macro avg       0.68      0.63      0.63     18000
# weighted avg       0.70      0.71      0.69     18000

# %%
params = {'base_estimator__min_samples_split':[3,5,10,15],
          'base_estimator__min_samples_leaf':[5,12, 15, 17, 20],
          'base_estimator__max_depth': [10,15,20],
          }

# %%
grid_bgcl = GridSearchCV(bgcl, param_grid = params, cv = 5, scoring='accuracy',n_jobs=-1)
grid_bgcl.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                                class_weight=None,
#                                                                                criterion='gini',
#                                                                                max_depth=None,
#                                                                                max_features=None,
#                                                                                max_leaf_nodes=None,
#                                                                                min_impurity_decrease=0.0,
#                                                                                min_impurity_split=None,
#                                                                                min_samples_leaf=1,
# ...

# %%
grid_bgcl.best_params_
# Out:
# {'base_estimator__max_depth': 15,
#  'base_estimator__min_samples_leaf': 17,
#  'base_estimator__min_samples_split': 3}

# %%
grid_bgcl.best_score_
# Out:
# 0.7150885252779526

# %%
abc_score=get_metrics_score(grid_bgcl)

train_pred = grid_bgcl.predict(X_train)
test_pred = grid_bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7677087549703564
# Accuracy on test set :  0.7134444444444444
# Recall on training set :  0.4468355323502434
# Recall on test set :  0.35989463286137635
# Precision on training set :  0.7677294217480907
# Precision on test set :  0.6325231481481481
# Train F1:  0.5648916242975649
# Test F1:  0.4587618048268625
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.81     11926
#            1       0.63      0.36      0.46      6074
#
#     accuracy                           0.71     18000
#    macro avg       0.68      0.63      0.63     18000
# weighted avg       0.70      0.71      0.69     18000

# %% [markdown]
# the accuracy difference between train and test is increasing.

# %% [markdown]
# Training the model with the best parameters

# %%
be = DecisionTreeClassifier(max_depth=10,min_samples_leaf=15,min_samples_split=5)
bgcl = BaggingClassifier(base_estimator=be,n_estimators=100,random_state=1)


bgcl = bgcl.fit(X_train, Y_train)

abc_score=get_metrics_score(bgcl)

train_pred = bgcl.predict(X_train)
test_pred = bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7454225100597633
# Accuracy on test set :  0.7168888888888889
# Recall on training set :  0.39836308473858745
# Recall on test set :  0.35001646361540995
# Precision on training set :  0.7228267827422865
# Precision on test set :  0.6493585827733659
# Train F1:  0.513646288209607
# Test F1:  0.4548566538296962
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.90      0.81     11926
#            1       0.65      0.35      0.45      6074
#
#     accuracy                           0.72     18000
#    macro avg       0.69      0.63      0.63     18000
# weighted avg       0.70      0.72      0.69     18000

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320     -0.349980       0.521128  ...      -0.560493      1.264368
# 49674     -0.413134      -0.055274  ...      -0.560493     -0.790909
# 33578     -0.413134      -0.631676  ...      -0.560493     -0.790909
# 37244     -0.411594      -2.649082  ...      -0.560493      1.264368
# 28351     -0.413134       0.809328  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394      -0.393109      -0.055274  ...      -0.560493     -0.790909
# 16228      0.842252      -2.072680  ...       1.784143     -0.790909
# 1517      -0.403892       1.097529  ...      -0.560493     -0.790909
# 34240     -0.297608      -0.343475  ...       1.784143     -0.790909
# 56693     -0.413134       1.097529  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 100,random_state=1)
gbcl = gbcl.fit(X_train, Y_train)

train_pred = gbcl.predict(X_train)
test_pred = gbcl.predict(X_test)

abc_score=get_metrics_score(gbcl)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7224695826091098
# Accuracy on test set :  0.7205
# Recall on training set :  0.3526423481267198
# Recall on test set :  0.35001646361540995
# Precision on training set :  0.6682711592458885
# Precision on test set :  0.6625116858834528
# Train F1:  0.46166635876593387
# Test F1:  0.458041581385328
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81     11926
#            1       0.66      0.35      0.46      6074
#
#     accuracy                           0.72     18000
#    macro avg       0.70      0.63      0.63     18000
# weighted avg       0.71      0.72      0.69     18000

# %%
#Importance of features
pd.Series(gbcl.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.371763
# SENIORITY                 0.146476
# STATE                     0.121101
# LOCATION                  0.106657
# INTERMEDIARY              0.068577
# CHANNEL_CLOSE CIRCLE      0.038014
# OD_PREM                   0.024506
# POLICY_AGE                0.023214
# TP_PREM                   0.020657
# VEH_MANU_YEAR             0.011169
# ZONE_Southern             0.010642
# BODY_TYPE_Van             0.009602
# SUM_INSURED               0.008959
# Ratio_PS                  0.006965
# VEHICLE_MODEL             0.006650
# ZONE_Western              0.006608
# VEH_AGE                   0.006205
# ZONE_Northern             0.005874
# CHANNEL_DEALERSHIP        0.002537
# VEHICLE_MAKE              0.002425
# BODY_TYPE_Sedan           0.000477
# BODY_TYPE_SUV             0.000422
# CHANNEL_TRAVEL AGENT      0.000237
# CHANNEL_DIRECT            0.000159
# CHANNEL_BANC ASSURANCE    0.000106
# ZONE_Eastern              0.000000
# ZONE_North Eastern        0.000000
# ...

# %%
params = {'n_estimators': [100, 200, 350],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 10],
          "learning_rate":[0.001,0.0005]
          }

# %%
gbcl = GradientBoostingClassifier(n_estimators = 100,random_state=1)
grid_gbcl = GridSearchCV(gbcl, param_grid = params, cv = 5, scoring='accuracy',n_jobs=-1)
grid_gbcl.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GradientBoostingClassifier(ccp_alpha=0.0,
#                                                   criterion='friedman_mse',
#                                                   init=None, learning_rate=0.1,
#                                                   loss='deviance', max_depth=3,
#                                                   max_features=None,
#                                                   max_leaf_nodes=None,
#                                                   min_impurity_decrease=0.0,
#                                                   min_impurity_split=None,
#                                                   min_samples_leaf=1,
#                                                   min_samples_split=2,
#                                                   min_weight_fraction_leaf=0.0,
#                                                   n_estimators=100,
# ...

# %%
grid_gbcl.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 10,
#  'min_samples_leaf': 10,
#  'n_estimators': 350}

# %%
grid_gbcl.best_score_
# Out:
# 0.7088264107405078

# %%
abc_score=get_metrics_score(grid_gbcl)

train_pred = grid_gbcl.predict(X_train)
test_pred = grid_gbcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7531607895426081
# Accuracy on test set :  0.7108888888888889
# Recall on training set :  0.43067804981302477
# Recall on test set :  0.3633519920974646
# Precision on training set :  0.7264936919781004
# Precision on test set :  0.6227426636568849
# Train F1:  0.5407751937984496
# Test F1:  0.4589311707215637
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80     11926
#            1       0.62      0.36      0.46      6074
#
#     accuracy                           0.71     18000
#    macro avg       0.68      0.63      0.63     18000
# weighted avg       0.70      0.71      0.69     18000

# %% [markdown]
# ### Ada boost

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320     -0.349980       0.521128  ...      -0.560493      1.264368
# 49674     -0.413134      -0.055274  ...      -0.560493     -0.790909
# 33578     -0.413134      -0.631676  ...      -0.560493     -0.790909
# 37244     -0.411594      -2.649082  ...      -0.560493      1.264368
# 28351     -0.413134       0.809328  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394      -0.393109      -0.055274  ...      -0.560493     -0.790909
# 16228      0.842252      -2.072680  ...       1.784143     -0.790909
# 1517      -0.403892       1.097529  ...      -0.560493     -0.790909
# 34240     -0.297608      -0.343475  ...       1.784143     -0.790909
# 56693     -0.413134       1.097529  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators= 100, random_state=1, learning_rate=0.1)
ada.fit(X_train, Y_train)

train_pred = ada.predict(X_train)
test_pred = ada.predict(X_test)

abc_score=get_metrics_score(ada)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6900164289625943
# Accuracy on test set :  0.6895
# Recall on training set :  0.24017498059690962
# Recall on test set :  0.2319723411261113
# Precision on training set :  0.6020516448532013
# Precision on test set :  0.6039434204886412
# Train F1:  0.34337015181318403
# Test F1:  0.335196859759724
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.80     11926
#            1       0.60      0.23      0.34      6074
#
#     accuracy                           0.69     18000
#    macro avg       0.65      0.58      0.57     18000
# weighted avg       0.67      0.69      0.64     18000

# %% [markdown]
# ### Extreme Gradient boosting

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320     -0.349980       0.521128  ...      -0.560493      1.264368
# 49674     -0.413134      -0.055274  ...      -0.560493     -0.790909
# 33578     -0.413134      -0.631676  ...      -0.560493     -0.790909
# 37244     -0.411594      -2.649082  ...      -0.560493      1.264368
# 28351     -0.413134       0.809328  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394      -0.393109      -0.055274  ...      -0.560493     -0.790909
# 16228      0.842252      -2.072680  ...       1.784143     -0.790909
# 1517      -0.403892       1.097529  ...      -0.560493     -0.790909
# 34240     -0.297608      -0.343475  ...       1.784143     -0.790909
# 56693     -0.413134       1.097529  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(n_estimators= 100, random_state=1, learning_rate=0.1)
xg.fit(X_train, Y_train)

train_pred = xg.predict(X_train)
test_pred = xg.predict(X_test)

abc_score=get_metrics_score(xg)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7238981880520965
# Accuracy on test set :  0.7203333333333334
# Recall on training set :  0.35800465674169196
# Recall on test set :  0.3531445505432993
# Precision on training set :  0.6701888786157707
# Precision on test set :  0.66
# Train F1:  0.46670345842531274
# Test F1:  0.46010296010296003
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81     11926
#            1       0.66      0.35      0.46      6074
#
#     accuracy                           0.72     18000
#    macro avg       0.70      0.63      0.64     18000
# weighted avg       0.71      0.72      0.69     18000

# %%
#Importance of features
pd.Series(xg.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.196617
# POLICY_AGE                0.138444
# SENIORITY                 0.100578
# STATE                     0.065878
# CHANNEL_CLOSE CIRCLE      0.063023
# INTERMEDIARY              0.053774
# ZONE_Northern             0.047539
# ZONE_Southern             0.045170
# LOCATION                  0.040363
# BODY_TYPE_Van             0.029178
# ZONE_Western              0.027287
# VEH_MANU_YEAR             0.025234
# VEH_AGE                   0.020011
# OD_PREM                   0.019157
# VEH_ORIG_Indian           0.017529
# TP_PREM                   0.017158
# SUM_INSURED               0.014922
# CHANNEL_DEALERSHIP        0.012512
# VEHICLE_MODEL             0.012385
# BODY_TYPE_SUV             0.011228
# CHANNEL_TRAVEL AGENT      0.009500
# VEHICLE_MAKE              0.009361
# Ratio_PS                  0.009226
# BODY_TYPE_Sedan           0.008127
# CHANNEL_DIRECT            0.005799
# CHANNEL_WEBSALES          0.000000
# BODY_TYPE_Pickup Truck    0.000000
# ...

# %%
params = {'n_estimators': [100, 200, 350],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 10],
          "learning_rate":[0.001,0.0005]
          }

# %%
xg = XGBClassifier(random_state=1)
grid_xg = GridSearchCV(xg, param_grid = params, cv = 5, scoring='accuracy',n_jobs=-1)
grid_xg.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=1, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.0005], 'max_depth': [5, 10],
#                          'min_samples_leaf': [10, 15, 20],
# ...

# %%
grid_xg.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 10,
#  'min_samples_leaf': 10,
#  'n_estimators': 350}

# %%
grid_xg.best_score_
# Out:
# 0.7088264107405078

# %%
abc_score=get_metrics_score(grid_xg)

train_pred = grid_xg.predict(X_train)
test_pred = grid_xg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7531607895426081
# Accuracy on test set :  0.7108888888888889
# Recall on training set :  0.43067804981302477
# Recall on test set :  0.3633519920974646
# Precision on training set :  0.7264936919781004
# Precision on test set :  0.6227426636568849
# Train F1:  0.5407751937984496
# Test F1:  0.4589311707215637
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80     11926
#            1       0.62      0.36      0.46      6074
#
#     accuracy                           0.71     18000
#    macro avg       0.68      0.63      0.63     18000
# weighted avg       0.70      0.71      0.69     18000

# %% [markdown]
# ### light gbm

# %%
X = df_dummy_low.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_low['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 52320     -0.349980       0.521128  ...      -0.560493      1.264368
# 49674     -0.413134      -0.055274  ...      -0.560493     -0.790909
# 33578     -0.413134      -0.631676  ...      -0.560493     -0.790909
# 37244     -0.411594      -2.649082  ...      -0.560493      1.264368
# 28351     -0.413134       0.809328  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 1394      -0.393109      -0.055274  ...      -0.560493     -0.790909
# 16228      0.842252      -2.072680  ...       1.784143     -0.790909
# 1517      -0.403892       1.097529  ...      -0.560493     -0.790909
# 34240     -0.297608      -0.343475  ...       1.784143     -0.790909
# 56693     -0.413134       1.097529  ...      -0.560493      1.264368
#
# [5 rows x 33 columns]

# %%
from lightgbm import LGBMClassifier
lg = LGBMClassifier(n_estimators= 100, random_state=1, learning_rate=0.1)
lg.fit(X_train, Y_train)

train_pred = lg.predict(X_train)
test_pred = lg.predict(X_test)

abc_score=get_metrics_score(lg)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7489940236672302
# Accuracy on test set :  0.7300555555555556
# Recall on training set :  0.40513652719960486
# Recall on test set :  0.3768521567336187
# Precision on training set :  0.7311855341907552
# Precision on test set :  0.6806422836752899
# Train F1:  0.5213838191228549
# Test F1:  0.48511179400233123
#
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82     11926
#            1       0.68      0.38      0.49      6074
#
#     accuracy                           0.73     18000
#    macro avg       0.71      0.64      0.65     18000
# weighted avg       0.72      0.73      0.71     18000

# %%
#Importance of features
pd.Series(lg.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# LOCATION                  429
# OD_PREM                   298
# Ratio_PS                  288
# STATE                     286
# INTERMEDIARY              229
# SUM_INSURED               227
# TP_PREM                   211
# SENIORITY                 173
# NCB                       164
# VEH_MANU_YEAR             133
# VEHICLE_MODEL             133
# POLICY_AGE                 92
# VEHICLE_MAKE               54
# VEH_AGE                    48
# ZONE_Southern              43
# CHANNEL_CLOSE CIRCLE       33
# ZONE_Western               31
# BODY_TYPE_Van              28
# ZONE_Northern              21
# CHANNEL_DEALERSHIP         21
# ZONE_Eastern               13
# VEH_ORIG_Indian            11
# BODY_TYPE_Sedan             9
# CHANNEL_TRAVEL AGENT        7
# BODY_TYPE_SUV               5
# CHANNEL_DIRECT              5
# BODY_TYPE_Pickup Truck      2
# ZONE_North Eastern          2
# CHANNEL_BANC ASSURANCE      2
# CHANNEL_BROKERS             1
# BODY_TYPE_MUV               1
# ...

# %% [markdown]
# MOdel is a right fit. we try to Tune it

# %%
params = {'n_estimators': [200, 300],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 10],
          "learning_rate":[0.001,0.0005]
          }

# %%
lg = LGBMClassifier(random_state=1)
grid_lg = GridSearchCV(lg, param_grid = params, cv = 7, scoring='accuracy',n_jobs=-1)
grid_lg.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=7, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=1, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=-1,
# ...

# %%
grid_lg.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 5,
#  'min_samples_leaf': 10,
#  'n_estimators': 200}

# %%
grid_lg.best_score_
# Out:
# 0.6625395859627398

# %%
abc_score=get_metrics_score(grid_lg)

train_pred = grid_lg.predict(X_train)
test_pred = grid_lg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.662539584275816
# Accuracy on test set :  0.6625555555555556
# Recall on training set :  0.0
# Recall on test set :  0.0
# Precision on training set :  0.0
# Precision on test set :  0.0
# Train F1:  0.0
# Test F1:  0.0
#
#
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.80     11926
#            1       0.00      0.00      0.00      6074
#
#     accuracy                           0.66     18000
#    macro avg       0.33      0.50      0.40     18000
# weighted avg       0.44      0.66      0.53     18000

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# The best performing models considered :
# 1. Light GBM
# 2. XGBoost
# 3. Gradient Boost
# 4. Ensemble Bossting Classifier
# 5. Random Forest Classifier
#
#
# we take the top 10 features and select only the features common across all of them. Then we run the Random Forest model (as it's our recommended model) with these features.

# %% [markdown]
# The Common Features are
# 1. NCB
# 2. SENIORITY
# 3. STATE
# 4. INTERMEDIARY
# 5. LOCATION
# 6. OD_PREM
# 7. TP_PREM

# %%
x_feature = X[['SENIORITY','INTERMEDIARY','NCB','LOCATION','STATE','OD_PREM','TP_PREM']]

# %%
Xf_train, Xf_test, Yf_train, Yf_test= train_test_split(x_feature, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = Xf_train.columns[:].to_list()
Xf_train.loc[:, num_cols] = ss.fit_transform(Xf_train.loc[:, num_cols])
Xf_train.head()
# Out:
#        SENIORITY  INTERMEDIARY       NCB  ...     STATE   OD_PREM   TP_PREM
# 52320  -1.220630     -0.349980 -0.614285  ...  0.431717 -0.155012 -0.180379
# 49674  -0.126235     -0.413134  0.848513  ... -0.172280 -0.985506 -0.466663
# 33578   1.017904     -0.413134  1.141072  ...  0.884715 -1.360768 -0.466663
# 37244  -0.399834     -0.411594  0.848513  ... -0.776277 -0.829714 -0.008201
# 28351  -0.399834     -0.413134 -1.784523  ...  0.431717  1.021124  0.314760
#
# [5 rows x 7 columns]

# %%
num_cols = Xf_test.columns[:].to_list()
Xf_test.loc[:, num_cols] = ss.transform(Xf_test.loc[:, num_cols])
Xf_test.head()
# Out:
#        SENIORITY  INTERMEDIARY       NCB  ...     STATE   OD_PREM   TP_PREM
# 1394    0.420962     -0.393109  0.848513  ... -1.078275 -0.099034 -0.258827
# 16228  -0.297234      0.842252  1.141072  ...  1.337713 -0.766331 -0.258827
# 1517   -0.235675     -0.403892 -0.321726  ...  0.280718  0.833345 -0.237432
# 34240   1.734235     -0.297608  1.141072  ...  1.337713 -1.276948  4.128144
# 56693  -0.235675     -0.413134 -0.614285  ... -0.776277  1.205349 -0.180379
#
# [5 rows x 7 columns]

# %%
rf1 = RandomForestClassifier(random_state=1,max_depth=20,min_samples_leaf= 10,min_samples_split= 5,n_estimators= 300)
rf1.fit(Xf_train, Yf_train)

train_pred = rf1.predict(Xf_train)
test_pred = rf1.predict(Xf_test)

print('Train ACC: ', rf1.score(Xf_train,Yf_train))
print('Test ACC: ', rf1.score(Xf_test,Yf_test))
print('Train F1: ', f1_score(Yf_train, train_pred))
print('Test F1: ', f1_score(Yf_test, test_pred))
print('\n')
print(classification_report(Yf_test, test_pred))
# Out:
# Train ACC:  0.7697088025905379
# Test ACC:  0.7211666666666666
# Train F1:  0.5578716401535929
# Test F1:  0.45875121319961176
#
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81     11926
#            1       0.66      0.35      0.46      6074
#
#     accuracy                           0.72     18000
#    macro avg       0.70      0.63      0.64     18000
# weighted avg       0.71      0.72      0.69     18000

# %% [markdown]
# The Recall, f1-score and accuracy score have improved

# %%
y_predict = rf1.predict(Xf_test)
cm=metrics.confusion_matrix( Yf_test, y_predict, labels=[0, 1])
df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No(0)","Actual - Yes(1)"]],
                  columns = [i for i in ['Predicted - No(0)','Predicted - Yes(1)']])
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=labels,fmt='')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 42.0, 'Predicted label')

# %% [markdown]
# ## Mid Budget

# %%
df_mid.head()
# Out:
#   INTERMEDIARY     CHANNEL  VEH_MANU_YEAR  ...        STATE      ZONE CHURN
# 0  IMD-1100111  DEALERSHIP         2016.0  ...    Rajasthan  Northern     1
# 1  IMD-1102937      AGENCY         2014.0  ...  West Bengal   Eastern     0
# 2  IMD-1100862      AGENCY         2010.0  ...      Gujarat   Western     0
# 3  IMD-1100101      AGENCY         2011.0  ...    Rajasthan  Northern     0
# 4  IMD-1100522      AGENCY         2012.0  ...  Maharashtra   Western     0
#
# [5 rows x 22 columns]

# %%
df1=df_mid.copy()
df1.drop(['ZONE','BODY_TYPE','CHANNEL','VEH_ORIG'],inplace = True,axis=1)

# %%
#encoding data
for i in df1.columns:#looping through all of the columns or variables
    if df1[i].dtype == 'object': #checking if the data type of the variable is 'object'
        df1[i] = pd.Categorical(df_mid[i]).codes #converting the identified variable into Categorical and extracting the ranks

# %%
df1.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN'],
#       dtype='object')

# %%
df1.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  VEHICLE_MAKE  ...  LOCATION  STATE  CHURN
# 0            11         2016.0            30  ...        66     20      1
# 1          2224         2014.0             3  ...        83     24      0
# 2           663         2010.0             3  ...       156      8      0
# 3             1         2011.0            30  ...        71     20      0
# 4           371         2012.0             2  ...        52     16      0
#
# [5 rows x 18 columns]

# %%
df1["BODY_TYPE"] = df_mid["BODY_TYPE"]
df1["CHANNEL"] = df_mid["CHANNEL"]
df1["ZONE"] = df_mid["ZONE"]
df1["VEH_ORIG"] = df_mid["VEH_ORIG"]

# %%
df1.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN', 'BODY_TYPE', 'CHANNEL', 'ZONE',
#        'VEH_ORIG'],
#       dtype='object')

# %%
df1 = df1.reindex(columns=['INTERMEDIARY', 'CHANNEL', 'VEH_MANU_YEAR', 'VEHICLE_MAKE',
       'VEHICLE_MODEL','VEH_ORIG', 'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM',
       'POLICY_AGE', 'NCB', 'VEH_AGE', 'SENIORITY','Ratio_PS','BODY_TYPE','CAR_BUDGET','CAR_TYPE',
       'LOCATION','STATE', 'ZONE','CHURN'])

# %%
df_dummy_mid = pd.get_dummies(df1,drop_first=True)

# %%
df_dummy_mid.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0            11         2016.0  ...              0             0
# 1          2224         2014.0  ...              0             0
# 2           663         2010.0  ...              0             1
# 3             1         2011.0  ...              0             0
# 4           371         2012.0  ...              0             1
#
# [5 rows x 39 columns]

# %%
df_dummy_mid['CHURN'] = df_dummy_mid['CHURN'].astype('category')

# %%
df_dummy_mid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143629 entries, 0 to 143628
# Data columns (total 39 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   INTERMEDIARY            143629 non-null  int16
#  1   VEH_MANU_YEAR           143629 non-null  float64
#  2   VEHICLE_MAKE            143629 non-null  int8
#  3   VEHICLE_MODEL           143629 non-null  int16
#  4   SUM_INSURED             143629 non-null  int64
#  5   TOTAL_PREMIUM           143629 non-null  int64
#  6   OD_PREM                 143629 non-null  int64
#  7   TP_PREM                 143629 non-null  int64
#  8   POLICY_AGE              143629 non-null  float64
#  9   NCB                     143629 non-null  float64
#  10  VEH_AGE                 143629 non-null  float64
#  11  SENIORITY               143629 non-null  float64
#  12  Ratio_PS                143629 non-null  float64
#  13  CAR_BUDGET              143629 non-null  int8
# ...

# %% [markdown]
# Comment : VEH_ORIG deleted. All cars are foreign cars.

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %% [markdown]
# ### Logistic Regression

# %%
X = df_dummy_mid.drop(df_dummy_mid[['CHURN','CAR_BUDGET','TOTAL_PREMIUM']],axis=1)
Y = df_dummy_mid["CHURN"]

# %%
df_dummy_mid.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN', 'CHANNEL_BANC ASSURANCE',
#        'CHANNEL_BROKERS', 'CHANNEL_CLOSE CIRCLE', 'CHANNEL_DEALERSHIP',
#        'CHANNEL_DIRECT', 'CHANNEL_OTHERS', 'CHANNEL_TRAVEL AGENT',
#        'CHANNEL_WEBSALES', 'VEH_ORIG_Indian', 'BODY_TYPE_Coupe',
#        'BODY_TYPE_Hatchback', 'BODY_TYPE_MUV', 'BODY_TYPE_Pickup Truck',
#        'BODY_TYPE_SUV', 'BODY_TYPE_Sedan', 'BODY_TYPE_Van', 'ZONE_Eastern',
#        'ZONE_North Eastern', 'ZONE_Northern', 'ZONE_Southern', 'ZONE_Western'],
#       dtype='object')

# %%
num_cols = X.columns[:].to_list()
X.loc[:, num_cols] = ss.fit_transform(X.loc[:, num_cols])
X.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0     -0.471549       0.796343  ...      -0.563282     -0.832622
# 1      1.818956      -0.097277  ...      -0.563282     -0.832622
# 2      0.203286      -1.884515  ...      -0.563282      1.201026
# 3     -0.481899      -1.437706  ...      -0.563282     -0.832622
# 4     -0.098941      -0.990896  ...      -0.563282      1.201026
#
# [5 rows x 36 columns]

# %%
import statsmodels.formula.api as SM
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=SM.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.48
# VEH_MANU_YEAR  VIF =  16.15
# VEHICLE_MAKE  VIF =  1.19
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  12.42
# OD_PREM  VIF =  13.59
# TP_PREM  VIF =  3.42
# POLICY_AGE  VIF =  7.4
# NCB  VIF =  1.39
# VEH_AGE  VIF =  14.78
# SENIORITY  VIF =  6.33
# Ratio_PS  VIF =  6.56
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1636: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# CAR_TYPE  VIF =  nan
# LOCATION  VIF =  1.04
# STATE  VIF =  1.3
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.55
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.26
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.85
# BODY_TYPE_Coupe  VIF =  9.0
# BODY_TYPE_Hatchback  VIF =  5805.22
# BODY_TYPE_MUV  VIF =  7912.75
# BODY_TYPE_Pickup Truck  VIF =  17.67
# ...

# %% [markdown]
# Car_Type. all are driven regular car. so we can drop the variable

# %%
X.drop('CAR_TYPE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.48
# VEH_MANU_YEAR  VIF =  16.15
# VEHICLE_MAKE  VIF =  1.19
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  12.42
# OD_PREM  VIF =  13.59
# TP_PREM  VIF =  3.42
# POLICY_AGE  VIF =  7.4
# NCB  VIF =  1.39
# VEH_AGE  VIF =  14.78
# SENIORITY  VIF =  6.33
# Ratio_PS  VIF =  6.56
# LOCATION  VIF =  1.04
# STATE  VIF =  1.3
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.55
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.26
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.85
# BODY_TYPE_Coupe  VIF =  9.0
# BODY_TYPE_Hatchback  VIF =  5805.22
# BODY_TYPE_MUV  VIF =  7912.75
# BODY_TYPE_Pickup Truck  VIF =  17.67
# BODY_TYPE_SUV  VIF =  8300.34
# BODY_TYPE_Sedan  VIF =  11715.95
# BODY_TYPE_Van  VIF =  11.34
# ZONE_Eastern  VIF =  2.41
# ZONE_North Eastern  VIF =  1.15
# ZONE_Northern  VIF =  3.24
# ...

# %%
X.drop('BODY_TYPE_Sedan',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.48
# VEH_MANU_YEAR  VIF =  16.15
# VEHICLE_MAKE  VIF =  1.19
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  12.42
# OD_PREM  VIF =  13.59
# TP_PREM  VIF =  3.42
# POLICY_AGE  VIF =  7.4
# NCB  VIF =  1.39
# VEH_AGE  VIF =  14.78
# SENIORITY  VIF =  6.33
# Ratio_PS  VIF =  6.56
# LOCATION  VIF =  1.04
# STATE  VIF =  1.3
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.55
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.26
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.85
# BODY_TYPE_Coupe  VIF =  1.01
# BODY_TYPE_Hatchback  VIF =  1.41
# BODY_TYPE_MUV  VIF =  1.36
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  2.41
# ZONE_North Eastern  VIF =  1.15
# ZONE_Northern  VIF =  3.24
# ZONE_Southern  VIF =  3.51
# ZONE_Western  VIF =  4.45

# %%
X.drop('VEH_MANU_YEAR',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.48
# VEHICLE_MAKE  VIF =  1.19
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  12.42
# OD_PREM  VIF =  13.53
# TP_PREM  VIF =  3.39
# POLICY_AGE  VIF =  7.25
# NCB  VIF =  1.39
# VEH_AGE  VIF =  2.65
# SENIORITY  VIF =  6.05
# Ratio_PS  VIF =  6.56
# LOCATION  VIF =  1.03
# STATE  VIF =  1.28
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.09
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.25
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.82
# BODY_TYPE_Coupe  VIF =  1.01
# BODY_TYPE_Hatchback  VIF =  1.41
# BODY_TYPE_MUV  VIF =  1.36
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.57
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  2.39
# ZONE_North Eastern  VIF =  1.15
# ZONE_Northern  VIF =  3.24
# ZONE_Southern  VIF =  3.5
# ZONE_Western  VIF =  4.37

# %%
X.drop('OD_PREM',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.47
# VEHICLE_MAKE  VIF =  1.18
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  1.73
# TP_PREM  VIF =  2.7
# POLICY_AGE  VIF =  7.25
# NCB  VIF =  1.39
# VEH_AGE  VIF =  2.59
# SENIORITY  VIF =  6.05
# Ratio_PS  VIF =  1.42
# LOCATION  VIF =  1.03
# STATE  VIF =  1.28
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.08
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.25
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.82
# BODY_TYPE_Coupe  VIF =  1.01
# BODY_TYPE_Hatchback  VIF =  1.39
# BODY_TYPE_MUV  VIF =  1.36
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.55
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  2.39
# ZONE_North Eastern  VIF =  1.15
# ZONE_Northern  VIF =  3.24
# ZONE_Southern  VIF =  3.5
# ZONE_Western  VIF =  4.37

# %%
X.drop('POLICY_AGE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.47
# VEHICLE_MAKE  VIF =  1.18
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  1.73
# TP_PREM  VIF =  2.7
# NCB  VIF =  1.39
# VEH_AGE  VIF =  2.12
# SENIORITY  VIF =  1.26
# Ratio_PS  VIF =  1.41
# LOCATION  VIF =  1.03
# STATE  VIF =  1.28
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.07
# CHANNEL_DEALERSHIP  VIF =  1.38
# CHANNEL_DIRECT  VIF =  1.25
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.82
# BODY_TYPE_Coupe  VIF =  1.01
# BODY_TYPE_Hatchback  VIF =  1.39
# BODY_TYPE_MUV  VIF =  1.36
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.55
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  2.39
# ZONE_North Eastern  VIF =  1.15
# ZONE_Northern  VIF =  3.24
# ZONE_Southern  VIF =  3.5
# ZONE_Western  VIF =  4.37

# %%
X.drop('ZONE_Western',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.46
# VEHICLE_MAKE  VIF =  1.18
# VEHICLE_MODEL  VIF =  1.25
# SUM_INSURED  VIF =  1.72
# TP_PREM  VIF =  2.69
# NCB  VIF =  1.39
# VEH_AGE  VIF =  2.1
# SENIORITY  VIF =  1.26
# Ratio_PS  VIF =  1.41
# LOCATION  VIF =  1.03
# STATE  VIF =  1.25
# CHANNEL_BANC ASSURANCE  VIF =  1.12
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_CLOSE CIRCLE  VIF =  4.07
# CHANNEL_DEALERSHIP  VIF =  1.37
# CHANNEL_DIRECT  VIF =  1.24
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.13
# VEH_ORIG_Indian  VIF =  2.81
# BODY_TYPE_Coupe  VIF =  1.01
# BODY_TYPE_Hatchback  VIF =  1.39
# BODY_TYPE_MUV  VIF =  1.35
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.55
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  1.38
# ZONE_North Eastern  VIF =  1.04
# ZONE_Northern  VIF =  1.25
# ZONE_Southern  VIF =  1.27

# %%
X.drop('CHANNEL_CLOSE CIRCLE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.29
# VEHICLE_MAKE  VIF =  1.18
# VEHICLE_MODEL  VIF =  1.24
# SUM_INSURED  VIF =  1.7
# TP_PREM  VIF =  2.41
# NCB  VIF =  1.37
# VEH_AGE  VIF =  2.08
# SENIORITY  VIF =  1.25
# Ratio_PS  VIF =  1.41
# LOCATION  VIF =  1.03
# STATE  VIF =  1.25
# CHANNEL_BANC ASSURANCE  VIF =  1.06
# CHANNEL_BROKERS  VIF =  1.02
# CHANNEL_DEALERSHIP  VIF =  1.23
# CHANNEL_DIRECT  VIF =  1.18
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.12
# VEH_ORIG_Indian  VIF =  1.7
# BODY_TYPE_Coupe  VIF =  1.0
# BODY_TYPE_Hatchback  VIF =  1.38
# BODY_TYPE_MUV  VIF =  1.35
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.45
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  1.37
# ZONE_North Eastern  VIF =  1.04
# ZONE_Northern  VIF =  1.24
# ZONE_Southern  VIF =  1.26

# %%
X.drop('TP_PREM',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.28
# VEHICLE_MAKE  VIF =  1.16
# VEHICLE_MODEL  VIF =  1.22
# SUM_INSURED  VIF =  1.34
# NCB  VIF =  1.33
# VEH_AGE  VIF =  1.63
# SENIORITY  VIF =  1.25
# Ratio_PS  VIF =  1.28
# LOCATION  VIF =  1.03
# STATE  VIF =  1.25
# CHANNEL_BANC ASSURANCE  VIF =  1.06
# CHANNEL_BROKERS  VIF =  1.02
# CHANNEL_DEALERSHIP  VIF =  1.22
# CHANNEL_DIRECT  VIF =  1.16
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.12
# VEH_ORIG_Indian  VIF =  1.67
# BODY_TYPE_Coupe  VIF =  1.0
# BODY_TYPE_Hatchback  VIF =  1.37
# BODY_TYPE_MUV  VIF =  1.34
# BODY_TYPE_Pickup Truck  VIF =  1.0
# BODY_TYPE_SUV  VIF =  1.38
# BODY_TYPE_Van  VIF =  1.0
# ZONE_Eastern  VIF =  1.35
# ZONE_North Eastern  VIF =  1.04
# ZONE_Northern  VIF =  1.23
# ZONE_Southern  VIF =  1.26

# %% [markdown]
# Comments : all the VIF are less than 2 We can proceed on the LR

# %%
import statsmodels.api as sm

import random
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.639769
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:               143629
# Model:                          Logit   Df Residuals:                   143600
# Method:                           MLE   Df Model:                           28
# Date:                Wed, 20 Oct 2021   Pseudo R-squ.:                 0.05393
# Time:                        12:10:29   Log-Likelihood:                -91889.
# converged:                       True   LL-Null:                       -97127.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.4064      0.006    -72.295      0.000      -0.417      -0.395
# INTERMEDIARY              -0.1559      0.007    -23.254      0.000      -0.169      -0.143
# ...

# %% [markdown]
# Removing all features that have Pvalue greater that 0.05

# %%
X.drop(['VEHICLE_MAKE','Ratio_PS','CHANNEL_BANC ASSURANCE','CHANNEL_DIRECT','CHANNEL_OTHERS','BODY_TYPE_Coupe','BODY_TYPE_Hatchback','BODY_TYPE_Pickup Truck','BODY_TYPE_Van','ZONE_Eastern'],axis=1,inplace=True)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.639808
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:               143629
# Model:                          Logit   Df Residuals:                   143610
# Method:                           MLE   Df Model:                           18
# Date:                Wed, 20 Oct 2021   Pseudo R-squ.:                 0.05387
# Time:                        12:10:36   Log-Likelihood:                -91895.
# converged:                       True   LL-Null:                       -97127.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.4064      0.006    -72.300      0.000      -0.417      -0.395
# INTERMEDIARY            -0.1567      0.006    -24.217      0.000      -0.169      -0.144
# ...

# %% [markdown]
# Comments
#     1. p-value shows that the model is significant
#     2. The pseudo R2 value is 0.05387, which means that model is not a good fit.
#     3. All the variables are significant.

# %%
## Collect the coef in a dataframe
lgcoef = pd.DataFrame(lg.params, columns=['coef'])

## Calculate Odds Ratio
lgcoef['Odds_ratio']=np.exp(lgcoef.coef)
lgcoef
# Out:
#                           coef  Odds_ratio
# const                -0.406422    0.666029
# INTERMEDIARY         -0.156680    0.854977
# VEHICLE_MODEL         0.023741    1.024025
# SUM_INSURED           0.019634    1.019828
# NCB                  -0.419022    0.657690
# VEH_AGE               0.126944    1.135354
# SENIORITY            -0.243201    0.784114
# LOCATION             -0.018864    0.981312
# STATE                -0.092019    0.912088
# CHANNEL_BROKERS      -0.061552    0.940304
# CHANNEL_DEALERSHIP    0.167102    1.181875
# CHANNEL_TRAVEL AGENT -0.014223    0.985877
# CHANNEL_WEBSALES      0.018648    1.018823
# VEH_ORIG_Indian       0.083565    1.087156
# BODY_TYPE_MUV         0.053528    1.054986
# BODY_TYPE_SUV         0.093365    1.097863
# ZONE_North Eastern   -0.019614    0.980577
# ZONE_Northern         0.068957    1.071390
# ZONE_Southern        -0.024716    0.975587

# %%
#Calculate Probability
lgcoef['probability'] = lgcoef['Odds_ratio']/(1+lgcoef['Odds_ratio'])
lgcoef
# Out:
#                           coef  Odds_ratio  probability
# const                -0.406422    0.666029     0.399770
# INTERMEDIARY         -0.156680    0.854977     0.460910
# VEHICLE_MODEL         0.023741    1.024025     0.505935
# SUM_INSURED           0.019634    1.019828     0.504908
# NCB                  -0.419022    0.657690     0.396751
# VEH_AGE               0.126944    1.135354     0.531694
# SENIORITY            -0.243201    0.784114     0.439498
# LOCATION             -0.018864    0.981312     0.495284
# STATE                -0.092019    0.912088     0.477012
# CHANNEL_BROKERS      -0.061552    0.940304     0.484617
# CHANNEL_DEALERSHIP    0.167102    1.181875     0.541679
# CHANNEL_TRAVEL AGENT -0.014223    0.985877     0.496444
# CHANNEL_WEBSALES      0.018648    1.018823     0.504662
# VEH_ORIG_Indian       0.083565    1.087156     0.520879
# BODY_TYPE_MUV         0.053528    1.054986     0.513379
# BODY_TYPE_SUV         0.093365    1.097863     0.523324
# ...

# %%
#Calculate p value
lgcoef['pval']=lg.pvalues

#Display rounded to 2 decimal points
pd.options.display.float_format = '{:.2f}'.format
lgcoef
# Out:
#                       coef  Odds_ratio  probability  pval
# const                -0.41        0.67         0.40  0.00
# INTERMEDIARY         -0.16        0.85         0.46  0.00
# VEHICLE_MODEL         0.02        1.02         0.51  0.00
# SUM_INSURED           0.02        1.02         0.50  0.00
# NCB                  -0.42        0.66         0.40  0.00
# VEH_AGE               0.13        1.14         0.53  0.00
# SENIORITY            -0.24        0.78         0.44  0.00
# LOCATION             -0.02        0.98         0.50  0.00
# STATE                -0.09        0.91         0.48  0.00
# CHANNEL_BROKERS      -0.06        0.94         0.48  0.00
# CHANNEL_DEALERSHIP    0.17        1.18         0.54  0.00
# CHANNEL_TRAVEL AGENT -0.01        0.99         0.50  0.02
# CHANNEL_WEBSALES      0.02        1.02         0.50  0.00
# VEH_ORIG_Indian       0.08        1.09         0.52  0.00
# BODY_TYPE_MUV         0.05        1.05         0.51  0.00
# ...

# %%
#Sort by descending order of odds ratio 
lgcoef = lgcoef.sort_values(by="Odds_ratio", ascending=False)

#Filter to display only variables with significant p value
pval_filter = lgcoef['pval']<=0.05
lgcoef[pval_filter]
# Out:
#                       coef  Odds_ratio  probability  pval
# CHANNEL_DEALERSHIP    0.17        1.18         0.54  0.00
# VEH_AGE               0.13        1.14         0.53  0.00
# BODY_TYPE_SUV         0.09        1.10         0.52  0.00
# VEH_ORIG_Indian       0.08        1.09         0.52  0.00
# ZONE_Northern         0.07        1.07         0.52  0.00
# BODY_TYPE_MUV         0.05        1.05         0.51  0.00
# VEHICLE_MODEL         0.02        1.02         0.51  0.00
# SUM_INSURED           0.02        1.02         0.50  0.00
# CHANNEL_WEBSALES      0.02        1.02         0.50  0.00
# CHANNEL_TRAVEL AGENT -0.01        0.99         0.50  0.02
# LOCATION             -0.02        0.98         0.50  0.00
# ZONE_North Eastern   -0.02        0.98         0.50  0.00
# ZONE_Southern        -0.02        0.98         0.49  0.00
# CHANNEL_BROKERS      -0.06        0.94         0.48  0.00
# STATE                -0.09        0.91         0.48  0.00
# ...

# %% [markdown]
# Comments : Relationship is the most valuable assets for the people with high car budget. It plays a key role in the attrition decision. Their prime location is also a key factor.

# %% [markdown]
# #### Logistic Regression using SCikitLearn library

# %%
X_lr = df_dummy_mid.drop(['CHURN','TOTAL_PREMIUM','CAR_BUDGET','VEHICLE_MAKE','Ratio_PS','CHANNEL_BANC ASSURANCE','CHANNEL_DIRECT','CHANNEL_OTHERS','BODY_TYPE_Coupe','BODY_TYPE_Hatchback','BODY_TYPE_Pickup Truck','BODY_TYPE_Van','ZONE_Eastern','VEH_MANU_YEAR','OD_PREM','TP_PREM','CAR_TYPE','BODY_TYPE_Sedan','CHANNEL_CLOSE CIRCLE','ZONE_Western','POLICY_AGE'],axis=1)
Y_lr = df_dummy_mid['CHURN']

# %%
X_lr.columns
# Out:
# Index(['INTERMEDIARY', 'VEHICLE_MODEL', 'SUM_INSURED', 'NCB', 'VEH_AGE',
#        'SENIORITY', 'LOCATION', 'STATE', 'CHANNEL_BROKERS',
#        'CHANNEL_DEALERSHIP', 'CHANNEL_TRAVEL AGENT', 'CHANNEL_WEBSALES',
#        'VEH_ORIG_Indian', 'BODY_TYPE_MUV', 'BODY_TYPE_SUV',
#        'ZONE_North Eastern', 'ZONE_Northern', 'ZONE_Southern'],
#       dtype='object')

# %%
# splitting data into training and test set for independent attributes. Test Size =30% and stratify on Y to have the good proportion between 0 and 1
from sklearn.model_selection import train_test_split

# %%
X_train_lr, X_test_lr, Y_train_lr, Y_test_lr= train_test_split(X_lr, Y_lr, test_size=.30, random_state=1,stratify= Y_lr)

# %%
num_cols = X_train_lr.columns[:].to_list()
X_train_lr.loc[:, num_cols] = ss.fit_transform(X_train_lr.loc[:, num_cols])
X_train_lr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#        INTERMEDIARY  VEHICLE_MODEL  ...  ZONE_Northern  ZONE_Southern
# 29681         -0.48          -0.81  ...          -0.46          -0.56
# 87006          0.48          -0.94  ...          -0.46          -0.56
# 43557         -0.48          -1.11  ...          -0.46           1.77
# 59747          3.77          -0.73  ...          -0.46          -0.56
# 85159         -0.48           1.19  ...          -0.46           1.77
#
# [5 rows x 18 columns]

# %%
num_cols = X_test_lr.columns[:].to_list()
X_test_lr.loc[:, num_cols] = ss.transform(X_test_lr.loc[:, num_cols])
X_test_lr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#         INTERMEDIARY  VEHICLE_MODEL  ...  ZONE_Northern  ZONE_Southern
# 122164          2.88          -1.62  ...          -0.46          -0.56
# 75203          -0.48           1.07  ...           2.17          -0.56
# 91514          -0.48          -1.11  ...          -0.46           1.77
# 66657          -0.48           1.05  ...          -0.46           1.77
# 127194         -0.48          -1.11  ...          -0.46           1.77
#
# [5 rows x 18 columns]

# %%
from sklearn.linear_model import  LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score,roc_auc_score,roc_curve
from sklearn import metrics
import pickle

# %%
lr = LogisticRegression()
lr.fit(X_train_lr, Y_train_lr)

train_pred = lr.predict(X_train_lr)
test_pred = lr.predict(X_test_lr)

print("Acc Train:",metrics.accuracy_score(Y_train_lr, train_pred))
print('Train F1: ', f1_score(Y_train_lr, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test_lr, test_pred))
print('Test F1: ', f1_score(Y_test_lr, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test_lr, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test_lr, test_pred)}')
print('\n')
print(classification_report(Y_test_lr, test_pred))
# Out:
# Acc Train: 0.6332902327431867
# Train F1:  0.4499216710182768
# Acc Test: 0.6312515955348232
# Test F1:  0.4480878113168224
# Area Under Curve: 0.5902381210821523
# Confusion Matrix:
# [[20750  4746]
#  [11143  6450]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.81      0.72     25496
#            1       0.58      0.37      0.45     17593
#
#     accuracy                           0.63     43089
#    macro avg       0.61      0.59      0.59     43089
# weighted avg       0.62      0.63      0.61     43089

# %% [markdown]
# ### LDA

# %%
df_dummy_mid.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0            11        2016.00  ...              0             0
# 1          2224        2014.00  ...              0             0
# 2           663        2010.00  ...              0             1
# 3             1        2011.00  ...              0             0
# 4           371        2012.00  ...              0             1
#
# [5 rows x 39 columns]

# %%
X = df_dummy_mid.drop(df_dummy_mid[["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE']] , axis=1)
Y = df_dummy_mid['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#        INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 29681     -0.477211       0.350306  ...      -0.563689      1.198273
# 87006      0.478870       0.796160  ...      -0.563689      1.198273
# 43557     -0.483406       1.242014  ...       1.774028     -0.834535
# 59747      3.773529      -0.987256  ...      -0.563689      1.198273
# 85159     -0.482374      -0.095548  ...       1.774028     -0.834535
#
# [5 rows x 35 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#         INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 122164      2.881462      -1.878964  ...      -0.563689      1.198273
# 75203      -0.483406       0.796160  ...      -0.563689     -0.834535
# 91514      -0.483406       1.242014  ...       1.774028     -0.834535
# 66657      -0.483406       0.796160  ...       1.774028     -0.834535
# 127194     -0.483406       0.796160  ...       1.774028     -0.834535
#
# [5 rows x 35 columns]

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, Y_train)

train_pred = lda.predict(X_train)
test_pred = lda.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6354286851004576
# Train F1:  0.44838068865880093
# Acc Test: 0.6313676344310613
# Test F1:  0.4435647726476564
# Area Under Curve: 0.5892878481402459
# Confusion Matrix:
# [[20874  4622]
#  [11262  6331]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.82      0.72     25496
#            1       0.58      0.36      0.44     17593
#
#     accuracy                           0.63     43089
#    macro avg       0.61      0.59      0.58     43089
# weighted avg       0.62      0.63      0.61     43089

# %% [markdown]
# ### Decision Tree

# %%
# Create Decision Tree classifer object
dt_model = DecisionTreeClassifier(criterion = 'gini' )
# Train Decision Tree Classifier
dt_model.fit(X_train, Y_train)

#Predict the response for test dataset
train_pred = dt_model.predict(X_train)
test_pred = dt_model.predict(X_test)
print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9701312910284464
# Train F1:  0.9627109383730892
# Acc Test: 0.6085543874306668
# Test F1:  0.5179893121481439
# Area Under Curve: 0.5940778004241247
# Confusion Matrix:
# [[17159  8337]
#  [ 8530  9063]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67     25496
#            1       0.52      0.52      0.52     17593
#
#     accuracy                           0.61     43089
#    macro avg       0.59      0.59      0.59     43089
# weighted avg       0.61      0.61      0.61     43089

# %% [markdown]
# Overfit. So we prune it.

# %%
params = {'min_samples_split':[5,7,10],
          'min_samples_leaf':[10,15,20],
          'max_depth': [5, 8, 10],
          }

# %%
grid_dt_model = GridSearchCV(dt_model, param_grid = params, verbose=1,n_jobs=-1)
grid_dt_model.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:  1.0min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
# ...

# %%
grid_dt_model.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 7}

# %%
grid_dt_model.best_score_
# Out:
# 0.6583449373383728

# %%
abc_score=get_metrics_score(grid_dt_model)

train_pred = grid_dt_model.predict(X_train)
test_pred = grid_dt_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6776506862940124
# Accuracy on test set :  0.6557358026410453
# Recall on training set :  0.5196950135197681
# Recall on test set :  0.49212755073040415
# Precision on training set :  0.6269911244342562
# Precision on test set :  0.5947654049598131
# Train F1:  0.5683231881934547
# Test F1:  0.5386003110419906
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73     25496
#            1       0.59      0.49      0.54     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.64      0.63      0.63     43089
# weighted avg       0.65      0.66      0.65     43089

# %%
params = {'min_samples_split':[7,10,15],
          'min_samples_leaf':[5,15,25],
          'max_depth': [10,15,20],
          }

# %%
grid_dt_model = GridSearchCV(dt_model, param_grid = params, verbose=1,n_jobs=-1)
grid_dt_model.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 135 out of 135 | elapsed:  1.6min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
# ...

# %%
grid_dt_model.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 15, 'min_samples_split': 10}

# %%
grid_dt_model.best_score_
# Out:
# 0.6583051521782376

# %%
abc_score=get_metrics_score(grid_dt_model)

train_pred = grid_dt_model.predict(X_train)
test_pred = grid_dt_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6776506862940124
# Accuracy on test set :  0.6558054259787881
# Recall on training set :  0.5197924532898103
# Recall on test set :  0.4921843915193543
# Precision on training set :  0.6269612740200976
# Precision on test set :  0.5948749656499038
# Train F1:  0.5683691815941934
# Test F1:  0.5386792746275156
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73     25496
#            1       0.59      0.49      0.54     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.64      0.63      0.63     43089
# weighted avg       0.65      0.66      0.65     43089

# %%
# Create Decision Tree classifer object
dt_model = DecisionTreeClassifier(criterion = 'gini',max_depth=10, min_samples_leaf=15, min_samples_split=7 )
# Train Decision Tree Classifier
dt_model.fit(X_train, Y_train)

#Predict the response for test dataset
train_pred = dt_model.predict(X_train)
test_pred = dt_model.predict(X_test)
print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6776506862940124
# Train F1:  0.5683691815941934
# Acc Test: 0.6557822181995405
# Test F1:  0.5386625194401244
# Area Under Curve: 0.6304269933749893
# Confusion Matrix:
# [[19598  5898]
#  [ 8934  8659]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73     25496
#            1       0.59      0.49      0.54     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.64      0.63      0.63     43089
# weighted avg       0.65      0.66      0.65     43089

# %%
make_confusion_matrix(dt_model,Y_test,)

# %%
pd.Series(dt_model.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.376587
# INTERMEDIARY              0.083688
# STATE                     0.081739
# LOCATION                  0.074678
# Ratio_PS                  0.069404
# SENIORITY                 0.064213
# CHANNEL_DEALERSHIP        0.040107
# TP_PREM                   0.035099
# OD_PREM                   0.028076
# SUM_INSURED               0.023631
# CHANNEL_CLOSE CIRCLE      0.020772
# VEH_MANU_YEAR             0.019890
# VEH_ORIG_Indian           0.014445
# ZONE_Western              0.013802
# VEHICLE_MAKE              0.009780
# VEHICLE_MODEL             0.009615
# BODY_TYPE_SUV             0.008686
# VEH_AGE                   0.007399
# POLICY_AGE                0.005578
# ZONE_Northern             0.005565
# BODY_TYPE_Sedan           0.002899
# CHANNEL_BROKERS           0.002471
# ZONE_Southern             0.000852
# BODY_TYPE_MUV             0.000547
# BODY_TYPE_Hatchback       0.000314
# ZONE_Eastern              0.000082
# CHANNEL_DIRECT            0.000079
# ...

# %% [markdown]
# ### ANN

# %%
ANN_model = MLPClassifier(hidden_layer_sizes=(100,100)
                     ,max_iter=100
                     ,solver='adam'
                     ,activation='relu'
                     ,random_state=1
                     ,verbose=True
                     ,tol=0.0001)

# %%
ANN_model.fit(X_train,Y_train)

train_pred = ANN_model.predict(X_train)
test_pred = ANN_model.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Iteration 1, loss = 0.63481118
# Iteration 2, loss = 0.62436398
# Iteration 3, loss = 0.61971119
# Iteration 4, loss = 0.61626118
# Iteration 5, loss = 0.61317164
# Iteration 6, loss = 0.61102946
# Iteration 7, loss = 0.60843495
# Iteration 8, loss = 0.60578699
# Iteration 9, loss = 0.60388603
# Iteration 10, loss = 0.60155480
# Iteration 11, loss = 0.59927506
# Iteration 12, loss = 0.59762424
# Iteration 13, loss = 0.59613725
# Iteration 14, loss = 0.59443816
# Iteration 15, loss = 0.59259458
# Iteration 16, loss = 0.59083394
# Iteration 17, loss = 0.58957292
# Iteration 18, loss = 0.58824707
# Iteration 19, loss = 0.58692984
# Iteration 20, loss = 0.58564610
# Iteration 21, loss = 0.58485548
# Iteration 22, loss = 0.58348678
# Iteration 23, loss = 0.58229404
# Iteration 24, loss = 0.58095161
# Iteration 25, loss = 0.58047274
# Iteration 26, loss = 0.57940841
# Iteration 27, loss = 0.57786368
# Iteration 28, loss = 0.57709150
# Iteration 29, loss = 0.57602612
# ...

# %% [markdown]
# Tuning

# %%
parameter_space = {
    'hidden_layer_sizes': [(10,30,10),(20,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
    'max_iter':[100]
}

# %%
tuned_ANN_model = GridSearchCV(ANN_model, parameter_space, n_jobs=-1, cv=5,verbose =1)
tuned_ANN_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  4.3min finished
# Iteration 1, loss = 0.64379946
# Iteration 2, loss = 0.63297273
# Iteration 3, loss = 0.63025312
# Iteration 4, loss = 0.62795418
# Iteration 5, loss = 0.62610069
# Iteration 6, loss = 0.62502465
# Iteration 7, loss = 0.62399878
# Iteration 8, loss = 0.62323160
# Iteration 9, loss = 0.62260443
# Iteration 10, loss = 0.62216979
# Iteration 11, loss = 0.62153832
# Iteration 12, loss = 0.62095548
# Iteration 13, loss = 0.62013412
# Iteration 14, loss = 0.61965948
# Iteration 15, loss = 0.61905536
# Iteration 16, loss = 0.61837928
# Iteration 17, loss = 0.61790692
# Iteration 18, loss = 0.61726922
# Iteration 19, loss = 0.61657255
# Iteration 20, loss = 0.61559842
# Iteration 21, loss = 0.61486358
# Iteration 22, loss = 0.61440896
# Iteration 23, loss = 0.61362504
# ...

# %%
tuned_ANN_model.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (10, 30, 10),
#  'learning_rate': 'constant',
#  'max_iter': 100,
#  'solver': 'adam'}

# %%
abc_score=get_metrics_score(tuned_ANN_model)

train_pred = tuned_ANN_model.predict(X_train)
test_pred = tuned_ANN_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6770837477620848
# Accuracy on test set :  0.6672700689271044
# Recall on training set :  0.4395995225451268
# Recall on test set :  0.42971636446313877
# Precision on training set :  0.6560511869705893
# Precision on test set :  0.6372218476062036
# Train F1:  0.5264447620992445
# Test F1:  0.5132905591200733
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75     25496
#            1       0.64      0.43      0.51     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.66      0.63      0.63     43089
# weighted avg       0.66      0.67      0.65     43089

# %%
parameter_space = {
    'hidden_layer_sizes': [(20,30,20),(30,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
    'max_iter':[100]
}

# %%
tuned_ANN_model = GridSearchCV(ANN_model, parameter_space, n_jobs=-1, cv=5,verbose =1)
tuned_ANN_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 69.8min finished
# Iteration 1, loss = 0.65523609
# Iteration 2, loss = 0.64027572
# Iteration 3, loss = 0.63683951
# Iteration 4, loss = 0.63463115
# Iteration 5, loss = 0.63283097
# Iteration 6, loss = 0.63118152
# Iteration 7, loss = 0.62976259
# Iteration 8, loss = 0.62848834
# Iteration 9, loss = 0.62741072
# Iteration 10, loss = 0.62570445
# Iteration 11, loss = 0.62470313
# Iteration 12, loss = 0.62340503
# Iteration 13, loss = 0.62241430
# Iteration 14, loss = 0.62142239
# Iteration 15, loss = 0.62084220
# Iteration 16, loss = 0.62042355
# Iteration 17, loss = 0.61962110
# Iteration 18, loss = 0.61931476
# Iteration 19, loss = 0.61877175
# Iteration 20, loss = 0.61820679
# Iteration 21, loss = 0.61793990
# ...

# %%
tuned_ANN_model.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.05,
#  'hidden_layer_sizes': (20, 30, 20),
#  'learning_rate': 'constant',
#  'max_iter': 100,
#  'solver': 'adam'}

# %%
abc_score=get_metrics_score(tuned_ANN_model)

train_pred = tuned_ANN_model.predict(X_train)
test_pred = tuned_ANN_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6789934354485777
# Accuracy on test set :  0.6642530576249158
# Recall on training set :  0.4938003946310687
# Recall on test set :  0.4742795430000568
# Precision on training set :  0.6381552022666457
# Precision on test set :  0.6152484884235363
# Train F1:  0.5567732366512854
# Test F1:  0.5356443588509068
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74     25496
#            1       0.62      0.47      0.54     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.65      0.63      0.64     43089
# weighted avg       0.66      0.66      0.65     43089

# %%
parameter_space = {
    'hidden_layer_sizes': [(30,40,30),(10,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
    'max_iter':[100]
}

# %%
tuned_ANN_model = GridSearchCV(ANN_model, parameter_space, n_jobs=-1, cv=5,verbose =1)
tuned_ANN_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 72.9min finished
# Iteration 1, loss = 0.64980072
# Iteration 2, loss = 0.63979274
# Iteration 3, loss = 0.63576772
# Iteration 4, loss = 0.63337637
# Iteration 5, loss = 0.63132642
# Iteration 6, loss = 0.63009646
# Iteration 7, loss = 0.62870175
# Iteration 8, loss = 0.62758717
# Iteration 9, loss = 0.62563564
# Iteration 10, loss = 0.62417477
# Iteration 11, loss = 0.62357968
# Iteration 12, loss = 0.62216597
# Iteration 13, loss = 0.62084753
# Iteration 14, loss = 0.62022523
# Iteration 15, loss = 0.61982185
# Iteration 16, loss = 0.61862307
# Iteration 17, loss = 0.61823236
# Iteration 18, loss = 0.61738826
# Iteration 19, loss = 0.61710878
# Iteration 20, loss = 0.61647134
# Iteration 21, loss = 0.61634997
# ...

# %%
tuned_ANN_model.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.05,
#  'hidden_layer_sizes': (30, 40, 30),
#  'learning_rate': 'constant',
#  'max_iter': 100,
#  'solver': 'adam'}

# %%
abc_score=get_metrics_score(tuned_ANN_model)

train_pred = tuned_ANN_model.predict(X_train)
test_pred = tuned_ANN_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.687417943107221
# Accuracy on test set :  0.6673861078233424
# Recall on training set :  0.4882706876811771
# Recall on test set :  0.46512817597908257
# Precision on training set :  0.6579569327731093
# Precision on test set :  0.6244181610072491
# Train F1:  0.5605537299867162
# Test F1:  0.5331291940843051
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.81      0.74     25496
#            1       0.62      0.47      0.53     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.66      0.64      0.64     43089
# weighted avg       0.66      0.67      0.66     43089

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, Y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9701213447384126
# Train F1:  0.9633058901131116
# Acc Test: 0.6646940054306203
# Test F1:  0.5417988075605733
# Area Under Curve: 0.6369268778207152
# Confusion Matrix:
# [[20099  5397]
#  [ 9051  8542]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.79      0.74     25496
#            1       0.61      0.49      0.54     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.65      0.64      0.64     43089
# weighted avg       0.66      0.66      0.66     43089

# %%
params = {'n_estimators': [70,90,100],
          'min_samples_split':[5,7,10],
          'min_samples_leaf':[10,15,20],
          'max_depth': [5, 8, 10],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed: 33.8min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 10,
#  'min_samples_split': 5,
#  'n_estimators': 100}

# %%
abc_score=get_metrics_score(grid_rfcl)

train_pred = grid_rfcl.predict(X_train)
test_pred = grid_rfcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6890093495126318
# Accuracy on test set :  0.6695444312933695
# Recall on training set :  0.44586002777033445
# Recall on test set :  0.42016711191951345
# Precision on training set :  0.6823875922749981
# Precision on test set :  0.6467191601049869
# Train F1:  0.5393308090109469
# Test F1:  0.5093891051924336
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.84      0.75     25496
#            1       0.65      0.42      0.51     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.66      0.63      0.63     43089
# weighted avg       0.67      0.67      0.65     43089

# %%
rf = RandomForestClassifier(random_state=1,max_depth=10,min_samples_leaf=10,min_samples_split=5,n_estimators=100)
rf.fit(X_train, Y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6890093495126318
# Train F1:  0.5393308090109469
# Acc Test: 0.6695444312933695
# Test F1:  0.5093891051924336
# Area Under Curve: 0.6308946635844821
# Confusion Matrix:
# [[21458  4038]
#  [10201  7392]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.84      0.75     25496
#            1       0.65      0.42      0.51     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.66      0.63      0.63     43089
# weighted avg       0.67      0.67      0.65     43089

# %%
#Importance of features
pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.282240
# INTERMEDIARY              0.085933
# STATE                     0.063787
# SENIORITY                 0.057865
# LOCATION                  0.057336
# Ratio_PS                  0.054659
# OD_PREM                   0.044055
# POLICY_AGE                0.043557
# TP_PREM                   0.039180
# SUM_INSURED               0.031925
# CHANNEL_DEALERSHIP        0.030274
# VEH_AGE                   0.029403
# VEH_MANU_YEAR             0.029010
# VEHICLE_MAKE              0.023031
# VEHICLE_MODEL             0.021892
# CHANNEL_CLOSE CIRCLE      0.019003
# VEH_ORIG_Indian           0.019003
# ZONE_Western              0.015598
# ZONE_Southern             0.013494
# ZONE_Northern             0.008733
# BODY_TYPE_SUV             0.008343
# BODY_TYPE_Sedan           0.004424
# ZONE_Eastern              0.004068
# CHANNEL_BROKERS           0.003112
# BODY_TYPE_Hatchback       0.002676
# BODY_TYPE_MUV             0.002444
# CHANNEL_DIRECT            0.002233
# ...

# %% [markdown]
# ### Ensemble Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
be = DecisionTreeClassifier()
bgcl = BaggingClassifier(base_estimator=be,random_state=1)


bgcl = bgcl.fit(X_train, Y_train)

abc_score=get_metrics_score(bgcl)

train_pred = bgcl.predict(X_train)
test_pred = bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.9504973145016908
# Accuracy on test set :  0.6533686091577897
# Recall on training set :  0.9185647121872792
# Recall on test set :  0.4679702154265901
# Precision on training set :  0.9584667785064308
# Precision on test set :  0.5962053733072634
# Train F1:  0.9380916248927146
# Test F1:  0.5243615056365837
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73     25496
#            1       0.60      0.47      0.52     17593
#
#     accuracy                           0.65     43089
#    macro avg       0.64      0.62      0.63     43089
# weighted avg       0.65      0.65      0.64     43089

# %%
params = {'base_estimator__min_samples_split':[5,10],
          'base_estimator__min_samples_leaf':[10,15],
          'base_estimator__max_depth': [5,10]
          }

# %%
bgcl = BaggingClassifier(base_estimator=be,random_state=1 )
grid_bgcl = GridSearchCV(bgcl, param_grid = params,verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_bgcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:  1.8min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                                                class_weight=None,
#                                                                                criterion='gini',
#                                                                                max_depth=None,
#                                                                                max_features=None,
#                                                                                max_leaf_nodes=None,
#                                                                                min_impurity_decrease=0.0,
# ...

# %%
grid_bgcl.best_params_
# Out:
# {'base_estimator__max_depth': 10,
#  'base_estimator__min_samples_leaf': 10,
#  'base_estimator__min_samples_split': 5}

# %%
abc_score=get_metrics_score(grid_bgcl)

train_pred = grid_bgcl.predict(X_train)
test_pred = grid_bgcl.predict(X_test)


print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6920628605530137
# Accuracy on test set :  0.6670611989138759
# Recall on training set :  0.48303330004141193
# Recall on test set :  0.4550673563349059
# Precision on training set :  0.6706463286772415
# Precision on test set :  0.627183705444575
# Train F1:  0.5615848650485711
# Test F1:  0.5274392252454049
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74     25496
#            1       0.63      0.46      0.53     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.66      0.63      0.64     43089
# weighted avg       0.66      0.67      0.65     43089

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 100,random_state=1)
gbcl = gbcl.fit(X_train, Y_train)

train_pred = gbcl.predict(X_train)
test_pred = gbcl.predict(X_test)

abc_score=get_metrics_score(gbcl)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6713248458325045
# Accuracy on test set :  0.6659240177307434
# Recall on training set :  0.4530462108109425
# Recall on test set :  0.44813278008298757
# Precision on training set :  0.6371360054813292
# Precision on test set :  0.6272076372315036
# Train F1:  0.5295482695291923
# Test F1:  0.5227596724463748
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.82      0.74     25496
#            1       0.63      0.45      0.52     17593
#
#     accuracy                           0.67     43089
#    macro avg       0.65      0.63      0.63     43089
# weighted avg       0.66      0.67      0.65     43089

# %%
#Importance of features
pd.Series(gbcl.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.457668
# STATE                     0.094247
# INTERMEDIARY              0.075637
# LOCATION                  0.072576
# SENIORITY                 0.058143
# CHANNEL_DEALERSHIP        0.043196
# TP_PREM                   0.043074
# CHANNEL_CLOSE CIRCLE      0.038713
# Ratio_PS                  0.026037
# VEH_MANU_YEAR             0.023182
# VEH_ORIG_Indian           0.015328
# ZONE_Northern             0.008112
# BODY_TYPE_SUV             0.008067
# ZONE_Western              0.007365
# CHANNEL_BROKERS           0.005259
# VEHICLE_MAKE              0.005174
# OD_PREM                   0.004554
# VEH_AGE                   0.003822
# SUM_INSURED               0.003799
# VEHICLE_MODEL             0.002679
# BODY_TYPE_Sedan           0.002474
# POLICY_AGE                0.000427
# ZONE_Southern             0.000351
# BODY_TYPE_Hatchback       0.000117
# BODY_TYPE_Van             0.000000
# ZONE_Eastern              0.000000
# ZONE_North Eastern        0.000000
# ...

# %% [markdown]
# ### Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier( n_estimators= 100, random_state=1, learning_rate=0.1)
ada.fit(X_train, Y_train)

train_pred = ada.predict(X_train)
test_pred = ada.predict(X_test)

abc_score=get_metrics_score(ada)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6484583250447583
# Accuracy on test set :  0.6441783285757385
# Recall on training set :  0.39302331246498257
# Recall on test set :  0.3881089069516285
# Precision on training set :  0.607431949098302
# Precision on test set :  0.5992101799034665
# Train F1:  0.4772525587173875
# Test F1:  0.47109148613219265
#
#
#               precision    recall  f1-score   support
#
#            0       0.66      0.82      0.73     25496
#            1       0.60      0.39      0.47     17593
#
#     accuracy                           0.64     43089
#    macro avg       0.63      0.60      0.60     43089
# weighted avg       0.64      0.64      0.63     43089

# %% [markdown]
# ### Extreme Gradient boosting

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(n_estimators= 100, random_state=1, learning_rate=0.1)
xg.fit(X_train, Y_train)

train_pred = xg.predict(X_train)
test_pred = xg.predict(X_test)

abc_score=get_metrics_score(xg)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6699124726477024
# Accuracy on test set :  0.6633479542342593
# Recall on training set :  0.4535334096611532
# Recall on test set :  0.4473938498266356
# Precision on training set :  0.633868990875664
# Precision on test set :  0.6219676017384433
# Train F1:  0.5287477102651122
# Test F1:  0.5204311028828352
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.81      0.74     25496
#            1       0.62      0.45      0.52     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.65      0.63      0.63     43089
# weighted avg       0.66      0.66      0.65     43089

# %%
#Importance of features
pd.Series(xg.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.254958
# CHANNEL_DEALERSHIP        0.082871
# SENIORITY                 0.063433
# BODY_TYPE_SUV             0.063190
# STATE                     0.055342
# CHANNEL_CLOSE CIRCLE      0.052431
# INTERMEDIARY              0.041990
# VEH_MANU_YEAR             0.039909
# VEH_ORIG_Indian           0.038559
# ZONE_Western              0.037278
# LOCATION                  0.033117
# TP_PREM                   0.032811
# Ratio_PS                  0.030620
# ZONE_Northern             0.028497
# CHANNEL_DIRECT            0.021793
# CHANNEL_BROKERS           0.020999
# POLICY_AGE                0.018953
# VEHICLE_MAKE              0.016946
# OD_PREM                   0.014591
# BODY_TYPE_Sedan           0.014292
# VEH_AGE                   0.012681
# VEHICLE_MODEL             0.012621
# SUM_INSURED               0.009120
# BODY_TYPE_MUV             0.002996
# CHANNEL_BANC ASSURANCE    0.000000
# BODY_TYPE_Pickup Truck    0.000000
# BODY_TYPE_Van             0.000000
# ...

# %% [markdown]
# tuning

# %%
params = {'n_estimators': [100, 200],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 10],
          "learning_rate":[0.001,0.0005]
          }

# %%
# %%time
xg = XGBClassifier(random_state=1)
grid_xg = GridSearchCV(xg, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_xg.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed: 66.9min finished
# CPU times: user 1min 52s, sys: 2.92 s, total: 1min 55s
# Wall time: 1h 8min 25s

# %%
grid_xg.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 10,
#  'min_samples_leaf': 10,
#  'n_estimators': 200}

# %%
grid_xg.best_score_
# Out:
# 0.6626616272130494

# %%
abc_score=get_metrics_score(grid_xg)

train_pred = grid_xg.predict(X_train)
test_pred = grid_xg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.686542669584245
# Accuracy on test set :  0.6603541507113184
# Recall on training set :  0.5037879710603883
# Recall on test set :  0.47285852327630307
# Precision on training set :  0.6498146169798278
# Precision on test set :  0.6081140350877193
# Train F1:  0.5675590378308657
# Test F1:  0.5320244300195057
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73     25496
#            1       0.61      0.47      0.53     17593
#
#     accuracy                           0.66     43089
#    macro avg       0.65      0.63      0.63     43089
# weighted avg       0.65      0.66      0.65     43089

# %% [markdown]
# ### light gbm

# %%
from lightgbm import LGBMClassifier
lg = LGBMClassifier(n_estimators= 100, random_state=1, learning_rate=0.1)
lg.fit(X_train, Y_train)

train_pred = lg.predict(X_train)
test_pred = lg.predict(X_test)

abc_score=get_metrics_score(lg)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6984483787547245
# Accuracy on test set :  0.6835851377381699
# Recall on training set :  0.4918515992302258
# Recall on test set :  0.4742227022111067
# Precision on training set :  0.6810010455664609
# Precision on test set :  0.6555354757601949
# Train F1:  0.5711739745403112
# Test F1:  0.5503298153034302
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76     25496
#            1       0.66      0.47      0.55     17593
#
#     accuracy                           0.68     43089
#    macro avg       0.68      0.65      0.65     43089
# weighted avg       0.68      0.68      0.67     43089

# %%
#Importance of features
pd.Series(lg.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# LOCATION                  394
# INTERMEDIARY              378
# Ratio_PS                  267
# TP_PREM                   240
# STATE                     232
# OD_PREM                   210
# NCB                       179
# VEH_MANU_YEAR             168
# SUM_INSURED               157
# SENIORITY                 125
# VEHICLE_MODEL             113
# CHANNEL_CLOSE CIRCLE       81
# VEHICLE_MAKE               73
# VEH_AGE                    68
# CHANNEL_DEALERSHIP         45
# ZONE_Northern              35
# VEH_ORIG_Indian            33
# ZONE_Western               32
# ZONE_Southern              30
# BODY_TYPE_SUV              30
# CHANNEL_BROKERS            27
# POLICY_AGE                 26
# BODY_TYPE_Sedan            14
# CHANNEL_BANC ASSURANCE     13
# BODY_TYPE_MUV              12
# CHANNEL_DIRECT              8
# ZONE_Eastern                4
# ZONE_North Eastern          4
# BODY_TYPE_Hatchback         1
# CHANNEL_WEBSALES            1
# BODY_TYPE_Pickup Truck      0
# ...

# %%
params = {'n_estimators': [200, 300],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 10],
          "learning_rate":[0.001,0.0005]
          }

# %%
lg = LGBMClassifier(random_state=1)
grid_lg = GridSearchCV(lg, param_grid = params, cv = 5, scoring='accuracy',n_jobs=-1)
grid_lg.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                       colsample_bytree=1.0,
#                                       importance_type='split',
#                                       learning_rate=0.1, max_depth=-1,
#                                       min_child_samples=20,
#                                       min_child_weight=0.001,
#                                       min_split_gain=0.0, n_estimators=100,
#                                       n_jobs=-1, num_leaves=31, objective=None,
#                                       random_state=1, reg_alpha=0.0,
#                                       reg_lambda=0.0, silent=True,
#                                       subsample=1.0, subsample_for_bin=200000,
#                                       subsample_freq=0),
#              iid='deprecated', n_jobs=-1,
# ...

# %%
grid_lg.best_params_
# Out:
# {'learning_rate': 0.001,
#  'max_depth': 10,
#  'min_samples_leaf': 10,
#  'n_estimators': 300}

# %%
grid_lg.best_score_
# Out:
# 0.6004674756315895

# %%
abc_score=get_metrics_score(grid_lg)

train_pred = grid_lg.predict(X_train)
test_pred = grid_lg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.599074995026855
# Accuracy on test set :  0.5994569379656061
# Recall on training set :  0.021850868431950502
# Recall on test set :  0.02421417609276417
# Precision on training set :  0.8526615969581749
# Precision on test set :  0.8223938223938224
# Train F1:  0.04260979027622735
# Test F1:  0.047043233394069905
#
#
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75     25496
#            1       0.82      0.02      0.05     17593
#
#     accuracy                           0.60     43089
#    macro avg       0.71      0.51      0.40     43089
# weighted avg       0.69      0.60      0.46     43089

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# The best performing models considered :
# 1. Decision Tree
# 2. Gradient Boost
# 3. Light Gradient Boost
# 4. XGBoost
# 5. Rnadom Forest
#
# For all the above models we take the top 10 features and select only the features which are most common across models. Then we run the best model (here its Decision Tree ) with these features.

# %% [markdown]
# The Common Features are
# 1. Ratio_PS
# 2. INTERMEDIARY
# 3. NCB
# 4. LOCATION
# 5. TP_PREM
# 6. STATE
# 7. SENIORITY

# %%
x_feature = X[['Ratio_PS','INTERMEDIARY','NCB','LOCATION','TP_PREM','STATE','SENIORITY']]

# %%
Xf_train, Xf_test, Yf_train, Yf_test= train_test_split(x_feature, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = Xf_train.columns[:].to_list()
Xf_train.loc[:, num_cols] = ss.fit_transform(Xf_train.loc[:, num_cols])
Xf_train.head()
# Out:
#        Ratio_PS  INTERMEDIARY       NCB  ...   TP_PREM     STATE  SENIORITY
# 29681 -0.225650     -0.477211  0.237276  ... -0.725822 -0.952529  -0.638588
# 87006  0.000702      0.478870  0.237276  ...  1.462803  0.488403  -0.638588
# 43557  0.812269     -0.483406 -1.472666  ... -0.891445  1.449025  -0.638588
# 59747  0.710515      3.773529 -0.104712  ... -0.698938 -0.792425   1.517546
# 85159  0.380564     -0.482374 -0.104712  ... -0.739264  0.008093   0.319693
#
# [5 rows x 7 columns]

# %%
num_cols = Xf_test.columns[:].to_list()
Xf_test.loc[:, num_cols] = ss.transform(Xf_test.loc[:, num_cols])
Xf_test.head()
# Out:
#         Ratio_PS  INTERMEDIARY       NCB  ...   TP_PREM     STATE  SENIORITY
# 122164 -1.373652      2.881462 -1.472666  ...  1.395114  0.488403  -0.638588
# 75203   0.480896     -0.483406 -0.104712  ... -0.793511 -1.112632  -0.638588
# 91514   0.395098     -0.483406 -0.104712  ... -0.891445  1.449025  -0.638588
# 66657   0.252478     -0.483406 -1.472666  ... -0.658132 -1.913150  -0.638588
# 127194  0.602964     -0.483406 -0.104712  ... -0.891445  1.449025  -0.638588
#
# [5 rows x 7 columns]

# %%
# Create Decision Tree classifer object
dt_model1 = DecisionTreeClassifier(criterion = 'gini',max_depth=10, min_samples_leaf=15, min_samples_split=7 )
# Train Decision Tree Classifier
dt_model1.fit(Xf_train, Yf_train)

#Predict the response for test dataset
train_pred = dt_model1.predict(Xf_train)
test_pred = dt_model1.predict(Xf_test)
print("Acc Train:",metrics.accuracy_score(Yf_train, train_pred))
print('Train F1: ', f1_score(Yf_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Yf_test, test_pred))
print('Test F1: ', f1_score(Yf_test, test_pred))

print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6747065844440023
# Train F1:  0.5538016562751545
# Acc Test: 0.6545522058994175
# Test F1:  0.5261214224316322
#
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.78      0.73     25496
#            1       0.60      0.47      0.53     17593
#
#     accuracy                           0.65     43089
#    macro avg       0.64      0.63      0.63     43089
# weighted avg       0.65      0.65      0.65     43089

# %% [markdown]
# Accuracy doesnt improve. The Recall score got decreased.

# %%
y_predict = dt_model1.predict(Xf_test)
cm=metrics.confusion_matrix( Yf_test, y_predict, labels=[0, 1])
df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No(0)","Actual - Yes(1)"]],
                  columns = [i for i in ['Predicted - No(0)','Predicted - Yes(1)']])
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=labels,fmt='')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 42.0, 'Predicted label')

# %% [markdown]
# ## High Budget

# %%
df1=df_high.copy()
df1.drop(['ZONE','BODY_TYPE','CHANNEL','VEH_ORIG'],inplace = True,axis=1)

# %%
#encoding data
for i in df1.columns:#looping through all of the columns or variables
    if df1[i].dtype == 'object': #checking if the data type of the variable is 'object'
        df1[i] = pd.Categorical(df_high[i]).codes #converting the identified variable into Categorical and extracting the ranks

# %%
df1.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN'],
#       dtype='object')

# %%
df1.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  VEHICLE_MAKE  ...  LOCATION  STATE  CHURN
# 0             0         2014.0            17  ...        27     20      0
# 1           467         2012.0             3  ...        25     20      0
# 2           108         2014.0            17  ...        69     15      0
# 3           296         2011.0             0  ...       104     15      0
# 4             0         2008.0            26  ...        40      9      0
#
# [5 rows x 18 columns]

# %%
df1["BODY_TYPE"] = df_high["BODY_TYPE"]
df1["CHANNEL"] = df_high["CHANNEL"]
df1["ZONE"] = df_high["ZONE"]
df1["VEH_ORIG"] = df_high["VEH_ORIG"]

# %%
df1.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN', 'BODY_TYPE', 'CHANNEL', 'ZONE',
#        'VEH_ORIG'],
#       dtype='object')

# %%
df1 = df1.reindex(columns=['INTERMEDIARY', 'CHANNEL', 'VEH_MANU_YEAR', 'VEHICLE_MAKE',
       'VEHICLE_MODEL','VEH_ORIG', 'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM',
       'POLICY_AGE', 'NCB', 'VEH_AGE', 'SENIORITY','Ratio_PS','BODY_TYPE','CAR_BUDGET','CAR_TYPE',
       'LOCATION','STATE', 'ZONE','CHURN'])

# %%
df_dummy_high = pd.get_dummies(df1,drop_first=True)

# %%
df_dummy_high.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0             0         2014.0  ...              1             0
# 1           467         2012.0  ...              1             0
# 2           108         2014.0  ...              0             1
# 3           296         2011.0  ...              0             1
# 4             0         2008.0  ...              0             0
#
# [5 rows x 36 columns]

# %%
df_dummy_high['CHURN'] = df_dummy_high['CHURN'].astype('category')

# %%
df_dummy_high.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5393 entries, 0 to 5392
# Data columns (total 36 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   INTERMEDIARY            5393 non-null   int16
#  1   VEH_MANU_YEAR           5393 non-null   float64
#  2   VEHICLE_MAKE            5393 non-null   int8
#  3   VEHICLE_MODEL           5393 non-null   int16
#  4   SUM_INSURED             5393 non-null   int64
#  5   TOTAL_PREMIUM           5393 non-null   int64
#  6   OD_PREM                 5393 non-null   int64
#  7   TP_PREM                 5393 non-null   int64
#  8   POLICY_AGE              5393 non-null   float64
#  9   NCB                     5393 non-null   float64
#  10  VEH_AGE                 5393 non-null   float64
#  11  SENIORITY               5393 non-null   float64
#  12  Ratio_PS                5393 non-null   float64
#  13  CAR_BUDGET              5393 non-null   int8
# ...

# %% [markdown]
# Comment : VEH_ORIG deleted. All cars are foreign cars.

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %% [markdown]
# ### Logistic Regression

# %%
X = df_dummy_high.drop(df_dummy_high[['CHURN','CAR_BUDGET','TOTAL_PREMIUM']],axis=1)
Y = df_dummy_high["CHURN"]

# %%
df_dummy_high.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'SUM_INSURED', 'TOTAL_PREMIUM', 'OD_PREM', 'TP_PREM', 'POLICY_AGE',
#        'NCB', 'VEH_AGE', 'SENIORITY', 'Ratio_PS', 'CAR_BUDGET', 'CAR_TYPE',
#        'LOCATION', 'STATE', 'CHURN', 'CHANNEL_BANC ASSURANCE',
#        'CHANNEL_BROKERS', 'CHANNEL_DEALERSHIP', 'CHANNEL_DIRECT',
#        'CHANNEL_OTHERS', 'CHANNEL_TRAVEL AGENT', 'CHANNEL_WEBSALES',
#        'BODY_TYPE_Coupe', 'BODY_TYPE_Hatchback', 'BODY_TYPE_MUV',
#        'BODY_TYPE_SUV', 'BODY_TYPE_Sedan', 'BODY_TYPE_Van', 'ZONE_Eastern',
#        'ZONE_North Eastern', 'ZONE_Northern', 'ZONE_Southern', 'ZONE_Western'],
#       dtype='object')

# %%
num_cols = X.columns[:].to_list()
X.loc[:, num_cols] = ss.fit_transform(X.loc[:, num_cols])
X.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0         -0.75           0.10  ...           1.99         -0.86
# 1          0.85          -0.75  ...           1.99         -0.86
# 2         -0.38           0.10  ...          -0.50          1.16
# 3          0.27          -1.17  ...          -0.50          1.16
# 4         -0.75          -2.44  ...          -0.50         -0.86
#
# [5 rows x 33 columns]

# %%
import statsmodels.formula.api as SM

# %%
def vif_cal(input_data):
    x_vars=input_data
    xvar_names=input_data.columns
    for i in range(0,xvar_names.shape[0]):
        y=x_vars[xvar_names[i]] 
        x=x_vars[xvar_names.drop(xvar_names[i])]
        rsq=SM.ols(formula="y~x", data=x_vars).fit().rsquared  
        vif=round(1/(1-rsq),2)
        print (xvar_names[i], " VIF = " , vif)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.29
# VEH_MANU_YEAR  VIF =  12.93
# VEHICLE_MAKE  VIF =  1.11
# VEHICLE_MODEL  VIF =  1.32
# SUM_INSURED  VIF =  9.17
# OD_PREM  VIF =  12.4
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  6.42
# NCB  VIF =  1.25
# VEH_AGE  VIF =  13.15
# SENIORITY  VIF =  5.82
# Ratio_PS  VIF =  4.34
# CAR_TYPE  VIF =  1.23
# LOCATION  VIF =  1.16
# STATE  VIF =  1.77
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.54
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.02
# CHANNEL_WEBSALES  VIF =  1.25
# BODY_TYPE_Coupe  VIF =  5.3
# BODY_TYPE_Hatchback  VIF =  4.8
# BODY_TYPE_MUV  VIF =  1.48
# BODY_TYPE_SUV  VIF =  71.36
# BODY_TYPE_Sedan  VIF =  71.74
# BODY_TYPE_Van  VIF =  1.17
# ZONE_Eastern  VIF =  2.4
# ZONE_North Eastern  VIF =  1.12
# ZONE_Northern  VIF =  4.99
# ZONE_Southern  VIF =  3.81
# ZONE_Western  VIF =  5.32

# %%
X.drop('BODY_TYPE_Sedan',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.29
# VEH_MANU_YEAR  VIF =  12.92
# VEHICLE_MAKE  VIF =  1.11
# VEHICLE_MODEL  VIF =  1.32
# SUM_INSURED  VIF =  9.16
# OD_PREM  VIF =  12.4
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  6.42
# NCB  VIF =  1.25
# VEH_AGE  VIF =  13.15
# SENIORITY  VIF =  5.82
# Ratio_PS  VIF =  4.34
# CAR_TYPE  VIF =  1.23
# LOCATION  VIF =  1.16
# STATE  VIF =  1.77
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.54
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.02
# CHANNEL_WEBSALES  VIF =  1.25
# BODY_TYPE_Coupe  VIF =  1.08
# BODY_TYPE_Hatchback  VIF =  1.07
# BODY_TYPE_MUV  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.33
# BODY_TYPE_Van  VIF =  1.01
# ZONE_Eastern  VIF =  2.4
# ZONE_North Eastern  VIF =  1.12
# ZONE_Northern  VIF =  4.99
# ZONE_Southern  VIF =  3.81
# ZONE_Western  VIF =  5.32

# %%
X.drop('VEH_AGE',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.28
# VEH_MANU_YEAR  VIF =  1.89
# VEHICLE_MAKE  VIF =  1.11
# VEHICLE_MODEL  VIF =  1.31
# SUM_INSURED  VIF =  9.16
# OD_PREM  VIF =  12.4
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  6.42
# NCB  VIF =  1.25
# SENIORITY  VIF =  5.7
# Ratio_PS  VIF =  4.34
# CAR_TYPE  VIF =  1.22
# LOCATION  VIF =  1.16
# STATE  VIF =  1.77
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.54
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.02
# CHANNEL_WEBSALES  VIF =  1.23
# BODY_TYPE_Coupe  VIF =  1.08
# BODY_TYPE_Hatchback  VIF =  1.07
# BODY_TYPE_MUV  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.33
# BODY_TYPE_Van  VIF =  1.01
# ZONE_Eastern  VIF =  2.36
# ZONE_North Eastern  VIF =  1.12
# ZONE_Northern  VIF =  4.99
# ZONE_Southern  VIF =  3.77
# ZONE_Western  VIF =  5.08

# %%
X.drop('SUM_INSURED',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.28
# VEH_MANU_YEAR  VIF =  1.88
# VEHICLE_MAKE  VIF =  1.1
# VEHICLE_MODEL  VIF =  1.31
# OD_PREM  VIF =  1.57
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  6.42
# NCB  VIF =  1.25
# SENIORITY  VIF =  5.7
# Ratio_PS  VIF =  1.73
# CAR_TYPE  VIF =  1.22
# LOCATION  VIF =  1.16
# STATE  VIF =  1.76
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.54
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.23
# BODY_TYPE_Coupe  VIF =  1.07
# BODY_TYPE_Hatchback  VIF =  1.06
# BODY_TYPE_MUV  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.33
# BODY_TYPE_Van  VIF =  1.01
# ZONE_Eastern  VIF =  2.35
# ZONE_North Eastern  VIF =  1.12
# ZONE_Northern  VIF =  4.99
# ZONE_Southern  VIF =  3.77
# ZONE_Western  VIF =  5.08

# %%
X.drop('SENIORITY',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.28
# VEH_MANU_YEAR  VIF =  1.66
# VEHICLE_MAKE  VIF =  1.1
# VEHICLE_MODEL  VIF =  1.31
# OD_PREM  VIF =  1.57
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  1.24
# NCB  VIF =  1.24
# Ratio_PS  VIF =  1.73
# CAR_TYPE  VIF =  1.2
# LOCATION  VIF =  1.16
# STATE  VIF =  1.76
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.53
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.23
# BODY_TYPE_Coupe  VIF =  1.07
# BODY_TYPE_Hatchback  VIF =  1.06
# BODY_TYPE_MUV  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.33
# BODY_TYPE_Van  VIF =  1.01
# ZONE_Eastern  VIF =  2.35
# ZONE_North Eastern  VIF =  1.12
# ZONE_Northern  VIF =  4.99
# ZONE_Southern  VIF =  3.77
# ZONE_Western  VIF =  5.07

# %%
X.drop('ZONE_Western',inplace=True,axis=1)

# %%
vif_cal(X)
# Out:
# INTERMEDIARY  VIF =  1.26
# VEH_MANU_YEAR  VIF =  1.66
# VEHICLE_MAKE  VIF =  1.1
# VEHICLE_MODEL  VIF =  1.31
# OD_PREM  VIF =  1.57
# TP_PREM  VIF =  1.06
# POLICY_AGE  VIF =  1.24
# NCB  VIF =  1.24
# Ratio_PS  VIF =  1.73
# CAR_TYPE  VIF =  1.2
# LOCATION  VIF =  1.16
# STATE  VIF =  1.75
# CHANNEL_BANC ASSURANCE  VIF =  1.09
# CHANNEL_BROKERS  VIF =  1.03
# CHANNEL_DEALERSHIP  VIF =  1.52
# CHANNEL_DIRECT  VIF =  1.13
# CHANNEL_OTHERS  VIF =  1.0
# CHANNEL_TRAVEL AGENT  VIF =  1.01
# CHANNEL_WEBSALES  VIF =  1.23
# BODY_TYPE_Coupe  VIF =  1.07
# BODY_TYPE_Hatchback  VIF =  1.06
# BODY_TYPE_MUV  VIF =  1.01
# BODY_TYPE_SUV  VIF =  1.33
# BODY_TYPE_Van  VIF =  1.01
# ZONE_Eastern  VIF =  1.46
# ZONE_North Eastern  VIF =  1.05
# ZONE_Northern  VIF =  1.74
# ZONE_Southern  VIF =  1.26

# %% [markdown]
# Comments : all the VIF are less than 2 We can proceed on the LR

# %%
import statsmodels.api as sm

import random
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# ...
#          Current function value: 0.639068
#          Iterations: 35
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                 5393
# Model:                          Logit   Df Residuals:                     5364
# Method:                           MLE   Df Model:                           28
# Date:                Tue, 19 Oct 2021   Pseudo R-squ.:                 0.07532
# Time:                        06:05:51   Log-Likelihood:                -3446.5
# converged:                      False   LL-Null:                       -3727.2
# Covariance Type:            nonrobust   LLR p-value:                1.359e-100
# ...
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.1407     93.827     -0.001      0.999    -184.038     183.756
# INTERMEDIARY              -0.2308      0.033     -7.023      0.000      -0.295      -0.166
# ...

# %% [markdown]
# Removing all features that have Pvalue greater that 0.05

# %%
X.drop(['OD_PREM','TP_PREM','Ratio_PS','LOCATION','CAR_TYPE','STATE','CHANNEL_BANC ASSURANCE','CHANNEL_DIRECT','CHANNEL_OTHERS','CHANNEL_TRAVEL AGENT'],axis=1,inplace=True)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.641034
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                 5393
# Model:                          Logit   Df Residuals:                     5374
# Method:                           MLE   Df Model:                           18
# Date:                Tue, 19 Oct 2021   Pseudo R-squ.:                 0.07247
# Time:                        06:05:52   Log-Likelihood:                -3457.1
# converged:                       True   LL-Null:                       -3727.2
# Covariance Type:            nonrobust   LLR p-value:                3.499e-103
# ...
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.1437      0.029     -4.982      0.000      -0.200      -0.087
# INTERMEDIARY           -0.2358      0.031     -7.562      0.000      -0.297      -0.175
# ...

# %%
X.drop(['CHANNEL_WEBSALES','BODY_TYPE_Coupe','BODY_TYPE_Hatchback','BODY_TYPE_MUV','BODY_TYPE_SUV','BODY_TYPE_Van','ZONE_Eastern','ZONE_North Eastern'],axis=1,inplace=True)

# %%
random.seed(10)
logreg = sm.Logit(Y, sm.add_constant(X) )
lg = logreg.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.641865
#          Iterations 5

# %%
#Summary of logistic regression
print(lg.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                  CHURN   No. Observations:                 5393
# Model:                          Logit   Df Residuals:                     5382
# Method:                           MLE   Df Model:                           10
# Date:                Tue, 19 Oct 2021   Pseudo R-squ.:                 0.07127
# Time:                        06:05:52   Log-Likelihood:                -3461.6
# converged:                       True   LL-Null:                       -3727.2
# Covariance Type:            nonrobust   LLR p-value:                8.961e-108
# ...
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.1428      0.029     -4.960      0.000      -0.199      -0.086
# INTERMEDIARY          -0.2386      0.031     -7.695      0.000      -0.299      -0.178
# ...

# %% [markdown]
# Comments
#     1. p-value shows that the model is significant
#     2. The pseudo R2 value is 0.07127, which means that model is not a good fit.
#     3. All the variables are significant.

# %%
## Collect the coef in a dataframe
lgcoef = pd.DataFrame(lg.params, columns=['coef'])

## Calculate Odds Ratio
lgcoef['Odds_ratio']=np.exp(lgcoef.coef)
lgcoef
# Out:
#                     coef  Odds_ratio
# const              -0.14        0.87
# INTERMEDIARY       -0.24        0.79
# VEH_MANU_YEAR      -0.19        0.82
# VEHICLE_MAKE       -0.10        0.91
# VEHICLE_MODEL       0.13        1.14
# POLICY_AGE         -0.23        0.80
# NCB                -0.39        0.68
# CHANNEL_BROKERS    -0.09        0.91
# CHANNEL_DEALERSHIP  0.29        1.34
# ZONE_Northern       0.10        1.11
# ZONE_Southern       0.10        1.11

# %%
#Calculate Probability
lgcoef['probability'] = lgcoef['Odds_ratio']/(1+lgcoef['Odds_ratio'])
lgcoef
# Out:
#                     coef  Odds_ratio  probability
# const              -0.14        0.87         0.46
# INTERMEDIARY       -0.24        0.79         0.44
# VEH_MANU_YEAR      -0.19        0.82         0.45
# VEHICLE_MAKE       -0.10        0.91         0.48
# VEHICLE_MODEL       0.13        1.14         0.53
# POLICY_AGE         -0.23        0.80         0.44
# NCB                -0.39        0.68         0.40
# CHANNEL_BROKERS    -0.09        0.91         0.48
# CHANNEL_DEALERSHIP  0.29        1.34         0.57
# ZONE_Northern       0.10        1.11         0.53
# ZONE_Southern       0.10        1.11         0.53

# %%
#Calculate p value
lgcoef['pval']=lg.pvalues

#Display rounded to 2 decimal points
pd.options.display.float_format = '{:.2f}'.format
lgcoef
# Out:
#                     coef  Odds_ratio  probability  pval
# const              -0.14        0.87         0.46  0.00
# INTERMEDIARY       -0.24        0.79         0.44  0.00
# VEH_MANU_YEAR      -0.19        0.82         0.45  0.00
# VEHICLE_MAKE       -0.10        0.91         0.48  0.00
# VEHICLE_MODEL       0.13        1.14         0.53  0.00
# POLICY_AGE         -0.23        0.80         0.44  0.00
# NCB                -0.39        0.68         0.40  0.00
# CHANNEL_BROKERS    -0.09        0.91         0.48  0.00
# CHANNEL_DEALERSHIP  0.29        1.34         0.57  0.00
# ZONE_Northern       0.10        1.11         0.53  0.00
# ZONE_Southern       0.10        1.11         0.53  0.00

# %%
#Sort by descending order of odds ratio 
lgcoef = lgcoef.sort_values(by="Odds_ratio", ascending=False)

#Filter to display only variables with significant p value
pval_filter = lgcoef['pval']<=0.05
lgcoef[pval_filter]
# Out:
#                     coef  Odds_ratio  probability  pval
# CHANNEL_DEALERSHIP  0.29        1.34         0.57  0.00
# VEHICLE_MODEL       0.13        1.14         0.53  0.00
# ZONE_Southern       0.10        1.11         0.53  0.00
# ZONE_Northern       0.10        1.11         0.53  0.00
# CHANNEL_BROKERS    -0.09        0.91         0.48  0.00
# VEHICLE_MAKE       -0.10        0.91         0.48  0.00
# const              -0.14        0.87         0.46  0.00
# VEH_MANU_YEAR      -0.19        0.82         0.45  0.00
# POLICY_AGE         -0.23        0.80         0.44  0.00
# INTERMEDIARY       -0.24        0.79         0.44  0.00
# NCB                -0.39        0.68         0.40  0.00

# %% [markdown]
# Comments : Relationship is the most valuable assets for the people with high car budget. It plays a key role in the attrition decision. Their prime location is also a key factor.

# %% [markdown]
# #### Logistic Regression using SCikitLearn library

# %%
X_lr = df_dummy_high.drop(['CHURN','BODY_TYPE_Sedan','SUM_INSURED','ZONE_Western','VEH_AGE','SENIORITY','CAR_BUDGET','TOTAL_PREMIUM','CHANNEL_WEBSALES','BODY_TYPE_Coupe','BODY_TYPE_Hatchback','BODY_TYPE_MUV','BODY_TYPE_SUV','BODY_TYPE_Van','ZONE_Eastern','ZONE_North Eastern','OD_PREM','TP_PREM','Ratio_PS','LOCATION','CAR_TYPE','STATE','CHANNEL_BANC ASSURANCE','CHANNEL_DIRECT','CHANNEL_OTHERS','CHANNEL_TRAVEL AGENT'],axis=1)
Y_lr = df_dummy_high['CHURN']

# %%
X_lr.columns
# Out:
# Index(['INTERMEDIARY', 'VEH_MANU_YEAR', 'VEHICLE_MAKE', 'VEHICLE_MODEL',
#        'POLICY_AGE', 'NCB', 'CHANNEL_BROKERS', 'CHANNEL_DEALERSHIP',
#        'ZONE_Northern', 'ZONE_Southern'],
#       dtype='object')

# %%
# splitting data into training and test set for independent attributes. Test Size =30% and stratify on Y to have the good proportion between 0 and 1
from sklearn.model_selection import train_test_split

# %%
X_train_lr, X_test_lr, Y_train_lr, Y_test_lr= train_test_split(X_lr, Y_lr, test_size=.30, random_state=1,stratify= Y_lr)

# %%
num_cols = X_train_lr.columns[:].to_list()
X_train_lr.loc[:, num_cols] = ss.fit_transform(X_train_lr.loc[:, num_cols])
X_train_lr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#       INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Northern  ZONE_Southern
# 12            0.52          -1.27  ...          -0.57          -0.50
# 256          -0.32           0.55  ...           1.75          -0.50
# 3904         -0.71           0.09  ...          -0.57           2.01
# 3301          2.44           0.09  ...           1.75          -0.50
# 4613         -0.05          -0.36  ...          -0.57          -0.50
#
# [5 rows x 10 columns]

# %%
num_cols = X_test_lr.columns[:].to_list()
X_test_lr.loc[:, num_cols] = ss.transform(X_test_lr.loc[:, num_cols])
X_test_lr.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#       INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Northern  ZONE_Southern
# 2039         -0.75           0.55  ...          -0.57           2.01
# 96           -0.71           0.55  ...          -0.57           2.01
# 3117          1.64           0.09  ...          -0.57          -0.50
# 457          -0.68           1.00  ...          -0.57          -0.50
# 1813         -0.64           0.55  ...           1.75          -0.50
#
# [5 rows x 10 columns]

# %%
from sklearn.linear_model import  LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix, f1_score,roc_auc_score,roc_curve
from sklearn import metrics
import pickle

# %%
lr = LogisticRegression()
lr.fit(X_train_lr, Y_train_lr)

train_pred = lr.predict(X_train_lr)
test_pred = lr.predict(X_test_lr)

print("Acc Train:",metrics.accuracy_score(Y_train_lr, train_pred))
print('Train F1: ', f1_score(Y_train_lr, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test_lr, test_pred))
print('Test F1: ', f1_score(Y_test_lr, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test_lr, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test_lr, test_pred)}')
print('\n')
print(classification_report(Y_test_lr, test_pred))
# Out:
# Acc Train: 0.633112582781457
# Train F1:  0.5781297593664332
# Acc Test: 0.6087762669962917
# Test F1:  0.5462365591397851
# Area Under Curve: 0.6024820519113947
# Confusion Matrix:
# [[604 256]
#  [377 381]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66       860
#            1       0.60      0.50      0.55       758
#
#     accuracy                           0.61      1618
#    macro avg       0.61      0.60      0.60      1618
# weighted avg       0.61      0.61      0.60      1618

# %% [markdown]
# ### LDA

# %%
df_dummy_high.head()
# Out:
#    INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 0             0         2014.0  ...              1             0
# 1           467         2012.0  ...              1             0
# 2           108         2014.0  ...              0             1
# 3           296         2011.0  ...              0             1
# 4             0         2008.0  ...              0             0
#
# [5 rows x 36 columns]

# %%
X = df_dummy_high.drop(df_dummy_high[["CHURN",'TOTAL_PREMIUM','CAR_BUDGET']] , axis=1)
Y = df_dummy_high['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
# Out:
#       INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 12        0.521234      -1.274659  ...      -0.497515      1.165922
# 256      -0.315245       0.545077  ...      -0.497515     -0.857690
# 3904     -0.706059       0.090143  ...       2.009988     -0.857690
# 3301      2.441023       0.090143  ...      -0.497515     -0.857690
# 4613     -0.054702      -0.364791  ...      -0.497515      1.165922
#
# [5 rows x 33 columns]

# %%
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
#       INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 2039     -0.750626       0.545077  ...       2.009988     -0.857690
# 96       -0.706059       0.545077  ...       2.009988     -0.857690
# 3117      1.635398       0.090143  ...      -0.497515      1.165922
# 457      -0.678634       1.000012  ...      -0.497515     -0.857690
# 1813     -0.644352       0.545077  ...      -0.497515     -0.857690
#
# [5 rows x 33 columns]

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(X_train, Y_train)

train_pred = lda.predict(X_train)
test_pred = lda.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6413245033112582
# Train F1:  0.5886998784933171
# Acc Test: 0.6081582200247219
# Test F1:  0.5522598870056498
# Area Under Curve: 0.602683009142787
# Confusion Matrix:
# [[593 267]
#  [367 391]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.69      0.65       860
#            1       0.59      0.52      0.55       758
#
#     accuracy                           0.61      1618
#    macro avg       0.61      0.60      0.60      1618
# weighted avg       0.61      0.61      0.61      1618

# %% [markdown]
# ### Decision Tree

# %%
# Create Decision Tree classifer object
dt_model = DecisionTreeClassifier(criterion = 'gini' )
# Train Decision Tree Classifier
dt_model.fit(X_train, Y_train)

#Predict the response for test dataset
train_pred = dt_model.predict(X_train)
test_pred = dt_model.predict(X_test)
print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9997350993377483
# Train F1:  0.9997169544296632
# Acc Test: 0.565512978986403
# Test F1:  0.5414220482713633
# Area Under Curve: 0.5644443762655703
# Confusion Matrix:
# [[500 360]
#  [343 415]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.58      0.59       860
#            1       0.54      0.55      0.54       758
#
#     accuracy                           0.57      1618
#    macro avg       0.56      0.56      0.56      1618
# weighted avg       0.57      0.57      0.57      1618

# %% [markdown]
# The model is overfitting. So we prune it.

# %%
params = {'min_samples_split':[5,7,10],
          'min_samples_leaf':[10,15,20],
          'max_depth': [5, 8, 10],
          }

# %%
grid_dt_model = GridSearchCV(dt_model, param_grid = params, verbose=1)
grid_dt_model.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 135 out of 135 | elapsed:    2.9s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
# ...

# %%
grid_dt_model.best_params_
# Out:
# {'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 5}

# %%
grid_dt_model.best_score_
# Out:
# 0.630728476821192

# %%
abc_score=get_metrics_score(grid_dt_model)

train_pred = grid_dt_model.predict(X_train)
test_pred = grid_dt_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6574834437086092
# Accuracy on test set :  0.6186650185414091
# Recall on training set :  0.5382003395585738
# Recall on test set :  0.48284960422163586
# Precision on training set :  0.6659663865546218
# Precision on test set :  0.6192893401015228
# Train F1:  0.5953051643192488
# Test F1:  0.542624166048925
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.67       860
#            1       0.62      0.48      0.54       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.61      0.61      1618
# weighted avg       0.62      0.62      0.61      1618

# %%
params = {'min_samples_split':[3,4,7,10],
          'min_samples_leaf':[5,7,11],
          'max_depth': [3,4,6,7],
          }

# %%
grid_dt_model = GridSearchCV(dt_model, param_grid = params, verbose=1)
grid_dt_model.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed:    4.1s finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features=None,
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               presort='deprecated',
# ...

# %%
grid_dt_model.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 5, 'min_samples_split': 3}

# %%
grid_dt_model.best_score_
# Out:
# 0.6251655629139072

# %%
abc_score=get_metrics_score(grid_dt_model)

train_pred = grid_dt_model.predict(X_train)
test_pred = grid_dt_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6381456953642384
# Accuracy on test set :  0.6217552533992583
# Recall on training set :  0.5087719298245614
# Recall on test set :  0.470976253298153
# Precision on training set :  0.6435218324982105
# Precision on test set :  0.6285211267605634
# Train F1:  0.5682680151706702
# Test F1:  0.5384615384615384
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68       860
#            1       0.63      0.47      0.54       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.61      0.61      1618
# weighted avg       0.62      0.62      0.61      1618

# %%
dt_model = DecisionTreeClassifier(criterion = 'gini', max_depth= 3, min_samples_leaf=5, min_samples_split=3)
# Train Decision Tree Classifier
dt_model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=3,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#Predict the response for test dataset
train_pred = dt_model.predict(X_train)
test_pred = dt_model.predict(X_test)
print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.6381456953642384
# Train F1:  0.5682680151706702
# Acc Test: 0.6217552533992583
# Test F1:  0.5384615384615384
# Area Under Curve: 0.6128137080444254
# Confusion Matrix:
# [[649 211]
#  [401 357]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68       860
#            1       0.63      0.47      0.54       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.61      0.61      1618
# weighted avg       0.62      0.62      0.61      1618

# %%
pd.Series(dt_model.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.527205
# INTERMEDIARY              0.306258
# VEHICLE_MODEL             0.077480
# VEHICLE_MAKE              0.050213
# Ratio_PS                  0.038843
# CHANNEL_BANC ASSURANCE    0.000000
# VEH_MANU_YEAR             0.000000
# SUM_INSURED               0.000000
# OD_PREM                   0.000000
# TP_PREM                   0.000000
# POLICY_AGE                0.000000
# VEH_AGE                   0.000000
# SENIORITY                 0.000000
# CAR_TYPE                  0.000000
# LOCATION                  0.000000
# STATE                     0.000000
# ZONE_Western              0.000000
# ZONE_Southern             0.000000
# CHANNEL_DEALERSHIP        0.000000
# CHANNEL_DIRECT            0.000000
# CHANNEL_OTHERS            0.000000
# CHANNEL_TRAVEL AGENT      0.000000
# CHANNEL_WEBSALES          0.000000
# BODY_TYPE_Coupe           0.000000
# BODY_TYPE_Hatchback       0.000000
# BODY_TYPE_MUV             0.000000
# BODY_TYPE_SUV             0.000000
# ...

# %% [markdown]
# ### ANN

# %%
ANN_model = MLPClassifier(hidden_layer_sizes=(100,100)
                     ,max_iter=100
                     ,solver='adam'
                     ,activation='relu'
                     ,random_state=1
                     ,verbose=True
                     ,tol=0.0001)

# %%
ANN_model.fit(X_train,Y_train)

train_pred = ANN_model.predict(X_train)
test_pred = ANN_model.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Iteration 1, loss = 0.69950673
# Iteration 2, loss = 0.65089086
# Iteration 3, loss = 0.63522307
# Iteration 4, loss = 0.62615666
# Iteration 5, loss = 0.62131045
# Iteration 6, loss = 0.61642458
# Iteration 7, loss = 0.61067760
# Iteration 8, loss = 0.60654981
# Iteration 9, loss = 0.60237921
# Iteration 10, loss = 0.59798530
# Iteration 11, loss = 0.59458033
# Iteration 12, loss = 0.59059053
# Iteration 13, loss = 0.58626698
# Iteration 14, loss = 0.58375700
# Iteration 15, loss = 0.57840322
# Iteration 16, loss = 0.57496670
# Iteration 17, loss = 0.57105649
# Iteration 18, loss = 0.56795792
# Iteration 19, loss = 0.56627979
# Iteration 20, loss = 0.56169178
# Iteration 21, loss = 0.55390666
# Iteration 22, loss = 0.55207923
# Iteration 23, loss = 0.54689930
# Iteration 24, loss = 0.54635816
# Iteration 25, loss = 0.54021685
# Iteration 26, loss = 0.53497126
# Iteration 27, loss = 0.53271675
# Iteration 28, loss = 0.52773821
# Iteration 29, loss = 0.52493453
# ...

# %% [markdown]
# The model is overfit. So we prune it

# %%
parameter_space = {
    'hidden_layer_sizes': [(100,300,100),(200,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
tuned_ANN_model = GridSearchCV(ANN_model, parameter_space, n_jobs=-1, cv=5,verbose =1)
tuned_ANN_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 14.6min finished
# Iteration 1, loss = 0.66691200
# Iteration 2, loss = 0.63752082
# Iteration 3, loss = 0.63594900
# Iteration 4, loss = 0.63492352
# Iteration 5, loss = 0.63376085
# Iteration 6, loss = 0.63294182
# Iteration 7, loss = 0.63264184
# Iteration 8, loss = 0.63100718
# Iteration 9, loss = 0.63195725
# Iteration 10, loss = 0.63038280
# Iteration 11, loss = 0.62940897
# Iteration 12, loss = 0.62843095
# Iteration 13, loss = 0.62721313
# Iteration 14, loss = 0.62628446
# Iteration 15, loss = 0.62555219
# Iteration 16, loss = 0.62495591
# Iteration 17, loss = 0.62496539
# Iteration 18, loss = 0.62437240
# Iteration 19, loss = 0.62321703
# Iteration 20, loss = 0.62080436
# Iteration 21, loss = 0.62218982
# ...

# %%
tuned_ANN_model.best_params_
# Out:
# {'activation': 'tanh',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (200,),
#  'learning_rate': 'constant',
#  'solver': 'adam'}

# %%
abc_score=get_metrics_score(tuned_ANN_model)

train_pred = tuned_ANN_model.predict(X_train)
test_pred = tuned_ANN_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7350993377483444
# Accuracy on test set :  0.6205191594561187
# Recall on training set :  0.6825127334465195
# Recall on test set :  0.5765171503957783
# Precision on training set :  0.7331306990881459
# Precision on test set :  0.5986301369863014
# Train F1:  0.7069167643610785
# Test F1:  0.5873655913978495
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.66      0.65       860
#            1       0.60      0.58      0.59       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.62      0.62      1618
# weighted avg       0.62      0.62      0.62      1618

# %%
parameter_space = {
    'hidden_layer_sizes': [(10,30,10),(20,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.005],
    'learning_rate': ['constant','adaptive'],
}

# %%
tuned_ANN_model = GridSearchCV(ANN_model, parameter_space, n_jobs=-1, cv=5,verbose =1)
tuned_ANN_model.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed:  2.4min finished
# Iteration 1, loss = 0.79092332
# Iteration 2, loss = 0.77847072
# Iteration 3, loss = 0.76576824
# Iteration 4, loss = 0.75413011
# Iteration 5, loss = 0.74430861
# Iteration 6, loss = 0.73577797
# Iteration 7, loss = 0.72785997
# Iteration 8, loss = 0.72109005
# Iteration 9, loss = 0.71501366
# Iteration 10, loss = 0.70948453
# Iteration 11, loss = 0.70456479
# Iteration 12, loss = 0.70011084
# Iteration 13, loss = 0.69613140
# Iteration 14, loss = 0.69235831
# Iteration 15, loss = 0.68913095
# Iteration 16, loss = 0.68601822
# Iteration 17, loss = 0.68333028
# Iteration 18, loss = 0.68073644
# Iteration 19, loss = 0.67834055
# Iteration 20, loss = 0.67627252
# Iteration 21, loss = 0.67435080
# ...

# %%
tuned_ANN_model.best_params_
# Out:
# {'activation': 'relu',
#  'alpha': 0.0001,
#  'hidden_layer_sizes': (20,),
#  'learning_rate': 'constant',
#  'solver': 'sgd'}

# %%
abc_score=get_metrics_score(tuned_ANN_model)

train_pred = tuned_ANN_model.predict(X_train)
test_pred = tuned_ANN_model.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6439735099337748
# Accuracy on test set :  0.6087762669962917
# Recall on training set :  0.5415959252971138
# Recall on test set :  0.4920844327176781
# Precision on training set :  0.641851106639839
# Precision on test set :  0.6006441223832528
# Train F1:  0.587476979742173
# Test F1:  0.5409717186366932
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.71      0.66       860
#            1       0.60      0.49      0.54       758
#
#     accuracy                           0.61      1618
#    macro avg       0.61      0.60      0.60      1618
# weighted avg       0.61      0.61      0.60      1618

# %% [markdown]
# ### RANDOM FOREST

# %%
rf = RandomForestClassifier(random_state=1)
rf.fit(X_train, Y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.9997350993377483
# Train F1:  0.9997171145685997
# Acc Test: 0.6297898640296663
# Test F1:  0.5784658691062632
# Area Under Curve: 0.6245965515125484
# Confusion Matrix:
# [[608 252]
#  [347 411]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67       860
#            1       0.62      0.54      0.58       758
#
#     accuracy                           0.63      1618
#    macro avg       0.63      0.62      0.62      1618
# weighted avg       0.63      0.63      0.63      1618

# %% [markdown]
# Tuning

# %%
params = {'n_estimators': [70,90,100],
          'min_samples_split':[5,7,10],
          'min_samples_leaf':[10,15,20],
          'max_depth': [5, 8, 10],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed:  1.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 8,
#  'min_samples_leaf': 15,
#  'min_samples_split': 5,
#  'n_estimators': 90}

# %%
abc_score=get_metrics_score(grid_rfcl)

train_pred = grid_rfcl.predict(X_train)
test_pred = grid_rfcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7162913907284768
# Accuracy on test set :  0.6415327564894932
# Recall on training set :  0.6095076400679117
# Recall on test set :  0.503957783641161
# Precision on training set :  0.7386831275720165
# Precision on test set :  0.6518771331058021
# Train F1:  0.667906976744186
# Test F1:  0.5684523809523809
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.76      0.69       860
#            1       0.65      0.50      0.57       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.63      1618

# %%
params = {'n_estimators': [50,70,80],
          'min_samples_split':[8,9,10,15],
          'min_samples_leaf':[5,10,15],
          'max_depth': [10,12,15,17],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 144 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   43.1s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  2.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 15,
#  'n_estimators': 50}

# %%
abc_score=get_metrics_score(grid_rfcl)

train_pred = grid_rfcl.predict(X_train)
test_pred = grid_rfcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7806622516556292
# Accuracy on test set :  0.6378244746600742
# Recall on training set :  0.7057159026598755
# Recall on test set :  0.525065963060686
# Precision on training set :  0.8019292604501608
# Precision on test set :  0.6378205128205128
# Train F1:  0.7507525586995785
# Test F1:  0.5759768451519537
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.74      0.68       860
#            1       0.64      0.53      0.58       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.63      1618

# %%
params = {'n_estimators': [50,70,80],
          'min_samples_split':[8,9,10,15],
          'min_samples_leaf':[5,10,15],
          'max_depth': [10,12,15,17],          
          }

# %%
grid_rfcl = GridSearchCV(rf, param_grid = params, verbose=1, cv = 7, scoring='accuracy',n_jobs=-1)
grid_rfcl.fit(X_train, Y_train)
# Out:
# Fitting 7 folds for each of 144 candidates, totalling 1008 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:   10.9s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 1008 out of 1008 | elapsed:  4.0min finished
# GridSearchCV(cv=7, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
# ...

# %%
grid_rfcl.best_params_
# Out:
# {'max_depth': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 15,
#  'n_estimators': 80}

# %%
abc_score=get_metrics_score(grid_rfcl)

train_pred = grid_rfcl.predict(X_train)
test_pred = grid_rfcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7864900662251656
# Accuracy on test set :  0.6396786155747837
# Recall on training set :  0.7074136955291455
# Recall on test set :  0.5184696569920845
# Precision on training set :  0.8122157244964262
# Precision on test set :  0.6432078559738135
# Train F1:  0.7562008469449485
# Test F1:  0.5741417092768445
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69       860
#            1       0.64      0.52      0.57       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.63      1618

# %%
rf = RandomForestClassifier(random_state=1,max_depth=10,min_samples_leaf=5,min_samples_split=15,n_estimators=80)
rf.fit(X_train, Y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print("Acc Train:",metrics.accuracy_score(Y_train, train_pred))
print('Train F1: ', f1_score(Y_train, train_pred))
print("Acc Test:",metrics.accuracy_score(Y_test, test_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('Area Under Curve:',roc_auc_score(Y_test, test_pred))
print(f'Confusion Matrix: \n{confusion_matrix(Y_test, test_pred)}')
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Acc Train: 0.7864900662251656
# Train F1:  0.7562008469449485
# Acc Test: 0.6396786155747837
# Test F1:  0.5741417092768445
# Area Under Curve: 0.6324906424495306
# Confusion Matrix:
# [[642 218]
#  [365 393]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.64      0.75      0.69       860
#            1       0.64      0.52      0.57       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.63      1618

# %%
# Importance of features
pd.Series(rf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# INTERMEDIARY              0.149973
# NCB                       0.119436
# Ratio_PS                  0.091747
# OD_PREM                   0.079898
# SUM_INSURED               0.078223
# VEHICLE_MODEL             0.060720
# LOCATION                  0.056683
# TP_PREM                   0.050208
# SENIORITY                 0.042769
# VEH_MANU_YEAR             0.039211
# VEHICLE_MAKE              0.038278
# CHANNEL_DEALERSHIP        0.036359
# VEH_AGE                   0.036072
# STATE                     0.034335
# POLICY_AGE                0.023088
# BODY_TYPE_Sedan           0.009844
# ZONE_Western              0.009666
# BODY_TYPE_SUV             0.009360
# ZONE_Northern             0.007928
# CHANNEL_DIRECT            0.007154
# ZONE_Southern             0.006762
# ZONE_Eastern              0.003535
# CHANNEL_BANC ASSURANCE    0.003335
# CHANNEL_BROKERS           0.002610
# BODY_TYPE_Coupe           0.001648
# ZONE_North Eastern        0.000466
# BODY_TYPE_Hatchback       0.000389
# ...

# %% [markdown]
# ### Ensemble Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
be = RandomForestClassifier()
bgcl = BaggingClassifier(base_estimator=be,random_state=1)


bgcl = bgcl.fit(X_train, Y_train)

abc_score=get_metrics_score(bgcl)

train_pred = bgcl.predict(X_train)
test_pred = bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.9809271523178807
# Accuracy on test set :  0.6396786155747837
# Recall on training set :  0.9796264855687606
# Recall on test set :  0.5527704485488126
# Precision on training set :  0.9796264855687606
# Precision on test set :  0.6319758672699849
# Train F1:  0.9796264855687606
# Test F1:  0.5897255453905701
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.72      0.68       860
#            1       0.63      0.55      0.59       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.64      1618

# %%
params = {'n_estimators': [70,90,100],
          'base_estimator__min_samples_split':[5,7,10],
          'base_estimator__min_samples_leaf':[10,15,20],
          'base_estimator__max_depth': [5, 8, 10]
          }

# %%
bgcl = BaggingClassifier(base_estimator=be,random_state=1 )
grid_bgcl = GridSearchCV(bgcl, param_grid = params,verbose=1, cv = 7, scoring='accuracy',n_jobs=-1)
grid_bgcl.fit(X_train, Y_train)
# Out:
# Fitting 7 folds for each of 81 candidates, totalling 567 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed: 60.0min
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed: 147.1min
# [Parallel(n_jobs=-1)]: Done 567 out of 567 | elapsed: 188.5min finished
# GridSearchCV(cv=7, error_score=nan,
#              estimator=BaggingClassifier(base_estimator=RandomForestClassifier(bootstrap=True,
#                                                                                ccp_alpha=0.0,
#                                                                                class_weight=None,
#                                                                                criterion='gini',
#                                                                                max_depth=None,
# ...

# %%
grid_bgcl.best_params_
# Out:
# {'base_estimator__max_depth': 8,
#  'base_estimator__min_samples_leaf': 10,
#  'base_estimator__min_samples_split': 5,
#  'n_estimators': 70}

# %%
abc_score=get_metrics_score(grid_bgcl)

train_pred = grid_bgcl.predict(X_train)
test_pred = grid_bgcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.7120529801324503
# Accuracy on test set :  0.6353522867737948
# Recall on training set :  0.6055461233729486
# Recall on test set :  0.49340369393139843
# Precision on training set :  0.7328767123287672
# Precision on test set :  0.6448275862068965
# Train F1:  0.6631546327858692
# Test F1:  0.5590433482810164
#
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.76      0.69       860
#            1       0.64      0.49      0.56       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.62      1618
# weighted avg       0.64      0.64      0.63      1618

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbcl = GradientBoostingClassifier(n_estimators = 1500,random_state=1,learning_rate=0.001)
gbcl = gbcl.fit(X_train, Y_train)

abc_score=get_metrics_score(gbcl)

train_pred = gbcl.predict(X_train)
test_pred = gbcl.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6513907284768212
# Accuracy on test set :  0.6242274412855378
# Recall on training set :  0.5285795132993775
# Recall on test set :  0.4868073878627968
# Precision on training set :  0.6591390261115032
# Precision on test set :  0.6275510204081632
# Train F1:  0.5866834170854272
# Test F1:  0.5482912332838038
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.75      0.68       860
#            1       0.63      0.49      0.55       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.62      0.61      1618
# weighted avg       0.62      0.62      0.62      1618

# %%
# Importance of features
pd.Series(gbcl.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.422195
# INTERMEDIARY              0.240227
# CHANNEL_DEALERSHIP        0.066683
# SENIORITY                 0.056532
# VEHICLE_MODEL             0.051185
# VEHICLE_MAKE              0.040987
# Ratio_PS                  0.024910
# LOCATION                  0.020734
# VEH_MANU_YEAR             0.019835
# STATE                     0.018240
# SUM_INSURED               0.014522
# OD_PREM                   0.009041
# TP_PREM                   0.008299
# POLICY_AGE                0.003498
# BODY_TYPE_Coupe           0.001630
# CHANNEL_BROKERS           0.000837
# ZONE_Southern             0.000646
# BODY_TYPE_MUV             0.000000
# ZONE_Northern             0.000000
# ZONE_North Eastern        0.000000
# ZONE_Eastern              0.000000
# BODY_TYPE_Van             0.000000
# BODY_TYPE_Sedan           0.000000
# BODY_TYPE_SUV             0.000000
# BODY_TYPE_Hatchback       0.000000
# CHANNEL_BANC ASSURANCE    0.000000
# VEH_AGE                   0.000000
# ...

# %% [markdown]
# ### ADABOOST

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators= 500, random_state=1, learning_rate=0.01)
ada.fit(X_train, Y_train)

abc_score=get_metrics_score(ada)

train_pred = ada.predict(X_train)
test_pred = ada.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6426490066225166
# Accuracy on test set :  0.6266996291718171
# Recall on training set :  0.5217883418222977
# Recall on test set :  0.49340369393139843
# Precision on training set :  0.6465638148667602
# Precision on test set :  0.6296296296296297
# Train F1:  0.5775133103664266
# Test F1:  0.5532544378698224
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.68       860
#            1       0.63      0.49      0.55       758
#
#     accuracy                           0.63      1618
#    macro avg       0.63      0.62      0.62      1618
# weighted avg       0.63      0.63      0.62      1618

# %%
# Importance of features
pd.Series(ada.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# INTERMEDIARY              0.334
# NCB                       0.292
# SENIORITY                 0.146
# CHANNEL_DEALERSHIP        0.128
# VEHICLE_MODEL             0.100
# CHANNEL_BANC ASSURANCE    0.000
# VEH_MANU_YEAR             0.000
# VEHICLE_MAKE              0.000
# SUM_INSURED               0.000
# OD_PREM                   0.000
# TP_PREM                   0.000
# POLICY_AGE                0.000
# VEH_AGE                   0.000
# Ratio_PS                  0.000
# LOCATION                  0.000
# STATE                     0.000
# ZONE_Western              0.000
# ZONE_Southern             0.000
# CHANNEL_DIRECT            0.000
# CHANNEL_OTHERS            0.000
# CHANNEL_TRAVEL AGENT      0.000
# CHANNEL_WEBSALES          0.000
# BODY_TYPE_Coupe           0.000
# BODY_TYPE_Hatchback       0.000
# BODY_TYPE_MUV             0.000
# BODY_TYPE_SUV             0.000
# BODY_TYPE_Sedan           0.000
# BODY_TYPE_Van             0.000
# ZONE_Eastern              0.000
# ...

# %% [markdown]
# ### Extreme Gradient boost

# %%
X = df_dummy_high.drop(["CHURN",'TOTAL_PREMIUM','CAR_BUDGET','CAR_TYPE'],axis=1)
Y = df_dummy_high['CHURN']

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X, Y, test_size=.30, random_state=1,stratify=Y)
num_cols = X_train.columns[:].to_list()
X_train.loc[:, num_cols] = ss.fit_transform(X_train.loc[:, num_cols])
X_train.head()
num_cols = X_test.columns[:].to_list()
X_test.loc[:, num_cols] = ss.transform(X_test.loc[:, num_cols])
X_test.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
#       INTERMEDIARY  VEH_MANU_YEAR  ...  ZONE_Southern  ZONE_Western
# 2039     -0.750626       0.545077  ...       2.009988     -0.857690
# ...

# %%
from xgboost import XGBClassifier
xg = XGBClassifier(n_estimators= 500, random_state=1, learning_rate=0.001)
xg.fit(X_train, Y_train)

abc_score=get_metrics_score(xg)

train_pred = xg.predict(X_train)
test_pred = xg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6410596026490066
# Accuracy on test set :  0.6242274412855378
# Recall on training set :  0.5302773061686474
# Recall on test set :  0.49604221635883905
# Precision on training set :  0.6409028727770177
# Precision on test set :  0.6245847176079734
# Train F1:  0.580365438216166
# Test F1:  0.5529411764705883
#
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.74      0.68       860
#            1       0.62      0.50      0.55       758
#
#     accuracy                           0.62      1618
#    macro avg       0.62      0.62      0.61      1618
# weighted avg       0.62      0.62      0.62      1618

# %%
make_confusion_matrix(xg,Y_test)

# %%
# Importance of features
pd.Series(xg.feature_importances_,index=X_train.columns).sort_values(ascending=False)
# Out:
# NCB                       0.365987
# CHANNEL_DEALERSHIP        0.107163
# INTERMEDIARY              0.104762
# VEHICLE_MODEL             0.083168
# SENIORITY                 0.067989
# VEHICLE_MAKE              0.058617
# SUM_INSURED               0.058104
# VEH_MANU_YEAR             0.057399
# LOCATION                  0.051359
# Ratio_PS                  0.045452
# CHANNEL_BANC ASSURANCE    0.000000
# OD_PREM                   0.000000
# TP_PREM                   0.000000
# POLICY_AGE                0.000000
# VEH_AGE                   0.000000
# STATE                     0.000000
# ZONE_Western              0.000000
# ZONE_Southern             0.000000
# CHANNEL_DIRECT            0.000000
# CHANNEL_OTHERS            0.000000
# CHANNEL_TRAVEL AGENT      0.000000
# CHANNEL_WEBSALES          0.000000
# BODY_TYPE_Coupe           0.000000
# BODY_TYPE_Hatchback       0.000000
# BODY_TYPE_MUV             0.000000
# BODY_TYPE_SUV             0.000000
# BODY_TYPE_Sedan           0.000000
# ...

# %% [markdown]
# #### Hyper parameter tuning of XGBoost

# %%
params = {'n_estimators': [500, 600, 250],
          'min_samples_leaf':[10, 15, 20],
          'max_depth': [5, 8, 10],
          "learning_rate":[0.001,0.0005,0.1]
          }

# %%
# %%time
xg = XGBClassifier(random_state=1)
grid_xg = GridSearchCV(xg, param_grid = params, verbose=1, cv = 5, scoring='accuracy',n_jobs=-1)
grid_xg.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 405 out of 405 | elapsed: 20.8min finished
# CPU times: user 10.8 s, sys: 1.06 s, total: 11.9 s
# Wall time: 20min 47s

# %%
grid_xg.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_samples_leaf': 10,
#  'n_estimators': 250}

# %%
grid_xg.best_score_
# Out:
# 0.639205298013245

# %%
abc_score=get_metrics_score(grid_xg)

train_pred = grid_xg.predict(X_train)
test_pred = grid_xg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.9165562913907285
# Accuracy on test set :  0.6378244746600742
# Recall on training set :  0.9037917374080362
# Recall on test set :  0.5725593667546174
# Precision on training set :  0.9167623421354765
# Precision on test set :  0.6235632183908046
# Train F1:  0.9102308349957252
# Test F1:  0.5969738651994498
#
#
#               precision    recall  f1-score   support
#
#            0       0.65      0.70      0.67       860
#            1       0.62      0.57      0.60       758
#
#     accuracy                           0.64      1618
#    macro avg       0.64      0.63      0.63      1618
# weighted avg       0.64      0.64      0.64      1618

# %% [markdown]
# ### Light gbm

# %%
from lightgbm import LGBMClassifier
lg = LGBMClassifier(n_estimators= 5000, random_state=1, learning_rate=0.0001)
lg.fit(X_train, Y_train)

abc_score=get_metrics_score(lg)

train_pred = lg.predict(X_train)
test_pred = lg.predict(X_test)

print('Train F1: ', f1_score(Y_train, train_pred))
print('Test F1: ', f1_score(Y_test, test_pred))
print('\n')
print(classification_report(Y_test, test_pred))
# Out:
# Accuracy on training set :  0.6916556291390729
# Accuracy on test set :  0.6242274412855378
# Recall on training set :  0.522354272778721
# Recall on test set :  0.44063324538258575
# Precision on training set :  0.7425583266291231
# Precision on test set :  0.6447876447876448
# Train F1:  0.6132890365448506
# Test F1:  0.5235109717868339
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.79      0.69       860
#            1       0.64      0.44      0.52       758
#
#     accuracy                           0.62      1618
#    macro avg       0.63      0.61      0.61      1618
# weighted avg       0.63      0.62      0.61      1618

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# The best performing models considered :
# 1. Decision Tree
# 2. Gradient Boost
# 3. Ada boost
# 4. XGBoost
#
#
# For all the above models we take the top 10 features and select only the features common across all of them. Then we run Decision Tree model (as its our recommended model) with these features.

# %% [markdown]
# The Common Features are
# 1. Ratio_PS
# 2. INTERMEDIARY
# 3. NCB
# 4. LOCATION
# 5. VEHICLE_MODEL

# %%
x_feature = X[['Ratio_PS','INTERMEDIARY','NCB','LOCATION','VEHICLE_MODEL']]

# %%
Xf_train, Xf_test, Yf_train, Yf_test= train_test_split(x_feature, Y, test_size=.30, random_state=1,stratify=Y)

# %%
num_cols = Xf_train.columns[:].to_list()
Xf_train.loc[:, num_cols] = ss.fit_transform(Xf_train.loc[:, num_cols])
Xf_train.head()
# Out:
#       Ratio_PS  INTERMEDIARY       NCB  LOCATION  VEHICLE_MODEL
# 12    0.853185      0.521234 -1.594107 -1.303583       1.604694
# 256   0.147993     -0.315245 -1.594107 -0.549998      -1.144584
# 3904 -1.785162     -0.706059  0.818371 -0.723902       1.074132
# 3301  0.716189      2.441023  0.818371 -0.607966      -1.120467
# 4613  0.561874     -0.054702 -0.215548  0.522411       1.604694

# %%
num_cols = Xf_test.columns[:].to_list()
Xf_test.loc[:, num_cols] = ss.transform(Xf_test.loc[:, num_cols])
Xf_test.head()
# Out:
#       Ratio_PS  INTERMEDIARY       NCB  LOCATION  VEHICLE_MODEL
# 2039 -0.115795     -0.750626  0.129092 -0.694918       1.411762
# 96   -0.980185     -0.706059  0.129092 -1.216631       0.688268
# 3117 -0.068092      1.635398  1.852291 -1.158663      -0.517555
# 457   0.088435     -0.678634 -1.594107 -0.897807       0.736501
# 1813  0.166597     -0.644352  0.129092 -0.549998       0.688268

# %%
dt1 = DecisionTreeClassifier(criterion = 'gini', max_depth= 3, min_samples_leaf=5, min_samples_split=3)
# Train Decision Tree Classifier
dt1.fit(Xf_train, Yf_train)

train_pred = dt1.predict(Xf_train)
test_pred = dt1.predict(Xf_test)

print('Train ACC: ', dt1.score(Xf_train,Yf_train))
print('Test ACC: ', dt1.score(Xf_test,Yf_test))
print('Train F1: ', f1_score(Yf_train, train_pred))
print('Test F1: ', f1_score(Yf_test, test_pred))
print('\n')
print(classification_report(Yf_test, test_pred))
# Out:
# Train ACC:  0.6407947019867549
# Test ACC:  0.6217552533992583
# Train F1:  0.5614489003880984
# Test F1:  0.5255813953488372
#
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.78      0.69       860
#            1       0.64      0.45      0.53       758
#
#     accuracy                           0.62      1618
#    macro avg       0.63      0.61      0.61      1618
# weighted avg       0.62      0.62      0.61      1618

# %% [markdown]
# There is a slight improvement in accuracy. Recall is getting reduced.

# %%
y_predict = dt1.predict(Xf_test)
cm=metrics.confusion_matrix( Yf_test, y_predict, labels=[0, 1])
df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No(0)","Actual - Yes(1)"]],
                  columns = [i for i in ['Predicted - No(0)','Predicted - Yes(1)']])
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
plt.figure(figsize = (10,7))
sns.heatmap(df_cm, annot=labels,fmt='')
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 42.0, 'Predicted label')
